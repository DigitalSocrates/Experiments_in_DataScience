# %% [markdown]
# # Experiment in trying to predict a lottey number
#
# Note: We know that is almost impossible BUT we can try to apply some Data Sciencey stuff and see what will happen
#
# So... the plan is to use a quick model first like ARIMA and see the results and after that we will build a full scalle deep learning model!

# %%
# imports
import pandas as pd
import numpy as np
import pmdarima as pm
import pickle
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from src.utils import read_all_parquet_files
from src.model import Model
from src.trainer import Trainer

# %%
# dataset location
DATASET_LOCAL_COPY = './static/data/'

# List of columns to forecast
COLUMNS_TO_FORECAST = ['Ball_1', 'Ball_2', 'Ball_3', 'Ball_4', 'Ball_5', 'Ball_Bonus']

# Location of stored models
MODEL_LOCATION = './static/model/'

# %%
# read in lottery games data 
all_games = read_all_parquet_files(DATASET_LOCAL_COPY)

# need to convert data 
all_games['Ball_1'] = all_games['Ball_1'].astype('float64')
all_games['Ball_2'] = all_games['Ball_2'].astype('float64')
all_games['Ball_3'] = all_games['Ball_3'].astype('float64')
all_games['Ball_4'] = all_games['Ball_4'].astype('float64')
all_games['Ball_5'] = all_games['Ball_5'].astype('float64')
all_games['Ball_Bonus'] = all_games['Ball_Bonus'].astype('float64')

min_date = all_games['Date'].min()
max_date = all_games['Date'].max()

# sort by date
all_games.sort_values(by=['Date'], ascending=False, inplace=True)
# set index
all_games.set_index('Date', inplace=True)
# specify frequency IMPORTANT
all_games.index = pd.DatetimeIndex(all_games.index).to_period('3.5D')

# %%
# let us take a look at one of the columns
endog = all_games['Ball_1']
endog.plot(figsize=(15, 5))
# Out:
# <Axes: >

# %% [markdown]
# ## Randomize
#
# I do not think that we care if the data is ordered or not so let just get it randomized
#
# we can also use
# ```
# from sklearn.utils import shuffle
# all_games = shuffle(all_games)
# ```

# %%
all_games = all_games.sample(frac=1).reset_index(drop=True)

# %%
# let us take a look at one of the columns
endog = all_games['Ball_1']
endog.plot(figsize=(15, 5))
# Out:
# <Axes: >

# %%
all_games.describe(include='all')
# Out:
#            Ball_1      Ball_2      Ball_3      Ball_4      Ball_5  Ball_Bonus
# count  603.000000  603.000000  603.000000  603.000000  603.000000  603.000000
# mean    12.114428   23.240464   35.248756   47.144279   58.535655   13.318408
# std      9.797035   11.834415   12.465813   11.979942    9.390741    7.712964
# min      1.000000    2.000000    3.000000    7.000000   22.000000    1.000000
# 25%      4.000000   14.500000   26.000000   39.000000   54.000000    6.000000
# 50%     10.000000   22.000000   36.000000   48.000000   61.000000   13.000000
# 75%     18.000000   31.000000   44.000000   57.000000   66.000000   20.000000
# max     52.000000   58.000000   64.000000   68.000000   69.000000   26.000000

# %% [markdown]
# ## let us add additional features

# %%
# Calculate weights based on historical frequency
weights = {}
for column in COLUMNS_TO_FORECAST:
    number_counts = all_games[column].value_counts(normalize=True).to_dict()
    total_samples = len(all_games[column])
    column_weights = {number: count / total_samples for number, count in number_counts.items()}
    weights[column] = column_weights
    #all_games[f'{column}_weight'] = column_weights

# %%
t = weights.get('Ball_1')
t.get(3)
# Out:
# 0.00010725807116985553

# %%
# use first rows for training and use last row for out-of-sample testing
X_train_all_balls, X_test_all_balls = all_games.iloc[:-1, :len(COLUMNS_TO_FORECAST)], all_games.iloc[[-1], :len(COLUMNS_TO_FORECAST)]

# %%
X_train_all_balls.describe()
# Out:
#            Ball_1      Ball_2      Ball_3      Ball_4      Ball_5  Ball_Bonus
# count  602.000000  602.000000  602.000000  602.000000  602.000000  602.000000
# mean    12.127907   23.242525   35.249169   47.159468   58.568106   13.307309
# std      9.799585   11.844148   12.476175   11.984092    9.364651    7.714557
# min      1.000000    2.000000    3.000000    7.000000   22.000000    1.000000
# 25%      4.000000   14.250000   26.000000   39.000000   54.000000    6.000000
# 50%     10.000000   22.000000   36.000000   48.000000   61.000000   13.000000
# 75%     18.000000   31.000000   44.000000   57.000000   66.000000   20.000000
# max     52.000000   58.000000   64.000000   68.000000   69.000000   26.000000

# %%
X_test_all_balls
# Out:
#      Ball_1  Ball_2  Ball_3  Ball_4  Ball_5  Ball_Bonus
# 602     4.0    22.0    35.0    38.0    39.0        20.0

# %% [markdown]
# # Let us try to optimize our ARIMA model
#
# The expected value range for the hyperparameters p, d, and q in an ARIMA model depends on the characteristics of your time series data. These hyperparameters determine the autoregressive (AR), differencing (I), and moving average (MA) components of the model, respectively. Here are some general guidelines for choosing values within these ranges:
#
# p (AR order):
#
# The autoregressive order (p) represents the number of lagged observations included in the model. It indicates how many past time points are used to predict the current value.
# A typical range for p is 0 to 3. If the autocorrelation plot (ACF) shows significant values at lags 1, 2, or 3, you may consider these values for p.
# Use the PACF plot to help determine the initial estimate for p.
# d (I order):
#
# The differencing order (d) indicates the number of times the time series needs to be differenced to achieve stationarity. It removes trends and seasonality from the data.
# A common range for d is 0 to 2. If your data is already stationary, use d=0. If first-order differencing is required to make the data stationary, use d=1. In some cases, second-order differencing (d=2) may be necessary.
# q (MA order):
#
# The moving average order (q) represents the number of lagged forecast errors (residuals) included in the model. It captures the dependency on past forecast errors.
# A typical range for q is 0 to 3. If the autocorrelation of the residuals (ACF of residuals) shows significant values at lags 1, 2, or 3, you may consider these values for q.
# The ACF of residuals is used to determine the initial estimate for q.
# These ranges are general guidelines and can vary depending on the specific characteristics of your time series. It's often a good practice to start with smaller values and incrementally increase them while monitoring the model's performance (e.g., using cross-validation or evaluation metrics) to avoid overfitting.
#
# Keep in mind that the optimal values for p, d, and q may require experimentation, and automated tools like grid search or the auto_arima function in libraries such as pmdarima can help identify the best hyperparameters based on the data.

# %%
# instantiate model trainer 
trainer = Trainer()

models_for_each_ball = {}

# Perform a grid search to find the best ARIMA model
for column in COLUMNS_TO_FORECAST:
    print(f'training model using {column}')
    ts_data = X_train_all_balls[column]

    try:
        # Use auto_arima to automatically select the best hyperparameters
        best_order, best_model, best_criteria = trainer.find_best_arima_model(ts_data=ts_data)

        # Fit the ARIMA model with the best hyperparameters
        arima_model, arima_model_fit = trainer.fit_arima_model(
            ts_data=ts_data,
            order=best_order
        )

        # Create an instance of the Model class
        my_model = Model(name=column,
                         model=arima_model,
                         model_fit=arima_model_fit,
                         order=best_order)
        
        # save model and model's summary for each ball
        #arima_model_fit.save(f'{MODEL_LOCATION}{column}_model.pkl')
        pickle.dump(my_model, open(f'{MODEL_LOCATION}{column}_model.pkl', 'wb'))
        with open(f'{MODEL_LOCATION}{column}_model_metadata.txt', 'w',encoding='UTF-8') as f:
            summary = arima_model_fit.summary().as_text()
            f.write(summary)
            f.write(f'\nBest criteria used: {best_criteria}')
            f.flush()

        models_for_each_ball[column] = my_model
    except Exception as e:
        print (f'Exception 2 during fit -> {e}')
        continue
# Out:
# training model using Ball_1
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5017.122, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4745.487, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4868.863, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4660.810, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4614.459, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4575.168, Time=0.09 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.075, Time=0.13 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.90 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.60 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4467.615, Time=0.18 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4465.685, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4465.077, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4463.094, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4461.321, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4459.339, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4461.320, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4463.324, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.997 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1
sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4305.465, Time=0.11 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4291.351, Time=0.11 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.90 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.95 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4179.320, Time=0.43 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4178.059, Time=0.27 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4176.357, Time=0.37 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4174.561, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 4.083 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4177.760, Time=0.68 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.905 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4523.621, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4768.576, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4401.945, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4346.607, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4305.465, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4291.351, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.94 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=1.00 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4179.320, Time=0.33 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4178.059, Time=0.19 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4176.357, Time=0.40 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4174.561, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.934 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4177.760, Time=0.58 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.862 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4523.621, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4768.576, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4401.945, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4346.607, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4305.465, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4291.351, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.12 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.96 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4179.320, Time=0.33 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4178.059, Time=0.19 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4176.357, Time=0.32 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4174.561, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.977 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4177.760, Time=0.59 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.819 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.39 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4523.621, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4768.576, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4401.945, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4346.607, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4305.465, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4291.351, Time=0.13 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.86 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.89 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4179.320, Time=0.34 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4178.059, Time=0.19 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4176.357, Time=0.32 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4174.561, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.665 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4177.760, Time=0.57 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.795 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4523.621, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4768.576, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4401.945, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4346.607, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4305.465, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4291.351, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.87 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.87 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4179.320, Time=0.34 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4178.059, Time=0.18 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4176.357, Time=0.32 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4174.561, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.634 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4177.760, Time=0.57 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4171.304, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4172.803, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4172.782, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5000.903, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4174.828, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.787 seconds
# Fit using method:hannan_rissanen                             and cov_type:robust with mse 59.415527974304915

# %% [markdown]
# To restore a saved model from a Pickle file, simply provide the "pickled" model as an argument to the Pickle's load() function, which will handle the deserialization process. Once this is done, you can assign the deserialized model back to a model object. Subsequently, you can utilize your original model's predict() function by feeding it test data, resulting in an array of predictions being returned.

# %%
# List of trained ARIMA models
arima_models = []

# Loop through each column and fit ARIMA models
for column in COLUMNS_TO_FORECAST:
    ts_data = all_games[column]
    # get the best model from the previous step
    model = pickle.load(open(f'{MODEL_LOCATION}{column}_model.pkl', 'rb'))
    arima_models.append(model)

    final_model = model.model
    final_model_fit = model.model_fit

    # make one-day forecast
    forecast = final_model_fit.predict(n_periods=1, exog=None, return_conf_int=True)

    print(f"Forecast for ('{column}'): {forecast.iloc[0]:.2f}")
# Out:
# Forecast for ('Ball_1'): 12.13
# Forecast for ('Ball_2'): 23.24
# Forecast for ('Ball_3'): 35.25
# Forecast for ('Ball_4'): 47.16
# Forecast for ('Ball_5'): 58.57
# Forecast for ('Ball_Bonus'): 13.31

# %% [markdown]
# # let us look inside the models
#
# The summary method produces several convenient tables showing the results.

# %%
for model in arima_models:
    final_model = model.model_fit
    print(final_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_1   No. Observations:                  602
# Model:                          ARIMA   Log Likelihood               -2227.669
# Date:                Mon, 25 Sep 2023   AIC                           4459.339
# Time:                        10:29:57   BIC                           4468.139
# Sample:                             0   HQIC                          4462.764
#                                 - 602
# Covariance Type:               robust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.1279      0.399     30.390      0.000      11.346      12.910
# sigma2        95.8723      6.875     13.946      0.000      82.398     109.347
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               162.61
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.07   Skew:                             1.15
# Prob(H) (two-sided):                  0.64   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using the observed information matrix (complex-step) described in Harvey (1989).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_2   No. Observations:                  602
# Model:                          ARIMA   Log Likelihood               -2341.745
# Date:                Mon, 25 Sep 2023   AIC                           4687.489
# Time:                        10:29:57   BIC                           4696.290
# Sample:                             0   HQIC                          4690.915
#                                 - 602
# Covariance Type:               robust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.2425      0.482     48.188      0.000      22.297      24.188
# sigma2       140.0508      7.430     18.849      0.000     125.488     154.613
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.23   Jarque-Bera (JB):                20.44
# Prob(Q):                              0.27   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                             0.42
# Prob(H) (two-sided):                  0.66   Kurtosis:                         2.69
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using the observed information matrix (complex-step) described in Harvey (1989).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_3   No. Observations:                  602
# Model:                          ARIMA   Log Likelihood               -2373.041
# Date:                Mon, 25 Sep 2023   AIC                           4750.081
# Time:                        10:29:57   BIC                           4758.882
# Sample:                             0   HQIC                          4753.507
#                                 - 602
# Covariance Type:               robust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.2492      0.508     69.379      0.000      34.253      36.245
# sigma2       155.3964      7.532     20.632      0.000     140.634     170.158
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                 8.88
# Prob(Q):                              0.71   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.17   Skew:                            -0.05
# Prob(H) (two-sided):                  0.26   Kurtosis:                         2.41
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using the observed information matrix (complex-step) described in Harvey (1989).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_4   No. Observations:                  602
# Model:                          ARIMA   Log Likelihood               -2348.816
# Date:                Mon, 25 Sep 2023   AIC                           4701.632
# Time:                        10:29:57   BIC                           4710.432
# Sample:                             0   HQIC                          4705.057
#                                 - 602
# Covariance Type:               robust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         47.1595      0.488     96.632      0.000      46.203      48.116
# sigma2       143.3799      7.569     18.943      0.000     128.545     158.215
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.59   Jarque-Bera (JB):                25.11
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                            -0.47
# Prob(H) (two-sided):                  0.48   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using the observed information matrix (complex-step) described in Harvey (1989).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_5   No. Observations:                  602
# Model:                          ARIMA   Log Likelihood               -2200.340
# Date:                Mon, 25 Sep 2023   AIC                           4404.679
# Time:                        10:29:57   BIC                           4413.480
# Sample:                             0   HQIC                          4408.105
#                                 - 602
# Covariance Type:               robust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         58.5681      0.381    153.578      0.000      57.821      59.316
# sigma2        87.5510      6.704     13.060      0.000      74.412     100.690
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.40   Jarque-Bera (JB):               223.84
# Prob(Q):                              0.24   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.99   Skew:                            -1.28
# Prob(H) (two-sided):                  0.93   Kurtosis:                         4.53
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using the observed information matrix (complex-step) described in Harvey (1989).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Ball_Bonus   No. Observations:                  602
# Model:                          ARIMA   Log Likelihood               -2083.652
# Date:                Mon, 25 Sep 2023   AIC                           4171.304
# Time:                        10:29:57   BIC                           4180.105
# Sample:                             0   HQIC                          4174.730
#                                 - 602
# Covariance Type:               robust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.3073      0.314     42.358      0.000      12.692      13.923
# sigma2        59.4155      2.079     28.586      0.000      55.342      63.489
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.50   Jarque-Bera (JB):                40.16
# Prob(Q):                              0.48   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                             0.04
# Prob(H) (two-sided):                  0.99   Kurtosis:                         1.74
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using the observed information matrix (complex-step) described in Harvey (1989).

# %% [markdown]
# Load saved metadata for Ball_1 model

# %%
with open(f'{MODEL_LOCATION}{column}_model_metadata.txt', 'r') as file:
    print(file.read().rstrip())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Ball_Bonus   No. Observations:                  602
# Model:                          ARIMA   Log Likelihood               -2083.652
# Date:                Mon, 25 Sep 2023   AIC                           4171.304
# Time:                        10:26:40   BIC                           4180.105
# Sample:                             0   HQIC                          4174.730
#                                 - 602
# Covariance Type:               robust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.3073      0.314     42.358      0.000      12.692      13.923
# sigma2        59.4155      2.079     28.586      0.000      55.342      63.489
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.50   Jarque-Bera (JB):                40.16
# Prob(Q):                              0.48   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                             0.04
# Prob(H) (two-sided):                  0.99   Kurtosis:                         1.74
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using the observed information matrix (complex-step) described in Harvey (1989).
# best criteria used: BIC
