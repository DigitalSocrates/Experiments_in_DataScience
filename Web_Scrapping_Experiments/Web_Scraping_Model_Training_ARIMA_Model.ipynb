# %% [markdown]
# # Experiment in trying to predict a lottey number
#
# Note: We know that is almost impossible BUT we can try to apply some Data Sciencey stuff and see what will happen
#
# So... the plan is to use a quick model first like ARIMA and see the results and after that we will build a full scalle deep learning model!

# %%
# imports
import pandas as pd
import numpy as np
import pmdarima as pm
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from src.utils import read_all_parquet_files
from src.model import Model
from src.trainer import Trainer

# %%
# dataset filename
DATASET_LOCAL_COPY = './static/data/'

# List of columns to forecast
COLUMNS_TO_FORECAST = ['Ball_1', 'Ball_2', 'Ball_3', 'Ball_4', 'Ball_5', 'Ball_Bonus']

# Location of stored models
MODEL_LOCATION = './static/model/'

# %%
# read in lottery games data 
all_games = read_all_parquet_files(DATASET_LOCAL_COPY)

# need to convert data 
all_games['Ball_1'] = all_games['Ball_1'].astype('float64')
all_games['Ball_2'] = all_games['Ball_2'].astype('float64')
all_games['Ball_3'] = all_games['Ball_3'].astype('float64')
all_games['Ball_4'] = all_games['Ball_4'].astype('float64')
all_games['Ball_5'] = all_games['Ball_5'].astype('float64')
all_games['Ball_Bonus'] = all_games['Ball_Bonus'].astype('float64')

min_date = all_games['Date'].min()
max_date = all_games['Date'].max()

# sort by date
all_games.sort_values(by=['Date'], ascending=False, inplace=True)
# set index
all_games.set_index('Date', inplace=True)
# specify frequency IMPORTANT
all_games.index = pd.DatetimeIndex(all_games.index).to_period('3.5D')

# %% [markdown]
# ## Randomize
#
# I do not think that we care if the data is ordered or not so let just get it randomized
#
# we can also use
# ```
# from sklearn.utils import shuffle
# all_games = shuffle(all_games)
# ```

# %%
all_games = all_games.sample(frac=1).reset_index(drop=True)

# %%
# let us take a look at one of the columns
endog = all_games['Ball_1']
endog.plot(figsize=(15, 5))
# Out:
# <Axes: >

# %%
all_games.describe(include='all')
# Out:
#            Ball_1      Ball_2      Ball_3      Ball_4      Ball_5  Ball_Bonus
# count  600.000000  600.000000  600.000000  600.000000  600.000000  600.000000
# mean    12.143333   23.256667   35.250000   47.155000   58.543333   13.296667
# std      9.800998   11.853761   12.437926   11.977064    9.383222    7.713699
# min      1.000000    2.000000    3.000000    7.000000   22.000000    1.000000
# 25%      4.000000   14.750000   26.000000   39.000000   54.000000    6.000000
# 50%     10.000000   22.000000   36.000000   48.000000   61.000000   13.000000
# 75%     18.000000   31.000000   44.000000   57.000000   66.000000   20.000000
# max     52.000000   58.000000   64.000000   68.000000   69.000000   26.000000

# %% [markdown]
# ## let us add additional features

# %%
# Calculate weights based on historical frequency
weights = {}
for column in COLUMNS_TO_FORECAST:
    number_counts = all_games[column].value_counts(normalize=True).to_dict()
    total_samples = len(all_games[column])
    column_weights = {number: count / total_samples for number, count in number_counts.items()}
    weights[column] = column_weights
    #all_games[f'{column}_weight'] = column_weights

# %%
t = weights.get('Ball_1')
t.get(3)
# Out:
# 0.00010833333333333334

# %%
# use first rows for training and use last row for out-of-sample testing
X_train_all_balls, X_test_all_balls = all_games.iloc[:-1, :len(COLUMNS_TO_FORECAST)], all_games.iloc[[-1], :len(COLUMNS_TO_FORECAST)]

# %%
X_train_all_balls.describe()
# Out:
#            Ball_1      Ball_2      Ball_3      Ball_4      Ball_5  Ball_Bonus
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    12.130217   23.255426   35.245409   47.140234   58.527546   13.288815
# std      9.803917   11.863629   12.447812   11.981607    9.383086    7.717746
# min      1.000000    2.000000    3.000000    7.000000   22.000000    1.000000
# 25%      4.000000   14.500000   26.000000   39.000000   54.000000    6.000000
# 50%     10.000000   22.000000   36.000000   48.000000   61.000000   13.000000
# 75%     18.000000   31.000000   44.000000   57.000000   66.000000   20.000000
# max     52.000000   58.000000   64.000000   68.000000   69.000000   26.000000

# %%
X_test_all_balls
# Out:
#      Ball_1  Ball_2  Ball_3  Ball_4  Ball_5  Ball_Bonus
# 599    20.0    24.0    38.0    56.0    68.0        18.0

# %% [markdown]
# # Let us try to optimize our ARIMA model
#
# The expected value range for the hyperparameters p, d, and q in an ARIMA model depends on the characteristics of your time series data. These hyperparameters determine the autoregressive (AR), differencing (I), and moving average (MA) components of the model, respectively. Here are some general guidelines for choosing values within these ranges:
#
# p (AR order):
#
# The autoregressive order (p) represents the number of lagged observations included in the model. It indicates how many past time points are used to predict the current value.
# A typical range for p is 0 to 3. If the autocorrelation plot (ACF) shows significant values at lags 1, 2, or 3, you may consider these values for p.
# Use the PACF plot to help determine the initial estimate for p.
# d (I order):
#
# The differencing order (d) indicates the number of times the time series needs to be differenced to achieve stationarity. It removes trends and seasonality from the data.
# A common range for d is 0 to 2. If your data is already stationary, use d=0. If first-order differencing is required to make the data stationary, use d=1. In some cases, second-order differencing (d=2) may be necessary.
# q (MA order):
#
# The moving average order (q) represents the number of lagged forecast errors (residuals) included in the model. It captures the dependency on past forecast errors.
# A typical range for q is 0 to 3. If the autocorrelation of the residuals (ACF of residuals) shows significant values at lags 1, 2, or 3, you may consider these values for q.
# The ACF of residuals is used to determine the initial estimate for q.
# These ranges are general guidelines and can vary depending on the specific characteristics of your time series. It's often a good practice to start with smaller values and incrementally increase them while monitoring the model's performance (e.g., using cross-validation or evaluation metrics) to avoid overfitting.
#
# Keep in mind that the optimal values for p, d, and q may require experimentation, and automated tools like grid search or the auto_arima function in libraries such as pmdarima can help identify the best hyperparameters based on the data.

# %%
# instantiate model trainer 
trainer = Trainer()

models_for_each_ball = {}

# Perform a grid search to find the best ARIMA model
for column in COLUMNS_TO_FORECAST:
    ts_data = X_train_all_balls[column]

    try:
        # Use auto_arima to automatically select the best hyperparameters
        best_order, best_model = trainer.find_best_arima_model(ts_data=ts_data)

        # Fit the ARIMA model with the best hyperparameters
        arima_model, arima_model_fit = trainer.fit_arima_model(
            ts_data=ts_data,
            order=best_order
        )

        # Create an instance of the Model class
        my_model = Model(name=column,
                         model=arima_model,
                         model_fit=arima_model_fit,
                         order=best_order)
        
        # save model and model's summary for each ball
        arima_model_fit.save(f'{MODEL_LOCATION}{column}_model.pkl')
        with open(f'{MODEL_LOCATION}{column}_model_metadata.txt', 'w',encoding='UTF-8') as f:
            summary = arima_model_fit.summary().as_text()
            f.write(summary)

        models_for_each_ball[column] = my_model
    except Exception as e:
        print (f'Exception -> {e}')
        continue
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.09 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.17 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.91 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.96 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.24 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.23 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.580 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.727 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.85 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.88 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.27 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.21 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.19 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.452 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.36 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.14 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.612 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.13 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.84 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.83 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.24 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.09 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.229 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.37 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.594 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.12 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.13 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.82 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.87 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.23 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.303 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.37 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.594 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.14 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.15 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.01 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.89 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.31 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.14 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.15 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.706 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.98 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.274 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.14 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.17 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=1.27 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.26 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.30 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.20 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.17 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.13 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 4.567 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.34 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.550 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.08 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.14 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.86 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.88 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.29 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.416 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.64 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.873 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.09 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.94 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=1.02 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.34 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.23 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.21 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.13 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 4.041 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.26 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.17 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.591 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.84 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.85 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.24 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.20 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.11 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.329 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.36 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.609 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.09 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.12 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.06 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=1.59 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.31 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.22 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.19 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 4.486 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.418 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.45 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.12 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.99 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.98 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.25 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.16 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.836 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.32 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.539 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.42 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.79 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.78 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.24 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.25 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.419 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.65 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.13 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.919 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.94 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.99 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.22 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.626 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.763 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.83 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.82 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.29 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.17 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.275 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.54 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.781 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.12 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.16 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.81 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.87 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.27 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.14 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.356 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.590 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.14 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.93 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.85 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.31 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.16 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.426 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.749 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.19 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.11 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.88 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.99 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.28 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.19 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.608 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.49 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.16 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.766 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.09 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.14 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.91 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.89 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.23 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.15 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.429 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.40 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.12 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.737 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.11 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.86 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.89 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.23 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.17 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.16 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.11 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.354 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.13 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.650 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.08 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.86 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.89 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.26 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.385 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.591 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.83 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.90 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.22 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.284 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.595 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.13 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.88 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.92 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.23 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.483 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.733 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.49 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.12 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.15 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.16 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.34 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.06 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=1.38 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.33 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.15 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 4.753 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.70 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.920 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4738.261, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4853.292, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4647.295, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4600.863, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4578.220, Time=0.09 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4562.853, Time=0.14 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.89 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.85 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4444.180, Time=0.24 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4443.223, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4442.260, Time=0.14 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4440.483, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.11 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.385 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.39 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4437.660, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4438.832, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4438.789, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4992.475, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4440.882, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.607 seconds
# fitting using method:hannan_rissanen and cov_type:robust_approx with mse 95.95633234021086
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5609.788, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=5011.722, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=5328.099, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4884.434, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4825.928, Time=0.08 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4802.700, Time=0.09 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4785.755, Time=0.12 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.69 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.86 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4675.186, Time=0.31 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4673.416, Time=0.19 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4671.900, Time=0.14 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4670.020, Time=0.13 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4666.113, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4670.042, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 4.428 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4674.019, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4666.113, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5609.788, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4670.042, Time=0.14 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.418 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5609.788, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=5011.722, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=5328.099, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4884.434, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4825.928, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4802.700, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4785.755, Time=0.09 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=2.00 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=1.05 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4675.186, Time=0.18 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4673.416, Time=0.27 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4671.900, Time=0.25 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4670.020, Time=0.19 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4666.113, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4670.042, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 5.033 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4674.019, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4666.113, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4668.044, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5609.788, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4670.042, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.365 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5609.788, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=5011.722, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=5328.099, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4884.434, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4825.928, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4802.700, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4785.755, Time=0.09 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.75 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.96 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4675.186, Time=0.18 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4673.416, Time=0.21 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4671.900, Time=0.15 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4670.020, Time=0.11 sec
# ...
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.13 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.61 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.50 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.25 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.11 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.05 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.566 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.05 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.655 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.14 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.63 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.48 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.26 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.05 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.562 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.56 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.838 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.16 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.70 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.56 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.29 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.12 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.17 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.924 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.54 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.781 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.07 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.10 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.13 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.24 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.74 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.57 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.28 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.16 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.197 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.54 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.788 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.08 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.20 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.16 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.70 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.71 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.34 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.27 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.16 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.513 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.61 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.931 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.09 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.16 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.89 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.76 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.29 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.12 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.17 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.391 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.56 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.810 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.15 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.68 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.68 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.28 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.17 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.15 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 3.089 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.58 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.832 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.17 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=0.96 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=2.43 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.78 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.16 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.23 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.21 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 5.998 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.99 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.10 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.314 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4478.868, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4737.983, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4351.763, Time=0.07 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4309.823, Time=0.09 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=4273.287, Time=0.11 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=4248.058, Time=0.25 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.07 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.91 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=4158.389, Time=0.42 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=4157.568, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4156.096, Time=0.26 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4154.356, Time=0.31 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 4.505 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=4158.244, Time=0.91 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4151.027, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4152.937, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4152.942, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4974.868, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4154.933, Time=0.09 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.248 seconds
# fitting using method:hannan_rissanen and cov_type:robust_approx with mse 59.4641653730062

# %%
# List of trained ARIMA models
arima_models = []

# Loop through each column and fit ARIMA models
for column in COLUMNS_TO_FORECAST:
    ts_data = all_games[column]
    # get the best model from the previous step
    model = models_for_each_ball[column]
    arima_models.append(model)

    final_model = model.model
    final_model_fit = model.model_fit

    # Forecast the next data point
    #forecast = final_model_fit.predict(n_periods=len(ts_data),steps=1)
    # make one-day forecast
    forecast = final_model_fit.predict(n_periods=1, exog=None, return_conf_int=True)

    print(f"Forecast for ('{column}'): {forecast.iloc[0]:.2f}")
# Out:
# Forecast for ('Ball_1'): 12.13
# Forecast for ('Ball_2'): 23.26
# Forecast for ('Ball_3'): 35.25
# Forecast for ('Ball_4'): 47.14
# Forecast for ('Ball_5'): 58.53
# Forecast for ('Ball_Bonus'): 13.29

# %%
results = []
# Loop through each column and fit ARIMA models
for column in COLUMNS_TO_FORECAST:
    ts_data = all_games[column].astype(float)
    # Generate predictions from each ARIMA model
    result = 0
    for model in arima_models:
        final_model = model.model
        model_fit = model.model_fit

        # Forecast the next data point
        forecast = model_fit.predict(n_periods=1)
        #print(forecast[0])
        #print(forecast[-1])
        #forecast = final_model_fit.forecast()

        result += forecast[0]
    
    results.append(f'{column} -> {int(result/len(arima_models))} weight ({weights.get(column).get(int(result/len(arima_models)))})')

# %%
for x in results:
    print (x)
# Out:
# Ball_1 -> 31 weight (1.1111111111111112e-05)
# Ball_2 -> 31 weight (4.166666666666667e-05)
# Ball_3 -> 31 weight (4.166666666666667e-05)
# Ball_4 -> 31 weight (1.6666666666666667e-05)
# Ball_5 -> 31 weight (None)
# Ball_Bonus -> 31 weight (None)

# %% [markdown]
# # let us look inside the models
#
# The summary method produces several convenient tables showing the results.

# %%
for model in arima_models:
    final_model = model.model_fit
    print(final_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_1   No. Observations:                  599
# Model:                          ARIMA   Log Likelihood               -2216.830
# Date:                Tue, 19 Sep 2023   AIC                           4437.660
# Time:                        14:36:52   BIC                           4446.451
# Sample:                             0   HQIC                          4441.083
#                                 - 599
# Covariance Type:        robust_approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.1302      0.400     30.307      0.000      11.346      12.915
# sigma2        95.9563      6.906     13.894      0.000      82.420     109.493
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.83   Jarque-Bera (JB):               163.57
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                             1.16
# Prob(H) (two-sided):                  0.57   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using numerical (complex-step) differentiation.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_2   No. Observations:                  599
# Model:                          ARIMA   Log Likelihood               -2331.057
# Date:                Tue, 19 Sep 2023   AIC                           4666.113
# Time:                        14:36:52   BIC                           4674.904
# Sample:                             0   HQIC                          4669.536
#                                 - 599
# Covariance Type:        robust_approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.2554      0.484     48.016      0.000      22.306      24.205
# sigma2       140.5107      7.457     18.843      0.000     125.896     155.126
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                20.30
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                             0.42
# Prob(H) (two-sided):                  0.98   Kurtosis:                         2.69
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using numerical (complex-step) differentiation.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_3   No. Observations:                  599
# Model:                          ARIMA   Log Likelihood               -2359.849
# Date:                Tue, 19 Sep 2023   AIC                           4723.698
# Time:                        14:36:52   BIC                           4732.489
# Sample:                             0   HQIC                          4727.121
#                                 - 599
# Covariance Type:        robust_approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.2454      0.508     69.356      0.000      34.249      36.241
# sigma2       154.6894      7.537     20.524      0.000     139.917     169.461
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                 8.69
# Prob(Q):                              0.67   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.97   Skew:                            -0.06
# Prob(H) (two-sided):                  0.81   Kurtosis:                         2.42
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using numerical (complex-step) differentiation.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_4   No. Observations:                  599
# Model:                          ARIMA   Log Likelihood               -2336.984
# Date:                Tue, 19 Sep 2023   AIC                           4677.968
# Time:                        14:36:52   BIC                           4686.759
# Sample:                             0   HQIC                          4681.390
#                                 - 599
# Covariance Type:        robust_approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         47.1402      0.489     96.372      0.000      46.182      48.099
# sigma2       143.3192      7.597     18.866      0.000     128.430     158.208
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.03   Jarque-Bera (JB):                24.83
# Prob(Q):                              0.31   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.47
# Prob(H) (two-sided):                  0.71   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using numerical (complex-step) differentiation.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Ball_5   No. Observations:                  599
# Model:                          ARIMA   Log Likelihood               -2190.550
# Date:                Tue, 19 Sep 2023   AIC                           4385.100
# Time:                        14:36:52   BIC                           4393.891
# Sample:                             0   HQIC                          4388.522
#                                 - 599
# Covariance Type:        robust_approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         58.5275      0.383    152.789      0.000      57.777      59.278
# sigma2        87.8953      6.726     13.068      0.000      74.713     101.078
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               219.65
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                            -1.28
# Prob(H) (two-sided):                  0.21   Kurtosis:                         4.51
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using numerical (complex-step) differentiation.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Ball_Bonus   No. Observations:                  599
# Model:                          ARIMA   Log Likelihood               -2073.514
# Date:                Tue, 19 Sep 2023   AIC                           4151.027
# Time:                        14:36:52   BIC                           4159.818
# Sample:                             0   HQIC                          4154.450
#                                 - 599
# Covariance Type:        robust_approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.2888      0.315     42.177      0.000      12.671      13.906
# sigma2        59.4642      2.087     28.496      0.000      55.374      63.554
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                39.93
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.95   Skew:                             0.04
# Prob(H) (two-sided):                  0.74   Kurtosis:                         1.74
# ===================================================================================
#
# Warnings:
# [1] Quasi-maximum likelihood covariance matrix used for robustness to some misspecifications; calculated using numerical (complex-step) differentiation.
