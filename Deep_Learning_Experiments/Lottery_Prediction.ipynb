# %% [markdown]
# ## Advanced Lottery Forecasting with Deep Learning
#
# In the realm of predicting lottery outcomes, the cutting-edge technology of deep learning has emerged as a powerful tool. This revolutionary approach leverages neural networks, massive data sets, and advanced algorithms to not only enhance the accuracy of lottery predictions but also to uncover patterns and trends that were once hidden from conventional analysis.
#
# ## Harnessing the Power of Neural Networks
#
# Deep learning employs artificial neural networks, which are designed to mimic the human brain's ability to process information and make decisions. These neural networks consist of multiple layers of interconnected nodes, or "neurons," that can analyze vast amounts of historical lottery data. By doing so, they can detect intricate patterns and dependencies that may elude traditional statistical methods.
#
# ## The Importance of Big Data
#
# One of the key strengths of deep learning in lottery prediction is its capability to process immense datasets. Lottery results from years or even decades can be analyzed, providing a comprehensive view of historical trends. This extensive data is then used to train the neural network, allowing it to recognize subtle correlations and predict future outcomes with greater accuracy.
#
# ## Unveiling Hidden Patterns
#
# Deep learning algorithms excel at revealing hidden patterns in data. In the context of lottery prediction, these patterns could include:
#
# - Recurring number combinations
# - Seasonal or cyclical trends
# - Number hotspots or cold spots
# - Anomalies and irregularities in draws
#
# By uncovering these patterns, deep learning can significantly improve the accuracy of lottery predictions, making it a valuable tool for both individual players and organizations involved in lottery operations.
#
# ## Real-Time Adaptability
#
# In addition to historical analysis, deep learning can adapt to real-time data. This means that as new lottery results become available, the neural network can continuously refine its predictions. This adaptability is particularly beneficial in dynamic lottery environments where trends can change rapidly.
#
# ## Ethical Considerations
#
# While the potential of deep learning in lottery prediction is undeniably promising, ethical concerns should not be overlooked. Responsible and transparent usage of this technology is crucial to maintain fairness in lottery games and prevent any form of exploitation.
#
# ## Conclusion
#
# The world of lottery prediction has entered a new era with the integration of deep learning techniques. These advanced algorithms, capable of processing vast amounts of data and uncovering hidden patterns, have the potential to revolutionize how we approach forecasting lottery outcomes. However, it is essential to use this technology responsibly and ethically to ensure the integrity of lottery games. As deep learning continues to evolve, we can anticipate further breakthroughs in lottery prediction, ultimately benefiting both players and lottery operators alike.

# %%
# required imports
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam

# %%
import tensorflow as tf
print(tf.__version__)

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 2.13.0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15568699381224830471
# xla_global_id: -1
# ]

# %%
# declare global variables
# window - how many games we will use for prediction
WINDOW_LENGTH = 7

# %%
# load data
all_games = pd.read_csv('..\Web_Scrapping_Experiments\static\data/all_Games.csv')

# %% [markdown]
# Let us take a closer look at the data

# %%
all_games.head()
# Out:
#    Unnamed: 0        Date  Ball_1  Ball_2  Ball_3  Ball_4  Ball_5  Ball_Bonus
# 0         103  2019-01-02       8      12      42      46      56          12
# 1         102  2019-01-05       3       7      15      27      69          19
# 2         101  2019-01-09       6      19      37      49      59          22
# 3         100  2019-01-12       7      36      48      57      58          24
# 4          99  2019-01-16      14      29      31      56      61           1

# %%
all_games.describe()
# Out:
#        Unnamed: 0      Ball_1      Ball_2      Ball_3      Ball_4      Ball_5  \
# count  603.000000  603.000000  603.000000  603.000000  603.000000  603.000000
# mean   301.000000   12.114428   23.240464   35.248756   47.144279   58.535655
# std    174.215384    9.797035   11.834415   12.465813   11.979942    9.390741
# min      0.000000    1.000000    2.000000    3.000000    7.000000   22.000000
# 25%    150.500000    4.000000   14.500000   26.000000   39.000000   54.000000
# 50%    301.000000   10.000000   22.000000   36.000000   48.000000   61.000000
# 75%    451.500000   18.000000   31.000000   44.000000   57.000000   66.000000
# max    602.000000   52.000000   58.000000   64.000000   68.000000   69.000000
#
#        Ball_Bonus
# count  603.000000
# mean    13.318408
# std      7.712964
# min      1.000000
# 25%      6.000000
# 50%     13.000000
# 75%     20.000000
# max     26.000000

# %%
all_games.shape
# Out:
# (603, 8)

# %% [markdown]
# To prepare the data for analysis, we will perform data preprocessing, which includes removing three columns from our dataset:
#
# 1. **Index Column**: The index column is typically an autogenerated identifier for each row in the dataset. Since it doesn't provide any meaningful information for our analysis, we will drop this column.
#
# 2. **Date Column**: The date column contains date values, which might not be relevant to our specific analysis or could be handled differently. For our current analysis, we will remove this column as it doesn't contribute to the immediate goals.
#
# 3. **Bonus Ball Column**: The bonus ball column might contain supplementary information. However, for our analysis, it is not required, so we will also eliminate this column.
#
# By dropping these three columns, we will streamline the dataset and focus on the relevant data that is essential for our analysis, making it more efficient and concise.

# %%
all_games.drop(['Date','Ball_Bonus'], axis=1, inplace=True)
all_games.drop(columns=all_games.columns[0], axis=1,  inplace=True)
all_games.head()
# Out:
#    Ball_1  Ball_2  Ball_3  Ball_4  Ball_5
# 0       8      12      42      46      56
# 1       3       7      15      27      69
# 2       6      19      37      49      59
# 3       7      36      48      57      58
# 4      14      29      31      56      61

# %% [markdown]
# Let us rescale the data

# %%
scaler = StandardScaler().fit(all_games.values)
transformed_dataset = scaler.transform(all_games.values)
transformed_df = pd.DataFrame(data=transformed_dataset, index=all_games.index)

# %% [markdown]
# Let us declare additional variables that might be helpful

# %%
# All our games
number_of_rows = all_games.values.shape[0]
# Balls counts
number_of_features = all_games.values.shape[1]

# %%
X = np.empty([ number_of_rows - WINDOW_LENGTH, WINDOW_LENGTH, number_of_features], dtype=float)
y = np.empty([ number_of_rows - WINDOW_LENGTH, number_of_features], dtype=float)
for i in range(0, number_of_rows - WINDOW_LENGTH):
    X[i] = transformed_df.iloc[i : i + WINDOW_LENGTH, 0 : number_of_features]
    y[i] = transformed_df.iloc[i+WINDOW_LENGTH : i + WINDOW_LENGTH+1, 0 : number_of_features]

# %% [markdown]
# ## Choosing optimizer
#
# Adam: It is also another method that calculates learning rate for each parameter that is shown by its developers to work well in practice and to compare favorably against other adaptive learning algorithms. The developers also propose the default values for the Adam optimizer parameters as Beta1 – 0.9 Beta2 – 0.999 and Epsilon – 10^-8
#
# [reference:](https://deepdatascience.wordpress.com/2016/11/18/which-lstm-optimizer-to-use/)

# %%
model_1 = Sequential()
# add the input layer and the LSTM layer
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# add first drop out layer in order to reduce overfitting
model_1.add(Dropout(0.11))
# layer 2
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# drop out layer
model_1.add(Dropout(0.11))
# Layer 3
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# drop out layer
model_1.add(Dropout(0.11))
# Layer 4
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = False)))
# drop out layer
model_1.add(Dropout(0.11))
# 
model_1.add(Dense(69))
# 
model_1.add(Dense(number_of_features))

model_1.compile(optimizer=Adam(learning_rate=0.0001), loss ='mse', metrics=['accuracy'])

model_1.fit(x=X, y=y, batch_size=25, epochs=300, verbose=2)

to_predict = all_games.tail(8)
to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
prediction = all_games.tail(1)
to_predict = np.array(to_predict)
scaled_to_predict = scaler.transform(to_predict)
# Out:
# Epoch 1/300
# 24/24 - 25s - loss: 1.0035 - accuracy: 0.2248 - 25s/epoch - 1s/step
# Epoch 2/300
# 24/24 - 7s - loss: 0.9985 - accuracy: 0.2416 - 7s/epoch - 288ms/step
# Epoch 3/300
# 24/24 - 8s - loss: 0.9920 - accuracy: 0.2332 - 8s/epoch - 313ms/step
# Epoch 4/300
# 24/24 - 8s - loss: 0.9819 - accuracy: 0.2282 - 8s/epoch - 337ms/step
# Epoch 5/300
# 24/24 - 8s - loss: 0.9778 - accuracy: 0.2332 - 8s/epoch - 314ms/step
# Epoch 6/300
# 24/24 - 7s - loss: 0.9760 - accuracy: 0.2332 - 7s/epoch - 310ms/step
# Epoch 7/300
# 24/24 - 9s - loss: 0.9795 - accuracy: 0.2466 - 9s/epoch - 360ms/step
# Epoch 8/300
# 24/24 - 8s - loss: 0.9746 - accuracy: 0.2466 - 8s/epoch - 330ms/step
# Epoch 9/300
# 24/24 - 7s - loss: 0.9721 - accuracy: 0.2483 - 7s/epoch - 281ms/step
# Epoch 10/300
# 24/24 - 7s - loss: 0.9740 - accuracy: 0.2550 - 7s/epoch - 289ms/step
# Epoch 11/300
# 24/24 - 7s - loss: 0.9737 - accuracy: 0.2366 - 7s/epoch - 280ms/step
# Epoch 12/300
# 24/24 - 7s - loss: 0.9733 - accuracy: 0.2433 - 7s/epoch - 278ms/step
# Epoch 13/300
# 24/24 - 7s - loss: 0.9699 - accuracy: 0.2366 - 7s/epoch - 279ms/step
# Epoch 14/300
# 24/24 - 7s - loss: 0.9689 - accuracy: 0.2332 - 7s/epoch - 296ms/step
# Epoch 15/300
# 24/24 - 8s - loss: 0.9690 - accuracy: 0.2332 - 8s/epoch - 326ms/step
# Epoch 16/300
# 24/24 - 7s - loss: 0.9677 - accuracy: 0.2282 - 7s/epoch - 284ms/step
# Epoch 17/300
# 24/24 - 8s - loss: 0.9657 - accuracy: 0.2164 - 8s/epoch - 320ms/step
# Epoch 18/300
# 24/24 - 7s - loss: 0.9656 - accuracy: 0.2433 - 7s/epoch - 290ms/step
# Epoch 19/300
# 24/24 - 7s - loss: 0.9614 - accuracy: 0.2483 - 7s/epoch - 287ms/step
# Epoch 20/300
# 24/24 - 7s - loss: 0.9570 - accuracy: 0.2584 - 7s/epoch - 283ms/step
# Epoch 21/300
# 24/24 - 8s - loss: 0.9614 - accuracy: 0.2466 - 8s/epoch - 326ms/step
# Epoch 22/300
# 24/24 - 8s - loss: 0.9601 - accuracy: 0.2416 - 8s/epoch - 319ms/step
# Epoch 23/300
# 24/24 - 8s - loss: 0.9541 - accuracy: 0.2483 - 8s/epoch - 318ms/step
# Epoch 24/300
# 24/24 - 7s - loss: 0.9474 - accuracy: 0.2466 - 7s/epoch - 287ms/step
# Epoch 25/300
# 24/24 - 7s - loss: 0.9490 - accuracy: 0.2685 - 7s/epoch - 285ms/step
# Epoch 26/300
# 24/24 - 7s - loss: 0.9435 - accuracy: 0.2651 - 7s/epoch - 307ms/step
# Epoch 27/300
# 24/24 - 7s - loss: 0.9455 - accuracy: 0.2685 - 7s/epoch - 283ms/step
# Epoch 28/300
# 24/24 - 7s - loss: 0.9470 - accuracy: 0.2567 - 7s/epoch - 291ms/step
# Epoch 29/300
# 24/24 - 7s - loss: 0.9399 - accuracy: 0.2651 - 7s/epoch - 284ms/step
# Epoch 30/300
# 24/24 - 7s - loss: 0.9320 - accuracy: 0.2617 - 7s/epoch - 284ms/step
# Epoch 31/300
# 24/24 - 7s - loss: 0.9321 - accuracy: 0.2534 - 7s/epoch - 298ms/step
# Epoch 32/300
# 24/24 - 7s - loss: 0.9297 - accuracy: 0.2567 - 7s/epoch - 303ms/step
# Epoch 33/300
# 24/24 - 7s - loss: 0.9269 - accuracy: 0.2735 - 7s/epoch - 300ms/step
# Epoch 34/300
# 24/24 - 8s - loss: 0.9159 - accuracy: 0.2785 - 8s/epoch - 313ms/step
# Epoch 35/300
# 24/24 - 8s - loss: 0.9100 - accuracy: 0.2852 - 8s/epoch - 339ms/step
# Epoch 36/300
# 24/24 - 8s - loss: 0.9056 - accuracy: 0.2634 - 8s/epoch - 336ms/step
# Epoch 37/300
# 24/24 - 7s - loss: 0.9099 - accuracy: 0.2819 - 7s/epoch - 288ms/step
# Epoch 38/300
# 24/24 - 7s - loss: 0.9049 - accuracy: 0.2685 - 7s/epoch - 299ms/step
# Epoch 39/300
# 24/24 - 7s - loss: 0.9028 - accuracy: 0.2970 - 7s/epoch - 293ms/step
# Epoch 40/300
# 24/24 - 8s - loss: 0.8888 - accuracy: 0.2987 - 8s/epoch - 314ms/step
# Epoch 41/300
# 24/24 - 7s - loss: 0.8930 - accuracy: 0.2701 - 7s/epoch - 293ms/step
# Epoch 42/300
# 24/24 - 7s - loss: 0.8889 - accuracy: 0.2852 - 7s/epoch - 303ms/step
# Epoch 43/300
# 24/24 - 7s - loss: 0.8660 - accuracy: 0.2869 - 7s/epoch - 275ms/step
# Epoch 44/300
# 24/24 - 7s - loss: 0.8682 - accuracy: 0.2785 - 7s/epoch - 284ms/step
# Epoch 45/300
# 24/24 - 7s - loss: 0.8635 - accuracy: 0.3272 - 7s/epoch - 309ms/step
# Epoch 46/300
# 24/24 - 7s - loss: 0.8780 - accuracy: 0.2752 - 7s/epoch - 278ms/step
# Epoch 47/300
# 24/24 - 7s - loss: 0.8490 - accuracy: 0.2886 - 7s/epoch - 285ms/step
# Epoch 48/300
# 24/24 - 7s - loss: 0.8552 - accuracy: 0.3154 - 7s/epoch - 290ms/step
# Epoch 49/300
# 24/24 - 8s - loss: 0.8488 - accuracy: 0.2987 - 8s/epoch - 331ms/step
# Epoch 50/300
# 24/24 - 7s - loss: 0.8346 - accuracy: 0.2852 - 7s/epoch - 288ms/step
# Epoch 51/300
# 24/24 - 7s - loss: 0.8328 - accuracy: 0.3154 - 7s/epoch - 294ms/step
# Epoch 52/300
# 24/24 - 7s - loss: 0.8244 - accuracy: 0.2869 - 7s/epoch - 304ms/step
# Epoch 53/300
# 24/24 - 7s - loss: 0.8262 - accuracy: 0.3104 - 7s/epoch - 284ms/step
# Epoch 54/300
# 24/24 - 7s - loss: 0.8077 - accuracy: 0.3104 - 7s/epoch - 305ms/step
# Epoch 55/300
# 24/24 - 7s - loss: 0.8135 - accuracy: 0.3037 - 7s/epoch - 279ms/step
# Epoch 56/300
# 24/24 - 7s - loss: 0.7945 - accuracy: 0.3205 - 7s/epoch - 273ms/step
# Epoch 57/300
# 24/24 - 7s - loss: 0.8047 - accuracy: 0.3205 - 7s/epoch - 277ms/step
# Epoch 58/300
# 24/24 - 6s - loss: 0.7893 - accuracy: 0.3188 - 6s/epoch - 269ms/step
# Epoch 59/300
# 24/24 - 6s - loss: 0.7820 - accuracy: 0.3356 - 6s/epoch - 268ms/step
# Epoch 60/300
# 24/24 - 6s - loss: 0.7746 - accuracy: 0.3205 - 6s/epoch - 266ms/step
# Epoch 61/300
# 24/24 - 7s - loss: 0.7631 - accuracy: 0.3406 - 7s/epoch - 280ms/step
# Epoch 62/300
# 24/24 - 7s - loss: 0.7551 - accuracy: 0.3372 - 7s/epoch - 289ms/step
# Epoch 63/300
# 24/24 - 7s - loss: 0.7574 - accuracy: 0.3440 - 7s/epoch - 278ms/step
# Epoch 64/300
# 24/24 - 7s - loss: 0.7639 - accuracy: 0.3758 - 7s/epoch - 288ms/step
# Epoch 65/300
# 24/24 - 7s - loss: 0.7240 - accuracy: 0.3742 - 7s/epoch - 274ms/step
# Epoch 66/300
# 24/24 - 7s - loss: 0.7177 - accuracy: 0.3792 - 7s/epoch - 281ms/step
# Epoch 67/300
# 24/24 - 6s - loss: 0.7152 - accuracy: 0.3859 - 6s/epoch - 269ms/step
# Epoch 68/300
# 24/24 - 6s - loss: 0.6940 - accuracy: 0.3977 - 6s/epoch - 268ms/step
# Epoch 69/300
# 24/24 - 6s - loss: 0.7004 - accuracy: 0.3641 - 6s/epoch - 268ms/step
# Epoch 70/300
# 24/24 - 7s - loss: 0.6796 - accuracy: 0.3993 - 7s/epoch - 285ms/step
# Epoch 71/300
# 24/24 - 7s - loss: 0.6646 - accuracy: 0.3943 - 7s/epoch - 301ms/step
# Epoch 72/300
# 24/24 - 7s - loss: 0.6710 - accuracy: 0.3960 - 7s/epoch - 288ms/step
# Epoch 73/300
# 24/24 - 7s - loss: 0.6688 - accuracy: 0.4144 - 7s/epoch - 296ms/step
# Epoch 74/300
# 24/24 - 7s - loss: 0.6600 - accuracy: 0.4094 - 7s/epoch - 284ms/step
# Epoch 75/300
# 24/24 - 8s - loss: 0.6220 - accuracy: 0.4228 - 8s/epoch - 314ms/step
# Epoch 76/300
# 24/24 - 7s - loss: 0.6197 - accuracy: 0.4178 - 7s/epoch - 276ms/step
# Epoch 77/300
# 24/24 - 7s - loss: 0.6143 - accuracy: 0.4564 - 7s/epoch - 272ms/step
# Epoch 78/300
# 24/24 - 7s - loss: 0.5951 - accuracy: 0.4195 - 7s/epoch - 276ms/step
# Epoch 79/300
# 24/24 - 7s - loss: 0.5725 - accuracy: 0.4480 - 7s/epoch - 271ms/step
# Epoch 80/300
# 24/24 - 7s - loss: 0.5801 - accuracy: 0.4413 - 7s/epoch - 279ms/step
# Epoch 81/300
# 24/24 - 7s - loss: 0.5649 - accuracy: 0.4513 - 7s/epoch - 297ms/step
# Epoch 82/300
# 24/24 - 7s - loss: 0.5638 - accuracy: 0.4430 - 7s/epoch - 286ms/step
# Epoch 83/300
# 24/24 - 7s - loss: 0.5310 - accuracy: 0.4530 - 7s/epoch - 288ms/step
# Epoch 84/300
# 24/24 - 7s - loss: 0.5383 - accuracy: 0.4245 - 7s/epoch - 312ms/step
# Epoch 85/300
# 24/24 - 7s - loss: 0.5166 - accuracy: 0.4664 - 7s/epoch - 277ms/step
# Epoch 86/300
# 24/24 - 7s - loss: 0.5015 - accuracy: 0.4832 - 7s/epoch - 271ms/step
# Epoch 87/300
# 24/24 - 7s - loss: 0.4988 - accuracy: 0.5017 - 7s/epoch - 271ms/step
# Epoch 88/300
# 24/24 - 7s - loss: 0.4852 - accuracy: 0.4748 - 7s/epoch - 275ms/step
# Epoch 89/300
# 24/24 - 7s - loss: 0.4667 - accuracy: 0.4950 - 7s/epoch - 291ms/step
# Epoch 90/300
# 24/24 - 7s - loss: 0.4446 - accuracy: 0.5050 - 7s/epoch - 283ms/step
# Epoch 91/300
# 24/24 - 7s - loss: 0.4428 - accuracy: 0.5050 - 7s/epoch - 302ms/step
# Epoch 92/300
# 24/24 - 7s - loss: 0.4203 - accuracy: 0.5101 - 7s/epoch - 279ms/step
# Epoch 93/300
# 24/24 - 7s - loss: 0.4193 - accuracy: 0.4950 - 7s/epoch - 291ms/step
# Epoch 94/300
# 24/24 - 7s - loss: 0.3910 - accuracy: 0.5403 - 7s/epoch - 294ms/step
# Epoch 95/300
# 24/24 - 7s - loss: 0.3716 - accuracy: 0.5285 - 7s/epoch - 272ms/step
# Epoch 96/300
# 24/24 - 7s - loss: 0.3682 - accuracy: 0.5570 - 7s/epoch - 276ms/step
# Epoch 97/300
# 24/24 - 7s - loss: 0.3352 - accuracy: 0.5721 - 7s/epoch - 274ms/step
# Epoch 98/300
# 24/24 - 7s - loss: 0.3278 - accuracy: 0.5336 - 7s/epoch - 279ms/step
# Epoch 99/300
# 24/24 - 7s - loss: 0.3123 - accuracy: 0.5570 - 7s/epoch - 272ms/step
# Epoch 100/300
# 24/24 - 7s - loss: 0.2942 - accuracy: 0.5973 - 7s/epoch - 283ms/step
# Epoch 101/300
# 24/24 - 7s - loss: 0.2786 - accuracy: 0.5872 - 7s/epoch - 301ms/step
# Epoch 102/300
# 24/24 - 7s - loss: 0.2492 - accuracy: 0.5973 - 7s/epoch - 278ms/step
# Epoch 103/300
# 24/24 - 7s - loss: 0.2379 - accuracy: 0.6007 - 7s/epoch - 279ms/step
# Epoch 104/300
# 24/24 - 7s - loss: 0.2233 - accuracy: 0.6493 - 7s/epoch - 290ms/step
# Epoch 105/300
# 24/24 - 7s - loss: 0.2191 - accuracy: 0.6409 - 7s/epoch - 273ms/step
# Epoch 106/300
# 24/24 - 7s - loss: 0.1948 - accuracy: 0.6728 - 7s/epoch - 272ms/step
# Epoch 107/300
# 24/24 - 7s - loss: 0.1768 - accuracy: 0.6527 - 7s/epoch - 274ms/step
# Epoch 108/300
# 24/24 - 7s - loss: 0.1697 - accuracy: 0.6711 - 7s/epoch - 271ms/step
# Epoch 109/300
# 24/24 - 7s - loss: 0.1579 - accuracy: 0.6862 - 7s/epoch - 273ms/step
# Epoch 110/300
# 24/24 - 7s - loss: 0.1582 - accuracy: 0.6879 - 7s/epoch - 280ms/step
# Epoch 111/300
# 24/24 - 7s - loss: 0.1333 - accuracy: 0.7064 - 7s/epoch - 303ms/step
# Epoch 112/300
# 24/24 - 7s - loss: 0.1249 - accuracy: 0.7131 - 7s/epoch - 279ms/step
# Epoch 113/300
# 24/24 - 7s - loss: 0.1211 - accuracy: 0.7248 - 7s/epoch - 278ms/step
# Epoch 114/300
# 24/24 - 7s - loss: 0.1156 - accuracy: 0.7299 - 7s/epoch - 290ms/step
# Epoch 115/300
# 24/24 - 7s - loss: 0.1036 - accuracy: 0.7584 - 7s/epoch - 275ms/step
# Epoch 116/300
# 24/24 - 7s - loss: 0.0967 - accuracy: 0.7366 - 7s/epoch - 273ms/step
# Epoch 117/300
# 24/24 - 7s - loss: 0.0953 - accuracy: 0.7483 - 7s/epoch - 275ms/step
# Epoch 118/300
# 24/24 - 7s - loss: 0.0977 - accuracy: 0.7349 - 7s/epoch - 286ms/step
# Epoch 119/300
# 24/24 - 7s - loss: 0.0910 - accuracy: 0.7550 - 7s/epoch - 290ms/step
# Epoch 120/300
# 24/24 - 7s - loss: 0.0847 - accuracy: 0.7567 - 7s/epoch - 273ms/step
# Epoch 121/300
# 24/24 - 7s - loss: 0.0808 - accuracy: 0.7735 - 7s/epoch - 285ms/step
# Epoch 122/300
# 24/24 - 7s - loss: 0.0796 - accuracy: 0.7685 - 7s/epoch - 271ms/step
# Epoch 123/300
# 24/24 - 6s - loss: 0.0744 - accuracy: 0.7768 - 6s/epoch - 269ms/step
# Epoch 124/300
# 24/24 - 7s - loss: 0.0775 - accuracy: 0.7886 - 7s/epoch - 283ms/step
# Epoch 125/300
# 24/24 - 7s - loss: 0.0662 - accuracy: 0.7785 - 7s/epoch - 274ms/step
# Epoch 126/300
# 24/24 - 6s - loss: 0.0654 - accuracy: 0.8171 - 6s/epoch - 267ms/step
# Epoch 127/300
# 24/24 - 6s - loss: 0.0614 - accuracy: 0.8020 - 6s/epoch - 268ms/step
# Epoch 128/300
# 24/24 - 6s - loss: 0.0580 - accuracy: 0.8205 - 6s/epoch - 267ms/step
# Epoch 129/300
# 24/24 - 7s - loss: 0.0569 - accuracy: 0.8121 - 7s/epoch - 279ms/step
# Epoch 130/300
# 24/24 - 6s - loss: 0.0553 - accuracy: 0.8238 - 6s/epoch - 263ms/step
# Epoch 131/300
# 24/24 - 7s - loss: 0.0575 - accuracy: 0.8171 - 7s/epoch - 281ms/step
# Epoch 132/300
# 24/24 - 7s - loss: 0.0537 - accuracy: 0.8255 - 7s/epoch - 274ms/step
# Epoch 133/300
# 24/24 - 7s - loss: 0.0514 - accuracy: 0.8087 - 7s/epoch - 280ms/step
# Epoch 134/300
# 24/24 - 7s - loss: 0.0509 - accuracy: 0.8272 - 7s/epoch - 285ms/step
# Epoch 135/300
# 24/24 - 7s - loss: 0.0504 - accuracy: 0.8138 - 7s/epoch - 280ms/step
# Epoch 136/300
# 24/24 - 7s - loss: 0.0500 - accuracy: 0.8339 - 7s/epoch - 273ms/step
# Epoch 137/300
# 24/24 - 7s - loss: 0.0448 - accuracy: 0.8255 - 7s/epoch - 283ms/step
# Epoch 138/300
# 24/24 - 7s - loss: 0.0460 - accuracy: 0.8322 - 7s/epoch - 277ms/step
# Epoch 139/300
# 24/24 - 6s - loss: 0.0447 - accuracy: 0.8389 - 6s/epoch - 263ms/step
# Epoch 140/300
# 24/24 - 6s - loss: 0.0438 - accuracy: 0.8607 - 6s/epoch - 264ms/step
# Epoch 141/300
# 24/24 - 7s - loss: 0.0436 - accuracy: 0.8372 - 7s/epoch - 280ms/step
# Epoch 142/300
# 24/24 - 7s - loss: 0.0401 - accuracy: 0.8372 - 7s/epoch - 276ms/step
# Epoch 143/300
# 24/24 - 7s - loss: 0.0404 - accuracy: 0.8322 - 7s/epoch - 278ms/step
# Epoch 144/300
# 24/24 - 7s - loss: 0.0410 - accuracy: 0.8775 - 7s/epoch - 273ms/step
# Epoch 145/300
# 24/24 - 7s - loss: 0.0435 - accuracy: 0.8322 - 7s/epoch - 277ms/step
# Epoch 146/300
# 24/24 - 6s - loss: 0.0387 - accuracy: 0.8456 - 6s/epoch - 268ms/step
# Epoch 147/300
# 24/24 - 7s - loss: 0.0386 - accuracy: 0.8708 - 7s/epoch - 278ms/step
# Epoch 148/300
# 24/24 - 6s - loss: 0.0374 - accuracy: 0.8674 - 6s/epoch - 267ms/step
# Epoch 149/300
# 24/24 - 6s - loss: 0.0385 - accuracy: 0.8540 - 6s/epoch - 264ms/step
# Epoch 150/300
# 24/24 - 6s - loss: 0.0371 - accuracy: 0.8523 - 6s/epoch - 263ms/step
# Epoch 151/300
# 24/24 - 6s - loss: 0.0368 - accuracy: 0.8540 - 6s/epoch - 269ms/step
# Epoch 152/300
# 24/24 - 7s - loss: 0.0371 - accuracy: 0.8456 - 7s/epoch - 280ms/step
# Epoch 153/300
# 24/24 - 7s - loss: 0.0368 - accuracy: 0.8406 - 7s/epoch - 273ms/step
# Epoch 154/300
# 24/24 - 6s - loss: 0.0370 - accuracy: 0.8523 - 6s/epoch - 270ms/step
# Epoch 155/300
# 24/24 - 7s - loss: 0.0365 - accuracy: 0.8557 - 7s/epoch - 288ms/step
# Epoch 156/300
# 24/24 - 7s - loss: 0.0328 - accuracy: 0.8658 - 7s/epoch - 275ms/step
# Epoch 157/300
# 24/24 - 6s - loss: 0.0372 - accuracy: 0.8725 - 6s/epoch - 268ms/step
# Epoch 158/300
# 24/24 - 6s - loss: 0.0357 - accuracy: 0.8356 - 6s/epoch - 264ms/step
# Epoch 159/300
# 24/24 - 6s - loss: 0.0316 - accuracy: 0.8624 - 6s/epoch - 263ms/step
# Epoch 160/300
# 24/24 - 6s - loss: 0.0314 - accuracy: 0.8574 - 6s/epoch - 267ms/step
# Epoch 161/300
# 24/24 - 6s - loss: 0.0325 - accuracy: 0.8557 - 6s/epoch - 264ms/step
# Epoch 162/300
# 24/24 - 7s - loss: 0.0326 - accuracy: 0.8742 - 7s/epoch - 284ms/step
# Epoch 163/300
# 24/24 - 7s - loss: 0.0312 - accuracy: 0.8809 - 7s/epoch - 284ms/step
# Epoch 164/300
# 24/24 - 7s - loss: 0.0304 - accuracy: 0.8792 - 7s/epoch - 273ms/step
# Epoch 165/300
# 24/24 - 7s - loss: 0.0328 - accuracy: 0.8658 - 7s/epoch - 295ms/step
# Epoch 166/300
# 24/24 - 6s - loss: 0.0313 - accuracy: 0.8792 - 6s/epoch - 266ms/step
# Epoch 167/300
# 24/24 - 7s - loss: 0.0308 - accuracy: 0.8658 - 7s/epoch - 280ms/step
# Epoch 168/300
# 24/24 - 7s - loss: 0.0296 - accuracy: 0.8674 - 7s/epoch - 284ms/step
# Epoch 169/300
# 24/24 - 7s - loss: 0.0271 - accuracy: 0.8842 - 7s/epoch - 273ms/step
# Epoch 170/300
# 24/24 - 7s - loss: 0.0288 - accuracy: 0.8859 - 7s/epoch - 277ms/step
# Epoch 171/300
# 24/24 - 7s - loss: 0.0287 - accuracy: 0.8758 - 7s/epoch - 273ms/step
# Epoch 172/300
# 24/24 - 7s - loss: 0.0281 - accuracy: 0.8809 - 7s/epoch - 297ms/step
# Epoch 173/300
# 24/24 - 7s - loss: 0.0297 - accuracy: 0.8758 - 7s/epoch - 283ms/step
# Epoch 174/300
# 24/24 - 7s - loss: 0.0292 - accuracy: 0.8758 - 7s/epoch - 304ms/step
# Epoch 175/300
# 24/24 - 7s - loss: 0.0264 - accuracy: 0.9044 - 7s/epoch - 294ms/step
# Epoch 176/300
# 24/24 - 7s - loss: 0.0276 - accuracy: 0.8624 - 7s/epoch - 277ms/step
# Epoch 177/300
# 24/24 - 7s - loss: 0.0280 - accuracy: 0.8691 - 7s/epoch - 275ms/step
# Epoch 178/300
# 24/24 - 7s - loss: 0.0258 - accuracy: 0.8909 - 7s/epoch - 274ms/step
# Epoch 179/300
# 24/24 - 7s - loss: 0.0253 - accuracy: 0.8893 - 7s/epoch - 272ms/step
# Epoch 180/300
# 24/24 - 7s - loss: 0.0254 - accuracy: 0.8725 - 7s/epoch - 274ms/step
# Epoch 181/300
# 24/24 - 7s - loss: 0.0262 - accuracy: 0.8909 - 7s/epoch - 285ms/step
# Epoch 182/300
# 24/24 - 7s - loss: 0.0269 - accuracy: 0.8809 - 7s/epoch - 292ms/step
# Epoch 183/300
# 24/24 - 7s - loss: 0.0272 - accuracy: 0.8641 - 7s/epoch - 295ms/step
# Epoch 184/300
# 24/24 - 7s - loss: 0.0267 - accuracy: 0.8641 - 7s/epoch - 278ms/step
# Epoch 185/300
# 24/24 - 7s - loss: 0.0284 - accuracy: 0.8708 - 7s/epoch - 295ms/step
# Epoch 186/300
# 24/24 - 7s - loss: 0.0282 - accuracy: 0.8775 - 7s/epoch - 277ms/step
# Epoch 187/300
# 24/24 - 7s - loss: 0.0270 - accuracy: 0.9044 - 7s/epoch - 277ms/step
# Epoch 188/300
# 24/24 - 7s - loss: 0.0263 - accuracy: 0.8993 - 7s/epoch - 287ms/step
# Epoch 189/300
# 24/24 - 7s - loss: 0.0263 - accuracy: 0.8641 - 7s/epoch - 285ms/step
# Epoch 190/300
# 24/24 - 7s - loss: 0.0281 - accuracy: 0.8607 - 7s/epoch - 284ms/step
# Epoch 191/300
# 24/24 - 7s - loss: 0.0268 - accuracy: 0.8742 - 7s/epoch - 303ms/step
# Epoch 192/300
# 24/24 - 7s - loss: 0.0268 - accuracy: 0.8809 - 7s/epoch - 296ms/step
# Epoch 193/300
# 24/24 - 7s - loss: 0.0252 - accuracy: 0.8809 - 7s/epoch - 278ms/step
# Epoch 194/300
# 24/24 - 7s - loss: 0.0252 - accuracy: 0.8876 - 7s/epoch - 285ms/step
# Epoch 195/300
# 24/24 - 7s - loss: 0.0245 - accuracy: 0.8926 - 7s/epoch - 283ms/step
# Epoch 196/300
# 24/24 - 7s - loss: 0.0252 - accuracy: 0.8960 - 7s/epoch - 278ms/step
# Epoch 197/300
# 24/24 - 7s - loss: 0.0238 - accuracy: 0.8809 - 7s/epoch - 276ms/step
# Epoch 198/300
# 24/24 - 7s - loss: 0.0219 - accuracy: 0.8993 - 7s/epoch - 276ms/step
# Epoch 199/300
# 24/24 - 7s - loss: 0.0236 - accuracy: 0.8859 - 7s/epoch - 277ms/step
# Epoch 200/300
# 24/24 - 7s - loss: 0.0229 - accuracy: 0.8792 - 7s/epoch - 285ms/step
# Epoch 201/300
# 24/24 - 7s - loss: 0.0227 - accuracy: 0.8977 - 7s/epoch - 289ms/step
# Epoch 202/300
# 24/24 - 7s - loss: 0.0231 - accuracy: 0.8893 - 7s/epoch - 288ms/step
# Epoch 203/300
# 24/24 - 7s - loss: 0.0210 - accuracy: 0.8993 - 7s/epoch - 280ms/step
# Epoch 204/300
# 24/24 - 7s - loss: 0.0213 - accuracy: 0.9027 - 7s/epoch - 290ms/step
# Epoch 205/300
# 24/24 - 7s - loss: 0.0200 - accuracy: 0.8826 - 7s/epoch - 283ms/step
# Epoch 206/300
# 24/24 - 7s - loss: 0.0202 - accuracy: 0.8876 - 7s/epoch - 280ms/step
# Epoch 207/300
# 24/24 - 7s - loss: 0.0225 - accuracy: 0.8993 - 7s/epoch - 272ms/step
# Epoch 208/300
# 24/24 - 7s - loss: 0.0221 - accuracy: 0.8993 - 7s/epoch - 272ms/step
# Epoch 209/300
# 24/24 - 7s - loss: 0.0214 - accuracy: 0.8960 - 7s/epoch - 283ms/step
# Epoch 210/300
# 24/24 - 7s - loss: 0.0201 - accuracy: 0.8960 - 7s/epoch - 275ms/step
# Epoch 211/300
# 24/24 - 7s - loss: 0.0201 - accuracy: 0.9027 - 7s/epoch - 289ms/step
# Epoch 212/300
# 24/24 - 7s - loss: 0.0208 - accuracy: 0.8993 - 7s/epoch - 287ms/step
# Epoch 213/300
# 24/24 - 6s - loss: 0.0217 - accuracy: 0.8876 - 6s/epoch - 267ms/step
# Epoch 214/300
# 24/24 - 7s - loss: 0.0211 - accuracy: 0.9128 - 7s/epoch - 277ms/step
# Epoch 215/300
# 24/24 - 6s - loss: 0.0201 - accuracy: 0.9111 - 6s/epoch - 270ms/step
# Epoch 216/300
# 24/24 - 7s - loss: 0.0212 - accuracy: 0.8960 - 7s/epoch - 272ms/step
# Epoch 217/300
# 24/24 - 6s - loss: 0.0203 - accuracy: 0.8926 - 6s/epoch - 267ms/step
# Epoch 218/300
# 24/24 - 6s - loss: 0.0189 - accuracy: 0.8926 - 6s/epoch - 270ms/step
# Epoch 219/300
# 24/24 - 6s - loss: 0.0194 - accuracy: 0.8876 - 6s/epoch - 263ms/step
# Epoch 220/300
# 24/24 - 6s - loss: 0.0216 - accuracy: 0.8993 - 6s/epoch - 262ms/step
# Epoch 221/300
# 24/24 - 7s - loss: 0.0201 - accuracy: 0.8993 - 7s/epoch - 278ms/step
# Epoch 222/300
# 24/24 - 7s - loss: 0.0200 - accuracy: 0.8960 - 7s/epoch - 282ms/step
# Epoch 223/300
# 24/24 - 7s - loss: 0.0205 - accuracy: 0.9094 - 7s/epoch - 281ms/step
# Epoch 224/300
# 24/24 - 7s - loss: 0.0194 - accuracy: 0.9027 - 7s/epoch - 272ms/step
# Epoch 225/300
# 24/24 - 7s - loss: 0.0191 - accuracy: 0.9111 - 7s/epoch - 288ms/step
# Epoch 226/300
# 24/24 - 7s - loss: 0.0191 - accuracy: 0.9044 - 7s/epoch - 276ms/step
# Epoch 227/300
# 24/24 - 6s - loss: 0.0197 - accuracy: 0.9077 - 6s/epoch - 267ms/step
# Epoch 228/300
# 24/24 - 6s - loss: 0.0205 - accuracy: 0.9044 - 6s/epoch - 269ms/step
# Epoch 229/300
# 24/24 - 6s - loss: 0.0214 - accuracy: 0.9060 - 6s/epoch - 267ms/step
# Epoch 230/300
# 24/24 - 7s - loss: 0.0205 - accuracy: 0.8960 - 7s/epoch - 273ms/step
# Epoch 231/300
# 24/24 - 6s - loss: 0.0199 - accuracy: 0.8826 - 6s/epoch - 271ms/step
# Epoch 232/300
# 24/24 - 7s - loss: 0.0201 - accuracy: 0.8993 - 7s/epoch - 292ms/step
# Epoch 233/300
# 24/24 - 7s - loss: 0.0211 - accuracy: 0.9077 - 7s/epoch - 276ms/step
# Epoch 234/300
# 24/24 - 7s - loss: 0.0199 - accuracy: 0.9077 - 7s/epoch - 283ms/step
# Epoch 235/300
# 24/24 - 7s - loss: 0.0192 - accuracy: 0.8926 - 7s/epoch - 289ms/step
# Epoch 236/300
# 24/24 - 7s - loss: 0.0204 - accuracy: 0.8977 - 7s/epoch - 281ms/step
# Epoch 237/300
# 24/24 - 6s - loss: 0.0198 - accuracy: 0.9077 - 6s/epoch - 265ms/step
# Epoch 238/300
# 24/24 - 6s - loss: 0.0193 - accuracy: 0.9010 - 6s/epoch - 263ms/step
# Epoch 239/300
# 24/24 - 6s - loss: 0.0188 - accuracy: 0.8993 - 6s/epoch - 264ms/step
# Epoch 240/300
# 24/24 - 6s - loss: 0.0182 - accuracy: 0.9195 - 6s/epoch - 264ms/step
# Epoch 241/300
# 24/24 - 6s - loss: 0.0178 - accuracy: 0.9094 - 6s/epoch - 264ms/step
# Epoch 242/300
# 24/24 - 7s - loss: 0.0184 - accuracy: 0.9027 - 7s/epoch - 301ms/step
# Epoch 243/300
# 24/24 - 7s - loss: 0.0189 - accuracy: 0.8893 - 7s/epoch - 274ms/step
# Epoch 244/300
# 24/24 - 6s - loss: 0.0192 - accuracy: 0.8993 - 6s/epoch - 264ms/step
# Epoch 245/300
# 24/24 - 7s - loss: 0.0188 - accuracy: 0.9060 - 7s/epoch - 285ms/step
# Epoch 246/300
# 24/24 - 7s - loss: 0.0184 - accuracy: 0.8960 - 7s/epoch - 282ms/step
# Epoch 247/300
# 24/24 - 6s - loss: 0.0174 - accuracy: 0.9262 - 6s/epoch - 262ms/step
# Epoch 248/300
# 24/24 - 6s - loss: 0.0170 - accuracy: 0.9111 - 6s/epoch - 261ms/step
# Epoch 249/300
# 24/24 - 6s - loss: 0.0163 - accuracy: 0.9128 - 6s/epoch - 263ms/step
# Epoch 250/300
# 24/24 - 6s - loss: 0.0162 - accuracy: 0.9094 - 6s/epoch - 263ms/step
# Epoch 251/300
# 24/24 - 6s - loss: 0.0164 - accuracy: 0.9111 - 6s/epoch - 268ms/step
# Epoch 252/300
# 24/24 - 7s - loss: 0.0163 - accuracy: 0.9111 - 7s/epoch - 283ms/step
# Epoch 253/300
# 24/24 - 7s - loss: 0.0163 - accuracy: 0.9329 - 7s/epoch - 276ms/step
# Epoch 254/300
# 24/24 - 6s - loss: 0.0163 - accuracy: 0.9161 - 6s/epoch - 263ms/step
# Epoch 255/300
# 24/24 - 7s - loss: 0.0170 - accuracy: 0.9228 - 7s/epoch - 285ms/step
# Epoch 256/300
# 24/24 - 7s - loss: 0.0167 - accuracy: 0.9211 - 7s/epoch - 271ms/step
# Epoch 257/300
# 24/24 - 6s - loss: 0.0158 - accuracy: 0.9094 - 6s/epoch - 265ms/step
# Epoch 258/300
# 24/24 - 6s - loss: 0.0168 - accuracy: 0.9094 - 6s/epoch - 266ms/step
# Epoch 259/300
# 24/24 - 6s - loss: 0.0166 - accuracy: 0.9111 - 6s/epoch - 263ms/step
# Epoch 260/300
# 24/24 - 6s - loss: 0.0155 - accuracy: 0.8977 - 6s/epoch - 264ms/step
# Epoch 261/300
# 24/24 - 6s - loss: 0.0166 - accuracy: 0.9094 - 6s/epoch - 265ms/step
# Epoch 262/300
# 24/24 - 7s - loss: 0.0169 - accuracy: 0.9178 - 7s/epoch - 277ms/step
# Epoch 263/300
# 24/24 - 7s - loss: 0.0185 - accuracy: 0.9128 - 7s/epoch - 289ms/step
# Epoch 264/300
# 24/24 - 7s - loss: 0.0161 - accuracy: 0.9161 - 7s/epoch - 287ms/step
# Epoch 265/300
# 24/24 - 6s - loss: 0.0150 - accuracy: 0.9094 - 6s/epoch - 264ms/step
# Epoch 266/300
# 24/24 - 7s - loss: 0.0156 - accuracy: 0.9027 - 7s/epoch - 282ms/step
# Epoch 267/300
# 24/24 - 6s - loss: 0.0156 - accuracy: 0.9346 - 6s/epoch - 263ms/step
# Epoch 268/300
# 24/24 - 6s - loss: 0.0156 - accuracy: 0.9379 - 6s/epoch - 261ms/step
# Epoch 269/300
# 24/24 - 6s - loss: 0.0158 - accuracy: 0.9379 - 6s/epoch - 262ms/step
# Epoch 270/300
# 24/24 - 6s - loss: 0.0150 - accuracy: 0.9010 - 6s/epoch - 267ms/step
# Epoch 271/300
# 24/24 - 7s - loss: 0.0155 - accuracy: 0.9027 - 7s/epoch - 272ms/step
# Epoch 272/300
# 24/24 - 7s - loss: 0.0155 - accuracy: 0.9211 - 7s/epoch - 274ms/step
# Epoch 273/300
# 24/24 - 7s - loss: 0.0157 - accuracy: 0.9211 - 7s/epoch - 302ms/step
# Epoch 274/300
# 24/24 - 6s - loss: 0.0160 - accuracy: 0.9178 - 6s/epoch - 263ms/step
# Epoch 275/300
# 24/24 - 6s - loss: 0.0158 - accuracy: 0.9346 - 6s/epoch - 264ms/step
# Epoch 276/300
# 24/24 - 7s - loss: 0.0153 - accuracy: 0.9077 - 7s/epoch - 281ms/step
# Epoch 277/300
# 24/24 - 6s - loss: 0.0158 - accuracy: 0.9077 - 6s/epoch - 268ms/step
# Epoch 278/300
# 24/24 - 6s - loss: 0.0156 - accuracy: 0.9111 - 6s/epoch - 266ms/step
# Epoch 279/300
# 24/24 - 6s - loss: 0.0144 - accuracy: 0.9262 - 6s/epoch - 267ms/step
# Epoch 280/300
# 24/24 - 7s - loss: 0.0151 - accuracy: 0.9111 - 7s/epoch - 272ms/step
# Epoch 281/300
# 24/24 - 6s - loss: 0.0151 - accuracy: 0.9044 - 6s/epoch - 265ms/step
# Epoch 282/300
# 24/24 - 6s - loss: 0.0143 - accuracy: 0.9044 - 6s/epoch - 264ms/step
# Epoch 283/300
# 24/24 - 7s - loss: 0.0144 - accuracy: 0.9228 - 7s/epoch - 288ms/step
# Epoch 284/300
# 24/24 - 6s - loss: 0.0152 - accuracy: 0.9044 - 6s/epoch - 270ms/step
# Epoch 285/300
# 24/24 - 6s - loss: 0.0143 - accuracy: 0.9329 - 6s/epoch - 263ms/step
# Epoch 286/300
# 24/24 - 7s - loss: 0.0147 - accuracy: 0.9329 - 7s/epoch - 273ms/step
# Epoch 287/300
# 24/24 - 7s - loss: 0.0134 - accuracy: 0.9128 - 7s/epoch - 273ms/step
# Epoch 288/300
# 24/24 - 7s - loss: 0.0143 - accuracy: 0.9295 - 7s/epoch - 275ms/step
# Epoch 289/300
# 24/24 - 6s - loss: 0.0138 - accuracy: 0.9178 - 6s/epoch - 267ms/step
# Epoch 290/300
# 24/24 - 6s - loss: 0.0144 - accuracy: 0.9228 - 6s/epoch - 267ms/step
# Epoch 291/300
# 24/24 - 7s - loss: 0.0149 - accuracy: 0.9178 - 7s/epoch - 273ms/step
# Epoch 292/300
# 24/24 - 7s - loss: 0.0139 - accuracy: 0.9211 - 7s/epoch - 276ms/step
# Epoch 293/300
# 24/24 - 7s - loss: 0.0137 - accuracy: 0.9144 - 7s/epoch - 275ms/step
# Epoch 294/300
# 24/24 - 7s - loss: 0.0136 - accuracy: 0.9228 - 7s/epoch - 281ms/step
# Epoch 295/300
# 24/24 - 6s - loss: 0.0135 - accuracy: 0.9245 - 6s/epoch - 263ms/step
# Epoch 296/300
# 24/24 - 6s - loss: 0.0134 - accuracy: 0.9379 - 6s/epoch - 269ms/step
# Epoch 297/300
# 24/24 - 7s - loss: 0.0133 - accuracy: 0.9161 - 7s/epoch - 281ms/step
# Epoch 298/300
# 24/24 - 6s - loss: 0.0130 - accuracy: 0.9161 - 6s/epoch - 263ms/step
# Epoch 299/300
# 24/24 - 6s - loss: 0.0140 - accuracy: 0.9329 - 6s/epoch - 263ms/step
# Epoch 300/300
# 24/24 - 6s - loss: 0.0138 - accuracy: 0.9144 - 6s/epoch - 265ms/step
# C:\Users\grigo\AppData\Local\Temp\ipykernel_28884\3152075703.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)

# %%
y_pred = model_1.predict(np.array([scaled_to_predict]))
print('The predicted numbers in the last lottery game are:', scaler.inverse_transform(y_pred).astype(int)[0])
# Out:
# 1/1 [==============================] - 3s 3s/step
# The predicted numbers in the last lottery game are: [ 1 11 19 33 66]

# %%
model_2 = Sequential()
# add the input layer and the LSTM layer
model_2.add(Bidirectional(LSTM(300, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# add first drop out layer in order to reduce overfitting
model_2.add(Dropout(0.09))
# layer 2
model_2.add(Bidirectional(LSTM(300, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# drop out layer
model_2.add(Dropout(0.09))
# Layer 3
model_2.add(Bidirectional(LSTM(23000, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# Layer 4
model_2.add(Bidirectional(LSTM(300, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = False)))
# 
model_2.add(Dense(69))
# drop out layer
model_2.add(Dropout(0.09))
# 
model_2.add(Dense(number_of_features))

model_2.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

model_2.fit(x=X, y=y, batch_size=25, epochs=300, verbose=2)

to_predict = all_games.tail(7)
to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
prediction = all_games.tail(1)
to_predict = np.array(to_predict)
scaled_to_predict = scaler.transform(to_predict)
# Out:
# Epoch 1/300

# %%
y_pred = model_2.predict(np.array([scaled_to_predict]))
print('The predicted numbers in the last lottery game are:', scaler.inverse_transform(y_pred).astype(int)[0])

# %%
# merge two models
from keras.layers import Concatenate
merged = Concatenate([model_1, model_2])

# %%
final_model = Sequential()
final_model.add(merged)
final_model.add(Dense(number_of_features, activation='softmax'))
final_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# checkpoint = ModelCheckpoint('weights.h5', monitor='val_acc', save_best_only=True, verbose=2)
# early_stopping = EarlyStopping(monitor="val_loss", patience=5)

final_model.fit(x=[X, X], y=y, batch_size=7, epochs=200, verbose=1, validation_split=0.1, shuffle=True)
# callbacks=[early_stopping, checkpoint]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# i:\workspace\Experiments_in_DataScience\Experiments_in_DataScience\Deep_Learning_Experiments\Lottery_Prediction.ipynb Cell 19 line 9
#       <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a> final_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#       <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=5'>6</a> # checkpoint = ModelCheckpoint('weights.h5', monitor='val_acc', save_best_only=True, verbose=2)
#       <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=6'>7</a> # early_stopping = EarlyStopping(monitor="val_loss", patience=5)
# ----> <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=8'>9</a> final_model.fit(x=int(X.shape[0]), y=y, batch_size=7, epochs=200, verbose=1, validation_split=0.1, shuffle=True)
#      <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=9'>10</a> # callbacks=[early_stopping, checkpoint]
#
# File i:\workspace\Experiments_in_DataScience\Experiments_in_DataScience\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File i:\workspace\Experiments_in_DataScience\Experiments_in_DataScience\.venv\Lib\site-packages\keras\src\engine\data_adapter.py:1766, in train_validation_split(arrays, validation_split)
#    1764 unsplitable = [type(t) for t in flat_arrays if not _can_split(t)]
#    1765 if unsplitable:
# -> 1766     raise ValueError(
#    1767         "`validation_split` is only supported for Tensors or NumPy "
#    1768         "arrays, found following types in the input: {}".format(unsplitable)
#    1769     )
#    1771 if all(t is None for t in flat_arrays):
#    1772     return arrays, arrays
#
# ValueError: `validation_split` is only supported for Tensors or NumPy arrays, found following types in the input: [<class 'int'>]

# %%
#Model Details
from tensorflow.keras.utils import plot_model
final_model.summary()
plot_model(final_model, "output/architecture.png", show_shapes=True)

# %% [markdown]
# build RNN

# %%
import os
import torch
from tensorflow import keras
from tensorflow.keras.optimizers import Adam

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:4096"
device = torch.device('cuda:0')

# %%
model_1.compile(optimizer=Adam(learning_rate=0.0001), loss ='mse', metrics=['accuracy'])
model_1.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
final_model

# %% [markdown]
# Train the sequential model

# %%
model.fit(x=X, y=y, batch_size=100, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 6/6 - 19s - loss: 1.0037 - accuracy: 0.2192 - 19s/epoch - 3s/step
# Epoch 2/300
# 6/6 - 1s - loss: 1.0007 - accuracy: 0.2074 - 1s/epoch - 214ms/step
# Epoch 3/300
# 6/6 - 1s - loss: 0.9975 - accuracy: 0.2260 - 1s/epoch - 239ms/step
# Epoch 4/300
# 6/6 - 1s - loss: 0.9949 - accuracy: 0.2159 - 1s/epoch - 224ms/step
# Epoch 5/300
# 6/6 - 1s - loss: 0.9924 - accuracy: 0.2260 - 1s/epoch - 214ms/step
# Epoch 6/300
# 6/6 - 1s - loss: 0.9880 - accuracy: 0.2226 - 1s/epoch - 211ms/step
# Epoch 7/300
# 6/6 - 1s - loss: 0.9819 - accuracy: 0.2344 - 1s/epoch - 217ms/step
# Epoch 8/300
# 6/6 - 1s - loss: 0.9774 - accuracy: 0.2260 - 1s/epoch - 212ms/step
# Epoch 9/300
# 6/6 - 1s - loss: 0.9755 - accuracy: 0.2175 - 1s/epoch - 214ms/step
# Epoch 10/300
# 6/6 - 1s - loss: 0.9756 - accuracy: 0.2024 - 1s/epoch - 198ms/step
# Epoch 11/300
# 6/6 - 1s - loss: 0.9751 - accuracy: 0.2226 - 1s/epoch - 204ms/step
# Epoch 12/300
# 6/6 - 1s - loss: 0.9740 - accuracy: 0.2411 - 1s/epoch - 210ms/step
# Epoch 13/300
# 6/6 - 1s - loss: 0.9722 - accuracy: 0.2378 - 1s/epoch - 207ms/step
# Epoch 14/300
# 6/6 - 1s - loss: 0.9713 - accuracy: 0.2293 - 1s/epoch - 215ms/step
# Epoch 15/300
# 6/6 - 1s - loss: 0.9701 - accuracy: 0.2260 - 1s/epoch - 213ms/step
# Epoch 16/300
# 6/6 - 1s - loss: 0.9693 - accuracy: 0.2293 - 1s/epoch - 212ms/step
# Epoch 17/300
# 6/6 - 1s - loss: 0.9718 - accuracy: 0.2395 - 1s/epoch - 210ms/step
# Epoch 18/300
# 6/6 - 1s - loss: 0.9688 - accuracy: 0.2428 - 1s/epoch - 192ms/step
# Epoch 19/300
# 6/6 - 1s - loss: 0.9684 - accuracy: 0.2428 - 1s/epoch - 195ms/step
# Epoch 20/300
# 6/6 - 1s - loss: 0.9679 - accuracy: 0.2411 - 1s/epoch - 193ms/step
# Epoch 21/300
# 6/6 - 1s - loss: 0.9660 - accuracy: 0.2496 - 1s/epoch - 191ms/step
# Epoch 22/300
# 6/6 - 1s - loss: 0.9663 - accuracy: 0.2344 - 1s/epoch - 194ms/step
# Epoch 23/300
# 6/6 - 1s - loss: 0.9654 - accuracy: 0.2462 - 1s/epoch - 192ms/step
# Epoch 24/300
# 6/6 - 1s - loss: 0.9637 - accuracy: 0.2479 - 1s/epoch - 201ms/step
# Epoch 25/300
# 6/6 - 1s - loss: 0.9636 - accuracy: 0.2546 - 1s/epoch - 197ms/step
# Epoch 26/300
# 6/6 - 1s - loss: 0.9637 - accuracy: 0.2496 - 1s/epoch - 189ms/step
# Epoch 27/300
# 6/6 - 1s - loss: 0.9621 - accuracy: 0.2395 - 1s/epoch - 214ms/step
# Epoch 28/300
# 6/6 - 1s - loss: 0.9602 - accuracy: 0.2530 - 1s/epoch - 214ms/step
# Epoch 29/300
# 6/6 - 1s - loss: 0.9588 - accuracy: 0.2378 - 1s/epoch - 226ms/step
# Epoch 30/300
# 6/6 - 1s - loss: 0.9598 - accuracy: 0.2361 - 1s/epoch - 212ms/step
# Epoch 31/300
# 6/6 - 1s - loss: 0.9564 - accuracy: 0.2411 - 1s/epoch - 212ms/step
# Epoch 32/300
# 6/6 - 1s - loss: 0.9580 - accuracy: 0.2462 - 1s/epoch - 197ms/step
# Epoch 33/300
# 6/6 - 1s - loss: 0.9564 - accuracy: 0.2462 - 1s/epoch - 205ms/step
# Epoch 34/300
# 6/6 - 1s - loss: 0.9552 - accuracy: 0.2445 - 1s/epoch - 201ms/step
# Epoch 35/300
# 6/6 - 1s - loss: 0.9533 - accuracy: 0.2361 - 1s/epoch - 203ms/step
# Epoch 36/300
# 6/6 - 1s - loss: 0.9547 - accuracy: 0.2411 - 1s/epoch - 199ms/step
# Epoch 37/300
# 6/6 - 1s - loss: 0.9506 - accuracy: 0.2496 - 1s/epoch - 208ms/step
# Epoch 38/300
# 6/6 - 1s - loss: 0.9510 - accuracy: 0.2293 - 1s/epoch - 234ms/step
# Epoch 39/300
# 6/6 - 1s - loss: 0.9458 - accuracy: 0.2530 - 1s/epoch - 211ms/step
# Epoch 40/300
# 6/6 - 1s - loss: 0.9434 - accuracy: 0.2462 - 1s/epoch - 233ms/step
# Epoch 41/300
# 6/6 - 1s - loss: 0.9469 - accuracy: 0.2462 - 1s/epoch - 202ms/step
# Epoch 42/300
# 6/6 - 1s - loss: 0.9454 - accuracy: 0.2310 - 1s/epoch - 212ms/step
# Epoch 43/300
# 6/6 - 1s - loss: 0.9366 - accuracy: 0.2344 - 1s/epoch - 196ms/step
# Epoch 44/300
# 6/6 - 1s - loss: 0.9350 - accuracy: 0.2344 - 1s/epoch - 195ms/step
# Epoch 45/300
# 6/6 - 1s - loss: 0.9434 - accuracy: 0.2395 - 1s/epoch - 198ms/step
# Epoch 46/300
# 6/6 - 1s - loss: 0.9313 - accuracy: 0.2344 - 1s/epoch - 208ms/step
# Epoch 47/300
# 6/6 - 1s - loss: 0.9398 - accuracy: 0.2445 - 1s/epoch - 193ms/step
# Epoch 48/300
# 6/6 - 1s - loss: 0.9323 - accuracy: 0.2344 - 1s/epoch - 195ms/step
# Epoch 49/300
# 6/6 - 1s - loss: 0.9314 - accuracy: 0.2479 - 1s/epoch - 195ms/step
# Epoch 50/300
# 6/6 - 2s - loss: 0.9347 - accuracy: 0.2411 - 2s/epoch - 253ms/step
# Epoch 51/300
# 6/6 - 2s - loss: 0.9294 - accuracy: 0.2395 - 2s/epoch - 257ms/step
# Epoch 52/300
# 6/6 - 1s - loss: 0.9289 - accuracy: 0.2479 - 1s/epoch - 247ms/step
# Epoch 53/300
# 6/6 - 1s - loss: 0.9143 - accuracy: 0.2445 - 1s/epoch - 248ms/step
# Epoch 54/300
# 6/6 - 1s - loss: 0.9209 - accuracy: 0.2445 - 1s/epoch - 249ms/step
# Epoch 55/300
# 6/6 - 1s - loss: 0.9249 - accuracy: 0.2260 - 1s/epoch - 248ms/step
# Epoch 56/300
# 6/6 - 1s - loss: 0.9349 - accuracy: 0.2395 - 1s/epoch - 232ms/step
# Epoch 57/300
# 6/6 - 2s - loss: 0.9240 - accuracy: 0.2344 - 2s/epoch - 264ms/step
# Epoch 58/300
# 6/6 - 2s - loss: 0.9190 - accuracy: 0.2378 - 2s/epoch - 256ms/step
# Epoch 59/300
# 6/6 - 1s - loss: 0.9200 - accuracy: 0.2563 - 1s/epoch - 237ms/step
# Epoch 60/300
# 6/6 - 1s - loss: 0.9223 - accuracy: 0.2462 - 1s/epoch - 234ms/step
# Epoch 61/300
# 6/6 - 1s - loss: 0.8995 - accuracy: 0.2479 - 1s/epoch - 218ms/step
# Epoch 62/300
# 6/6 - 1s - loss: 0.9139 - accuracy: 0.2226 - 1s/epoch - 214ms/step
# Epoch 63/300
# 6/6 - 1s - loss: 0.9033 - accuracy: 0.2462 - 1s/epoch - 225ms/step
# Epoch 64/300
# 6/6 - 1s - loss: 0.8995 - accuracy: 0.2546 - 1s/epoch - 229ms/step
# Epoch 65/300
# 6/6 - 1s - loss: 0.8992 - accuracy: 0.2428 - 1s/epoch - 224ms/step
# Epoch 66/300
# 6/6 - 1s - loss: 0.8981 - accuracy: 0.2378 - 1s/epoch - 212ms/step
# Epoch 67/300
# 6/6 - 1s - loss: 0.8900 - accuracy: 0.2614 - 1s/epoch - 214ms/step
# Epoch 68/300
# 6/6 - 1s - loss: 0.8896 - accuracy: 0.2563 - 1s/epoch - 214ms/step
# Epoch 69/300
# 6/6 - 1s - loss: 0.8876 - accuracy: 0.2496 - 1s/epoch - 224ms/step
# Epoch 70/300
# 6/6 - 1s - loss: 0.8856 - accuracy: 0.2479 - 1s/epoch - 206ms/step
# Epoch 71/300
# 6/6 - 1s - loss: 0.8953 - accuracy: 0.2395 - 1s/epoch - 243ms/step
# Epoch 72/300
# 6/6 - 1s - loss: 0.8936 - accuracy: 0.2293 - 1s/epoch - 213ms/step
# Epoch 73/300
# 6/6 - 1s - loss: 0.8831 - accuracy: 0.2563 - 1s/epoch - 203ms/step
# Epoch 74/300
# 6/6 - 1s - loss: 0.8801 - accuracy: 0.2715 - 1s/epoch - 210ms/step
# Epoch 75/300
# 6/6 - 1s - loss: 0.8760 - accuracy: 0.2530 - 1s/epoch - 200ms/step
# Epoch 76/300
# 6/6 - 1s - loss: 0.8804 - accuracy: 0.2411 - 1s/epoch - 197ms/step
# Epoch 77/300
# 6/6 - 1s - loss: 0.8700 - accuracy: 0.2445 - 1s/epoch - 218ms/step
# Epoch 78/300
# 6/6 - 1s - loss: 0.8783 - accuracy: 0.2580 - 1s/epoch - 232ms/step
# Epoch 79/300
# 6/6 - 2s - loss: 0.8740 - accuracy: 0.2597 - 2s/epoch - 261ms/step
# Epoch 80/300
# 6/6 - 2s - loss: 0.8669 - accuracy: 0.2546 - 2s/epoch - 314ms/step
# Epoch 81/300
# 6/6 - 2s - loss: 0.8674 - accuracy: 0.2546 - 2s/epoch - 267ms/step
# Epoch 82/300
# 6/6 - 2s - loss: 0.8671 - accuracy: 0.2445 - 2s/epoch - 254ms/step
# Epoch 83/300
# 6/6 - 2s - loss: 0.8699 - accuracy: 0.2749 - 2s/epoch - 278ms/step
# Epoch 84/300
# 6/6 - 1s - loss: 0.8711 - accuracy: 0.2546 - 1s/epoch - 214ms/step
# Epoch 85/300
# 6/6 - 1s - loss: 0.8590 - accuracy: 0.2698 - 1s/epoch - 210ms/step
# Epoch 86/300
# 6/6 - 1s - loss: 0.8610 - accuracy: 0.2631 - 1s/epoch - 200ms/step
# Epoch 87/300
# 6/6 - 1s - loss: 0.8650 - accuracy: 0.2563 - 1s/epoch - 227ms/step
# Epoch 88/300
# 6/6 - 1s - loss: 0.8588 - accuracy: 0.2597 - 1s/epoch - 191ms/step
# Epoch 89/300
# 6/6 - 1s - loss: 0.8628 - accuracy: 0.2648 - 1s/epoch - 192ms/step
# Epoch 90/300
# 6/6 - 1s - loss: 0.8542 - accuracy: 0.2833 - 1s/epoch - 207ms/step
# Epoch 91/300
# 6/6 - 1s - loss: 0.8536 - accuracy: 0.2597 - 1s/epoch - 227ms/step
# Epoch 92/300
# 6/6 - 1s - loss: 0.8530 - accuracy: 0.2698 - 1s/epoch - 209ms/step
# Epoch 93/300
# 6/6 - 1s - loss: 0.8577 - accuracy: 0.2580 - 1s/epoch - 211ms/step
# Epoch 94/300
# 6/6 - 1s - loss: 0.8518 - accuracy: 0.2698 - 1s/epoch - 242ms/step
# Epoch 95/300
# 6/6 - 2s - loss: 0.8443 - accuracy: 0.2782 - 2s/epoch - 267ms/step
# Epoch 96/300
# 6/6 - 1s - loss: 0.8446 - accuracy: 0.2715 - 1s/epoch - 231ms/step
# Epoch 97/300
# 6/6 - 1s - loss: 0.8483 - accuracy: 0.2867 - 1s/epoch - 229ms/step
# Epoch 98/300
# 6/6 - 1s - loss: 0.8612 - accuracy: 0.2597 - 1s/epoch - 224ms/step
# Epoch 99/300
# 6/6 - 1s - loss: 0.8533 - accuracy: 0.2732 - 1s/epoch - 215ms/step
# Epoch 100/300
# 6/6 - 1s - loss: 0.8430 - accuracy: 0.2681 - 1s/epoch - 217ms/step
# Epoch 101/300
# 6/6 - 1s - loss: 0.8449 - accuracy: 0.2732 - 1s/epoch - 233ms/step
# Epoch 102/300
# 6/6 - 1s - loss: 0.8402 - accuracy: 0.2850 - 1s/epoch - 226ms/step
# Epoch 103/300
# 6/6 - 1s - loss: 0.8468 - accuracy: 0.2782 - 1s/epoch - 225ms/step
# Epoch 104/300
# 6/6 - 1s - loss: 0.8400 - accuracy: 0.2766 - 1s/epoch - 208ms/step
# Epoch 105/300
# 6/6 - 1s - loss: 0.8342 - accuracy: 0.2901 - 1s/epoch - 203ms/step
# Epoch 106/300
# 6/6 - 1s - loss: 0.8359 - accuracy: 0.2766 - 1s/epoch - 204ms/step
# Epoch 107/300
# 6/6 - 1s - loss: 0.8472 - accuracy: 0.2698 - 1s/epoch - 201ms/step
# Epoch 108/300
# 6/6 - 1s - loss: 0.8511 - accuracy: 0.2799 - 1s/epoch - 199ms/step
# Epoch 109/300
# 6/6 - 1s - loss: 0.8446 - accuracy: 0.2917 - 1s/epoch - 197ms/step
# Epoch 110/300
# 6/6 - 1s - loss: 0.8278 - accuracy: 0.3002 - 1s/epoch - 193ms/step
# Epoch 111/300
# 6/6 - 1s - loss: 0.8288 - accuracy: 0.2732 - 1s/epoch - 196ms/step
# Epoch 112/300
# 6/6 - 1s - loss: 0.8191 - accuracy: 0.2766 - 1s/epoch - 194ms/step
# Epoch 113/300
# 6/6 - 1s - loss: 0.8235 - accuracy: 0.2850 - 1s/epoch - 191ms/step
# Epoch 114/300
# 6/6 - 1s - loss: 0.8187 - accuracy: 0.2766 - 1s/epoch - 200ms/step
# Epoch 115/300
# 6/6 - 1s - loss: 0.8281 - accuracy: 0.2917 - 1s/epoch - 198ms/step
# Epoch 116/300
# 6/6 - 1s - loss: 0.8171 - accuracy: 0.2681 - 1s/epoch - 213ms/step
# Epoch 117/300
# 6/6 - 1s - loss: 0.8095 - accuracy: 0.2934 - 1s/epoch - 231ms/step
# Epoch 118/300
# 6/6 - 1s - loss: 0.8119 - accuracy: 0.2917 - 1s/epoch - 236ms/step
# Epoch 119/300
# 6/6 - 1s - loss: 0.8109 - accuracy: 0.3103 - 1s/epoch - 211ms/step
# Epoch 120/300
# 6/6 - 1s - loss: 0.8113 - accuracy: 0.2867 - 1s/epoch - 216ms/step
# Epoch 121/300
# 6/6 - 1s - loss: 0.8065 - accuracy: 0.2985 - 1s/epoch - 200ms/step
# Epoch 122/300
# 6/6 - 1s - loss: 0.8037 - accuracy: 0.3103 - 1s/epoch - 201ms/step
# Epoch 123/300
# 6/6 - 1s - loss: 0.8012 - accuracy: 0.2951 - 1s/epoch - 213ms/step
# Epoch 124/300
# 6/6 - 1s - loss: 0.7969 - accuracy: 0.3019 - 1s/epoch - 201ms/step
# Epoch 125/300
# 6/6 - 1s - loss: 0.7948 - accuracy: 0.2934 - 1s/epoch - 194ms/step
# Epoch 126/300
# 6/6 - 1s - loss: 0.7916 - accuracy: 0.2917 - 1s/epoch - 207ms/step
# Epoch 127/300
# 6/6 - 1s - loss: 0.7953 - accuracy: 0.3052 - 1s/epoch - 194ms/step
# Epoch 128/300
# 6/6 - 1s - loss: 0.7872 - accuracy: 0.2951 - 1s/epoch - 197ms/step
# Epoch 129/300
# 6/6 - 1s - loss: 0.7887 - accuracy: 0.2934 - 1s/epoch - 206ms/step
# Epoch 130/300
# 6/6 - 1s - loss: 0.7851 - accuracy: 0.2732 - 1s/epoch - 194ms/step
# Epoch 131/300
# 6/6 - 1s - loss: 0.7823 - accuracy: 0.2917 - 1s/epoch - 211ms/step
# Epoch 132/300
# 6/6 - 1s - loss: 0.7747 - accuracy: 0.3035 - 1s/epoch - 199ms/step
# Epoch 133/300
# 6/6 - 1s - loss: 0.7791 - accuracy: 0.3170 - 1s/epoch - 212ms/step
# Epoch 134/300
# 6/6 - 1s - loss: 0.7876 - accuracy: 0.3103 - 1s/epoch - 206ms/step
# Epoch 135/300
# 6/6 - 1s - loss: 0.7973 - accuracy: 0.3255 - 1s/epoch - 212ms/step
# Epoch 136/300
# 6/6 - 1s - loss: 0.8068 - accuracy: 0.2968 - 1s/epoch - 221ms/step
# Epoch 137/300
# 6/6 - 2s - loss: 0.8070 - accuracy: 0.3069 - 2s/epoch - 271ms/step
# Epoch 138/300
# 6/6 - 1s - loss: 0.7822 - accuracy: 0.3305 - 1s/epoch - 237ms/step
# Epoch 139/300
# 6/6 - 1s - loss: 0.7799 - accuracy: 0.3103 - 1s/epoch - 225ms/step
# Epoch 140/300
# 6/6 - 1s - loss: 0.7729 - accuracy: 0.3221 - 1s/epoch - 221ms/step
# Epoch 141/300
# 6/6 - 1s - loss: 0.7623 - accuracy: 0.3137 - 1s/epoch - 202ms/step
# Epoch 142/300
# 6/6 - 1s - loss: 0.7570 - accuracy: 0.3238 - 1s/epoch - 195ms/step
# Epoch 143/300
# 6/6 - 1s - loss: 0.7554 - accuracy: 0.3120 - 1s/epoch - 194ms/step
# Epoch 144/300
# 6/6 - 1s - loss: 0.7599 - accuracy: 0.3170 - 1s/epoch - 199ms/step
# Epoch 145/300
# 6/6 - 1s - loss: 0.7699 - accuracy: 0.3069 - 1s/epoch - 207ms/step
# Epoch 146/300
# 6/6 - 1s - loss: 0.7695 - accuracy: 0.3153 - 1s/epoch - 241ms/step
# Epoch 147/300
# 6/6 - 2s - loss: 0.7744 - accuracy: 0.3170 - 2s/epoch - 255ms/step
# Epoch 148/300
# 6/6 - 1s - loss: 0.7639 - accuracy: 0.3255 - 1s/epoch - 234ms/step
# Epoch 149/300
# 6/6 - 1s - loss: 0.7595 - accuracy: 0.3221 - 1s/epoch - 204ms/step
# Epoch 150/300
# 6/6 - 1s - loss: 0.7475 - accuracy: 0.3356 - 1s/epoch - 201ms/step
# Epoch 151/300
# 6/6 - 1s - loss: 0.7448 - accuracy: 0.3272 - 1s/epoch - 205ms/step
# Epoch 152/300
# 6/6 - 1s - loss: 0.7477 - accuracy: 0.3272 - 1s/epoch - 196ms/step
# Epoch 153/300
# 6/6 - 1s - loss: 0.7506 - accuracy: 0.3221 - 1s/epoch - 244ms/step
# Epoch 154/300
# 6/6 - 1s - loss: 0.7464 - accuracy: 0.3170 - 1s/epoch - 238ms/step
# Epoch 155/300
# 6/6 - 1s - loss: 0.7378 - accuracy: 0.3221 - 1s/epoch - 247ms/step
# Epoch 156/300
# 6/6 - 1s - loss: 0.7388 - accuracy: 0.3170 - 1s/epoch - 237ms/step
# Epoch 157/300
# 6/6 - 1s - loss: 0.7361 - accuracy: 0.3187 - 1s/epoch - 220ms/step
# Epoch 158/300
# 6/6 - 1s - loss: 0.7336 - accuracy: 0.3221 - 1s/epoch - 236ms/step
# Epoch 159/300
# 6/6 - 1s - loss: 0.7300 - accuracy: 0.3440 - 1s/epoch - 225ms/step
# Epoch 160/300
# 6/6 - 1s - loss: 0.7295 - accuracy: 0.3626 - 1s/epoch - 212ms/step
# Epoch 161/300
# 6/6 - 1s - loss: 0.7388 - accuracy: 0.3221 - 1s/epoch - 198ms/step
# Epoch 162/300
# 6/6 - 1s - loss: 0.7400 - accuracy: 0.3305 - 1s/epoch - 204ms/step
# Epoch 163/300
# 6/6 - 1s - loss: 0.7278 - accuracy: 0.3356 - 1s/epoch - 201ms/step
# Epoch 164/300
# 6/6 - 1s - loss: 0.7236 - accuracy: 0.3423 - 1s/epoch - 203ms/step
# Epoch 165/300
# 6/6 - 1s - loss: 0.7243 - accuracy: 0.3339 - 1s/epoch - 212ms/step
# Epoch 166/300
# 6/6 - 1s - loss: 0.7272 - accuracy: 0.3423 - 1s/epoch - 207ms/step
# Epoch 167/300
# 6/6 - 1s - loss: 0.7160 - accuracy: 0.3221 - 1s/epoch - 213ms/step
# Epoch 168/300
# 6/6 - 1s - loss: 0.7108 - accuracy: 0.3373 - 1s/epoch - 199ms/step
# Epoch 169/300
# 6/6 - 1s - loss: 0.7161 - accuracy: 0.3440 - 1s/epoch - 236ms/step
# Epoch 170/300
# 6/6 - 1s - loss: 0.7091 - accuracy: 0.3440 - 1s/epoch - 223ms/step
# Epoch 171/300
# 6/6 - 2s - loss: 0.7030 - accuracy: 0.3373 - 2s/epoch - 250ms/step
# Epoch 172/300
# 6/6 - 1s - loss: 0.7142 - accuracy: 0.3406 - 1s/epoch - 240ms/step
# Epoch 173/300
# 6/6 - 1s - loss: 0.7064 - accuracy: 0.3440 - 1s/epoch - 201ms/step
# Epoch 174/300
# 6/6 - 1s - loss: 0.7146 - accuracy: 0.3440 - 1s/epoch - 236ms/step
# Epoch 175/300
# 6/6 - 1s - loss: 0.6970 - accuracy: 0.3305 - 1s/epoch - 216ms/step
# Epoch 176/300
# 6/6 - 1s - loss: 0.6906 - accuracy: 0.3524 - 1s/epoch - 219ms/step
# Epoch 177/300
# 6/6 - 1s - loss: 0.6960 - accuracy: 0.3356 - 1s/epoch - 206ms/step
# Epoch 178/300
# 6/6 - 1s - loss: 0.6961 - accuracy: 0.3474 - 1s/epoch - 218ms/step
# Epoch 179/300
# 6/6 - 1s - loss: 0.6914 - accuracy: 0.3491 - 1s/epoch - 219ms/step
# Epoch 180/300
# 6/6 - 1s - loss: 0.6908 - accuracy: 0.3406 - 1s/epoch - 215ms/step
# Epoch 181/300
# 6/6 - 1s - loss: 0.6947 - accuracy: 0.3356 - 1s/epoch - 208ms/step
# Epoch 182/300
# 6/6 - 1s - loss: 0.6848 - accuracy: 0.3339 - 1s/epoch - 206ms/step
# Epoch 183/300
# 6/6 - 1s - loss: 0.6890 - accuracy: 0.3575 - 1s/epoch - 220ms/step
# Epoch 184/300
# 6/6 - 1s - loss: 0.6919 - accuracy: 0.3609 - 1s/epoch - 236ms/step
# Epoch 185/300
# 6/6 - 1s - loss: 0.6844 - accuracy: 0.3423 - 1s/epoch - 210ms/step
# Epoch 186/300
# 6/6 - 1s - loss: 0.6848 - accuracy: 0.3541 - 1s/epoch - 212ms/step
# Epoch 187/300
# 6/6 - 1s - loss: 0.6768 - accuracy: 0.3305 - 1s/epoch - 195ms/step
# Epoch 188/300
# 6/6 - 1s - loss: 0.6690 - accuracy: 0.3491 - 1s/epoch - 198ms/step
# Epoch 189/300
# 6/6 - 1s - loss: 0.6600 - accuracy: 0.3305 - 1s/epoch - 198ms/step
# Epoch 190/300
# 6/6 - 1s - loss: 0.6640 - accuracy: 0.3440 - 1s/epoch - 201ms/step
# Epoch 191/300
# 6/6 - 1s - loss: 0.6678 - accuracy: 0.3474 - 1s/epoch - 204ms/step
# Epoch 192/300
# 6/6 - 1s - loss: 0.6625 - accuracy: 0.3693 - 1s/epoch - 209ms/step
# Epoch 193/300
# 6/6 - 1s - loss: 0.6642 - accuracy: 0.3592 - 1s/epoch - 198ms/step
# Epoch 194/300
# 6/6 - 1s - loss: 0.6647 - accuracy: 0.3558 - 1s/epoch - 197ms/step
# Epoch 195/300
# 6/6 - 1s - loss: 0.6561 - accuracy: 0.3794 - 1s/epoch - 200ms/step
# Epoch 196/300
# 6/6 - 1s - loss: 0.6521 - accuracy: 0.3761 - 1s/epoch - 200ms/step
# Epoch 197/300
# 6/6 - 1s - loss: 0.6483 - accuracy: 0.3659 - 1s/epoch - 206ms/step
# Epoch 198/300
# 6/6 - 1s - loss: 0.6360 - accuracy: 0.3524 - 1s/epoch - 199ms/step
# Epoch 199/300
# 6/6 - 1s - loss: 0.6445 - accuracy: 0.3524 - 1s/epoch - 194ms/step
# Epoch 200/300
# 6/6 - 1s - loss: 0.6406 - accuracy: 0.3592 - 1s/epoch - 192ms/step
# Epoch 201/300
# 6/6 - 1s - loss: 0.6557 - accuracy: 0.3575 - 1s/epoch - 200ms/step
# Epoch 202/300
# 6/6 - 1s - loss: 0.6327 - accuracy: 0.3676 - 1s/epoch - 193ms/step
# Epoch 203/300
# 6/6 - 1s - loss: 0.6291 - accuracy: 0.3626 - 1s/epoch - 210ms/step
# Epoch 204/300
# 6/6 - 2s - loss: 0.6269 - accuracy: 0.3828 - 2s/epoch - 274ms/step
# Epoch 205/300
# 6/6 - 1s - loss: 0.6255 - accuracy: 0.3474 - 1s/epoch - 243ms/step
# Epoch 206/300
# 6/6 - 2s - loss: 0.6249 - accuracy: 0.3811 - 2s/epoch - 277ms/step
# Epoch 207/300
# 6/6 - 2s - loss: 0.6280 - accuracy: 0.3777 - 2s/epoch - 254ms/step
# Epoch 208/300
# 6/6 - 1s - loss: 0.6196 - accuracy: 0.3609 - 1s/epoch - 248ms/step
# Epoch 209/300
# 6/6 - 2s - loss: 0.6192 - accuracy: 0.3912 - 2s/epoch - 255ms/step
# Epoch 210/300
# 6/6 - 1s - loss: 0.6185 - accuracy: 0.3811 - 1s/epoch - 226ms/step
# Epoch 211/300
# 6/6 - 2s - loss: 0.6077 - accuracy: 0.3626 - 2s/epoch - 262ms/step
# Epoch 212/300
# 6/6 - 1s - loss: 0.6043 - accuracy: 0.3794 - 1s/epoch - 229ms/step
# Epoch 213/300
# 6/6 - 2s - loss: 0.6151 - accuracy: 0.3710 - 2s/epoch - 251ms/step
# Epoch 214/300
# 6/6 - 1s - loss: 0.6162 - accuracy: 0.3997 - 1s/epoch - 227ms/step
# Epoch 215/300
# 6/6 - 1s - loss: 0.6014 - accuracy: 0.4047 - 1s/epoch - 198ms/step
# Epoch 216/300
# 6/6 - 1s - loss: 0.6010 - accuracy: 0.3895 - 1s/epoch - 215ms/step
# Epoch 217/300
# 6/6 - 1s - loss: 0.5968 - accuracy: 0.3946 - 1s/epoch - 231ms/step
# Epoch 218/300
# 6/6 - 1s - loss: 0.6005 - accuracy: 0.3929 - 1s/epoch - 218ms/step
# Epoch 219/300
# 6/6 - 2s - loss: 0.5969 - accuracy: 0.3912 - 2s/epoch - 250ms/step
# Epoch 220/300
# 6/6 - 1s - loss: 0.5943 - accuracy: 0.3862 - 1s/epoch - 240ms/step
# Epoch 221/300
# 6/6 - 1s - loss: 0.5869 - accuracy: 0.4081 - 1s/epoch - 223ms/step
# Epoch 222/300
# 6/6 - 1s - loss: 0.5858 - accuracy: 0.3862 - 1s/epoch - 225ms/step
# Epoch 223/300
# 6/6 - 1s - loss: 0.5900 - accuracy: 0.3895 - 1s/epoch - 218ms/step
# Epoch 224/300
# 6/6 - 1s - loss: 0.5798 - accuracy: 0.3862 - 1s/epoch - 225ms/step
# Epoch 225/300
# 6/6 - 1s - loss: 0.5826 - accuracy: 0.4064 - 1s/epoch - 205ms/step
# Epoch 226/300
# 6/6 - 1s - loss: 0.5791 - accuracy: 0.3946 - 1s/epoch - 213ms/step
# Epoch 227/300
# 6/6 - 1s - loss: 0.5843 - accuracy: 0.3929 - 1s/epoch - 206ms/step
# Epoch 228/300
# 6/6 - 1s - loss: 0.5701 - accuracy: 0.3946 - 1s/epoch - 211ms/step
# Epoch 229/300
# 6/6 - 1s - loss: 0.5750 - accuracy: 0.4266 - 1s/epoch - 238ms/step
# Epoch 230/300
# 6/6 - 1s - loss: 0.5742 - accuracy: 0.4047 - 1s/epoch - 234ms/step
# Epoch 231/300
# 6/6 - 1s - loss: 0.5719 - accuracy: 0.3980 - 1s/epoch - 202ms/step
# Epoch 232/300
# 6/6 - 1s - loss: 0.5749 - accuracy: 0.3997 - 1s/epoch - 201ms/step
# Epoch 233/300
# 6/6 - 1s - loss: 0.5691 - accuracy: 0.4165 - 1s/epoch - 197ms/step
# Epoch 234/300
# 6/6 - 1s - loss: 0.5731 - accuracy: 0.4064 - 1s/epoch - 216ms/step
# Epoch 235/300
# 6/6 - 1s - loss: 0.5641 - accuracy: 0.4199 - 1s/epoch - 231ms/step
# Epoch 236/300
# 6/6 - 1s - loss: 0.5648 - accuracy: 0.4182 - 1s/epoch - 209ms/step
# Epoch 237/300
# 6/6 - 1s - loss: 0.5674 - accuracy: 0.4115 - 1s/epoch - 197ms/step
# Epoch 238/300
# 6/6 - 1s - loss: 0.5501 - accuracy: 0.4148 - 1s/epoch - 204ms/step
# Epoch 239/300
# 6/6 - 1s - loss: 0.5550 - accuracy: 0.4300 - 1s/epoch - 198ms/step
# Epoch 240/300
# 6/6 - 1s - loss: 0.5465 - accuracy: 0.4132 - 1s/epoch - 192ms/step
# Epoch 241/300
# 6/6 - 1s - loss: 0.5518 - accuracy: 0.4148 - 1s/epoch - 189ms/step
# Epoch 242/300
# 6/6 - 1s - loss: 0.5513 - accuracy: 0.4233 - 1s/epoch - 200ms/step
# Epoch 243/300
# 6/6 - 1s - loss: 0.5628 - accuracy: 0.4081 - 1s/epoch - 242ms/step
# Epoch 244/300
# 6/6 - 1s - loss: 0.5499 - accuracy: 0.4199 - 1s/epoch - 220ms/step
# Epoch 245/300
# 6/6 - 1s - loss: 0.5405 - accuracy: 0.4418 - 1s/epoch - 230ms/step
# Epoch 246/300
# 6/6 - 1s - loss: 0.5464 - accuracy: 0.4216 - 1s/epoch - 237ms/step
# Epoch 247/300
# 6/6 - 2s - loss: 0.5303 - accuracy: 0.4334 - 2s/epoch - 252ms/step
# Epoch 248/300
# 6/6 - 2s - loss: 0.5447 - accuracy: 0.4401 - 2s/epoch - 253ms/step
# Epoch 249/300
# 6/6 - 1s - loss: 0.5342 - accuracy: 0.4418 - 1s/epoch - 233ms/step
# Epoch 250/300
# 6/6 - 2s - loss: 0.5305 - accuracy: 0.4604 - 2s/epoch - 250ms/step
# Epoch 251/300
# 6/6 - 1s - loss: 0.5282 - accuracy: 0.4368 - 1s/epoch - 248ms/step
# Epoch 252/300
# 6/6 - 1s - loss: 0.5338 - accuracy: 0.4047 - 1s/epoch - 217ms/step
# Epoch 253/300
# 6/6 - 2s - loss: 0.5264 - accuracy: 0.4452 - 2s/epoch - 271ms/step
# Epoch 254/300
# 6/6 - 1s - loss: 0.5213 - accuracy: 0.4486 - 1s/epoch - 244ms/step
# Epoch 255/300
# 6/6 - 2s - loss: 0.5181 - accuracy: 0.4519 - 2s/epoch - 256ms/step
# Epoch 256/300
# 6/6 - 2s - loss: 0.5065 - accuracy: 0.4519 - 2s/epoch - 319ms/step
# Epoch 257/300
# 6/6 - 1s - loss: 0.5144 - accuracy: 0.4469 - 1s/epoch - 247ms/step
# Epoch 258/300
# 6/6 - 1s - loss: 0.5085 - accuracy: 0.4469 - 1s/epoch - 231ms/step
# Epoch 259/300
# 6/6 - 2s - loss: 0.5056 - accuracy: 0.4486 - 2s/epoch - 280ms/step
# Epoch 260/300
# 6/6 - 1s - loss: 0.5050 - accuracy: 0.4654 - 1s/epoch - 224ms/step
# Epoch 261/300
# 6/6 - 1s - loss: 0.4961 - accuracy: 0.4486 - 1s/epoch - 212ms/step
# Epoch 262/300
# 6/6 - 1s - loss: 0.5059 - accuracy: 0.4435 - 1s/epoch - 224ms/step
# Epoch 263/300
# 6/6 - 1s - loss: 0.4967 - accuracy: 0.4688 - 1s/epoch - 207ms/step
# Epoch 264/300
# 6/6 - 1s - loss: 0.4904 - accuracy: 0.4637 - 1s/epoch - 206ms/step
# Epoch 265/300
# 6/6 - 1s - loss: 0.4923 - accuracy: 0.4570 - 1s/epoch - 206ms/step
# Epoch 266/300
# 6/6 - 1s - loss: 0.4853 - accuracy: 0.4688 - 1s/epoch - 206ms/step
# Epoch 267/300
# 6/6 - 1s - loss: 0.4839 - accuracy: 0.4452 - 1s/epoch - 199ms/step
# Epoch 268/300
# 6/6 - 1s - loss: 0.4919 - accuracy: 0.4452 - 1s/epoch - 207ms/step
# Epoch 269/300
# 6/6 - 1s - loss: 0.4855 - accuracy: 0.4755 - 1s/epoch - 239ms/step
# Epoch 270/300
# 6/6 - 1s - loss: 0.4794 - accuracy: 0.4435 - 1s/epoch - 218ms/step
# Epoch 271/300
# 6/6 - 1s - loss: 0.4876 - accuracy: 0.4587 - 1s/epoch - 229ms/step
# Epoch 272/300
# 6/6 - 2s - loss: 0.4864 - accuracy: 0.4722 - 2s/epoch - 255ms/step
# Epoch 273/300
# 6/6 - 1s - loss: 0.4724 - accuracy: 0.4671 - 1s/epoch - 213ms/step
# Epoch 274/300
# 6/6 - 1s - loss: 0.4654 - accuracy: 0.4823 - 1s/epoch - 201ms/step
# Epoch 275/300
# 6/6 - 1s - loss: 0.4695 - accuracy: 0.4722 - 1s/epoch - 204ms/step
# Epoch 276/300
# 6/6 - 1s - loss: 0.4568 - accuracy: 0.4553 - 1s/epoch - 207ms/step
# Epoch 277/300
# 6/6 - 1s - loss: 0.4563 - accuracy: 0.4637 - 1s/epoch - 212ms/step
# Epoch 278/300
# 6/6 - 1s - loss: 0.4559 - accuracy: 0.4874 - 1s/epoch - 212ms/step
# Epoch 279/300
# 6/6 - 1s - loss: 0.4603 - accuracy: 0.5194 - 1s/epoch - 228ms/step
# Epoch 280/300
# 6/6 - 1s - loss: 0.4533 - accuracy: 0.4654 - 1s/epoch - 214ms/step
# Epoch 281/300
# 6/6 - 1s - loss: 0.4548 - accuracy: 0.4992 - 1s/epoch - 207ms/step
# Epoch 282/300
# 6/6 - 1s - loss: 0.4529 - accuracy: 0.4823 - 1s/epoch - 223ms/step
# Epoch 283/300
# 6/6 - 1s - loss: 0.4416 - accuracy: 0.4840 - 1s/epoch - 234ms/step
# Epoch 284/300
# 6/6 - 1s - loss: 0.4395 - accuracy: 0.4907 - 1s/epoch - 208ms/step
# Epoch 285/300
# 6/6 - 1s - loss: 0.4374 - accuracy: 0.4924 - 1s/epoch - 217ms/step
# Epoch 286/300
# 6/6 - 1s - loss: 0.4323 - accuracy: 0.5143 - 1s/epoch - 205ms/step
# Epoch 287/300
# 6/6 - 1s - loss: 0.4255 - accuracy: 0.4924 - 1s/epoch - 203ms/step
# Epoch 288/300
# 6/6 - 1s - loss: 0.4170 - accuracy: 0.4874 - 1s/epoch - 199ms/step
# Epoch 289/300
# 6/6 - 1s - loss: 0.4183 - accuracy: 0.5110 - 1s/epoch - 200ms/step
# Epoch 290/300
# 6/6 - 1s - loss: 0.4133 - accuracy: 0.4890 - 1s/epoch - 215ms/step
# Epoch 291/300
# 6/6 - 1s - loss: 0.4144 - accuracy: 0.5076 - 1s/epoch - 222ms/step
# Epoch 292/300
# 6/6 - 1s - loss: 0.4076 - accuracy: 0.5059 - 1s/epoch - 209ms/step
# Epoch 293/300
# 6/6 - 1s - loss: 0.4107 - accuracy: 0.5160 - 1s/epoch - 201ms/step
# Epoch 294/300
# 6/6 - 1s - loss: 0.4088 - accuracy: 0.4924 - 1s/epoch - 213ms/step
# Epoch 295/300
# 6/6 - 1s - loss: 0.3960 - accuracy: 0.5295 - 1s/epoch - 206ms/step
# Epoch 296/300
# 6/6 - 1s - loss: 0.4085 - accuracy: 0.4941 - 1s/epoch - 210ms/step
# Epoch 297/300
# 6/6 - 1s - loss: 0.4049 - accuracy: 0.5295 - 1s/epoch - 210ms/step
# Epoch 298/300
# 6/6 - 1s - loss: 0.4010 - accuracy: 0.5059 - 1s/epoch - 208ms/step
# Epoch 299/300
# 6/6 - 1s - loss: 0.3994 - accuracy: 0.5363 - 1s/epoch - 227ms/step
# Epoch 300/300
# 6/6 - 1s - loss: 0.3913 - accuracy: 0.5177 - 1s/epoch - 217ms/step

# %% [markdown]
# Prediction

# %%
to_predict = all_games.tail(8)
to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
prediction = all_games.tail(1)
to_predict = np.array(to_predict)
scaled_to_predict = scaler.transform(to_predict)
# Out:
# C:\Users\grigo\AppData\Local\Temp\ipykernel_21528\2568062844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
# array([[-0.83156105, -0.86598885, -0.02011658,  1.15692394,  1.11533021],
#        [ 1.31286573,  1.24480621,  0.54314779,  1.57473685,  0.90200597],
#        [-1.13790774,  0.23162458, -0.2615156 , -0.09651478, -0.80458791],
#        [-0.32098325, -0.78155705, -1.22711168, -2.01845416,  0.4753575 ],
#        [-0.11675213, -0.35939804, -0.50291462,  1.32404911,  1.00866809],
#        [-0.32098325,  0.14719278, -0.6638473 ,  0.48842329,  0.79534386],
#        [ 1.00651905,  0.56935179,  0.14081609, -0.26363995, -1.44456061]])

# %%
y_pred = model.predict(np.array([scaled_to_predict]))
print('The predicted numbers in the last lottery game are:', scaler.inverse_transform(y_pred).astype(int)[0])
# Out:
# 1/1 [==============================] - 4s 4s/step
# The predicted numbers in the last lottery game are: [ 9 20 29 41 50]

# %%
prediction = np.array(prediction)
print(f'The actual numbers in the last lottery game were: {prediction[0]}')
# Out:
# The actual numbers in the last lottery game were: [ 8 11 19 24 46]

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
