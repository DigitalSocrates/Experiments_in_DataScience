# %% [markdown]
# ## Advanced Lottery Forecasting with Deep Learning
#
# In the realm of predicting lottery outcomes, the cutting-edge technology of deep learning has emerged as a powerful tool. This revolutionary approach leverages neural networks, massive data sets, and advanced algorithms to not only enhance the accuracy of lottery predictions but also to uncover patterns and trends that were once hidden from conventional analysis.
#
# ## Harnessing the Power of Neural Networks
#
# Deep learning employs artificial neural networks, which are designed to mimic the human brain's ability to process information and make decisions. These neural networks consist of multiple layers of interconnected nodes, or "neurons," that can analyze vast amounts of historical lottery data. By doing so, they can detect intricate patterns and dependencies that may elude traditional statistical methods.
#
# ## The Importance of Big Data
#
# One of the key strengths of deep learning in lottery prediction is its capability to process immense datasets. Lottery results from years or even decades can be analyzed, providing a comprehensive view of historical trends. This extensive data is then used to train the neural network, allowing it to recognize subtle correlations and predict future outcomes with greater accuracy.
#
# ## Unveiling Hidden Patterns
#
# Deep learning algorithms excel at revealing hidden patterns in data. In the context of lottery prediction, these patterns could include:
#
# - Recurring number combinations
# - Seasonal or cyclical trends
# - Number hotspots or cold spots
# - Anomalies and irregularities in draws
#
# By uncovering these patterns, deep learning can significantly improve the accuracy of lottery predictions, making it a valuable tool for both individual players and organizations involved in lottery operations.
#
# ## Real-Time Adaptability
#
# In addition to historical analysis, deep learning can adapt to real-time data. This means that as new lottery results become available, the neural network can continuously refine its predictions. This adaptability is particularly beneficial in dynamic lottery environments where trends can change rapidly.
#
# ## Ethical Considerations
#
# While the potential of deep learning in lottery prediction is undeniably promising, ethical concerns should not be overlooked. Responsible and transparent usage of this technology is crucial to maintain fairness in lottery games and prevent any form of exploitation.
#
# ## Conclusion
#
# The world of lottery prediction has entered a new era with the integration of deep learning techniques. These advanced algorithms, capable of processing vast amounts of data and uncovering hidden patterns, have the potential to revolutionize how we approach forecasting lottery outcomes. However, it is essential to use this technology responsibly and ethically to ensure the integrity of lottery games. As deep learning continues to evolve, we can anticipate further breakthroughs in lottery prediction, ultimately benefiting both players and lottery operators alike.

# %%
# required imports
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional, Dropout

# %%
# declare global variables
# window - how many games we will use for prediction
WINDOW_LENGTH = 7

# %%
# load data
all_games = pd.read_csv('..\Web_Scrapping_Experiments\static\data/all_Games.csv')

# %% [markdown]
# Let us take a closer look at the data

# %%
all_games.head()
# Out:
#    Unnamed: 0        Date  Ball_1  Ball_2  Ball_3  Ball_4  Ball_5  Ball_Bonus
# 0         103  2019-01-02       8      12      42      46      56          12
# 1         102  2019-01-05       3       7      15      27      69          19
# 2         101  2019-01-09       6      19      37      49      59          22
# 3         100  2019-01-12       7      36      48      57      58          24
# 4          99  2019-01-16      14      29      31      56      61           1

# %%
all_games.describe()
# Out:
#        Unnamed: 0      Ball_1      Ball_2      Ball_3      Ball_4      Ball_5  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000  600.000000
# mean   299.500000   12.143333   23.256667   35.250000   47.155000   58.543333
# std    173.349358    9.800998   11.853761   12.437926   11.977064    9.383222
# min      0.000000    1.000000    2.000000    3.000000    7.000000   22.000000
# 25%    149.750000    4.000000   14.750000   26.000000   39.000000   54.000000
# 50%    299.500000   10.000000   22.000000   36.000000   48.000000   61.000000
# 75%    449.250000   18.000000   31.000000   44.000000   57.000000   66.000000
# max    599.000000   52.000000   58.000000   64.000000   68.000000   69.000000
#
#        Ball_Bonus
# count  600.000000
# mean    13.296667
# std      7.713699
# min      1.000000
# 25%      6.000000
# 50%     13.000000
# 75%     20.000000
# max     26.000000

# %%
all_games.shape
# Out:
# (600, 8)

# %% [markdown]
# To prepare the data for analysis, we will perform data preprocessing, which includes removing three columns from our dataset:
#
# 1. **Index Column**: The index column is typically an autogenerated identifier for each row in the dataset. Since it doesn't provide any meaningful information for our analysis, we will drop this column.
#
# 2. **Date Column**: The date column contains date values, which might not be relevant to our specific analysis or could be handled differently. For our current analysis, we will remove this column as it doesn't contribute to the immediate goals.
#
# 3. **Bonus Ball Column**: The bonus ball column might contain supplementary information. However, for our analysis, it is not required, so we will also eliminate this column.
#
# By dropping these three columns, we will streamline the dataset and focus on the relevant data that is essential for our analysis, making it more efficient and concise.

# %%
all_games.drop(['Date','Ball_Bonus'], axis=1, inplace=True)
all_games.drop(columns=all_games.columns[0], axis=1,  inplace=True)
all_games.head()
# Out:
#    Ball_1  Ball_2  Ball_3  Ball_4  Ball_5
# 0       8      12      42      46      56
# 1       3       7      15      27      69
# 2       6      19      37      49      59
# 3       7      36      48      57      58
# 4      14      29      31      56      61

# %% [markdown]
# Let us rescale the data

# %%
scaler = StandardScaler().fit(all_games.values)
transformed_dataset = scaler.transform(all_games.values)
transformed_df = pd.DataFrame(data=transformed_dataset, index=all_games.index)

# %% [markdown]
# Let us declare additional variables that might be helpful

# %%
# All our games
number_of_rows = all_games.values.shape[0]
# Balls counts
number_of_features = all_games.values.shape[1]

# %%
X = np.empty([ number_of_rows - WINDOW_LENGTH, WINDOW_LENGTH, number_of_features], dtype=float)
y = np.empty([ number_of_rows - WINDOW_LENGTH, number_of_features], dtype=float)
for i in range(0, number_of_rows - WINDOW_LENGTH):
    X[i] = transformed_df.iloc[i : i + WINDOW_LENGTH, 0 : number_of_features]
    y[i] = transformed_df.iloc[i+WINDOW_LENGTH : i + WINDOW_LENGTH+1, 0 : number_of_features]

# %%
model_1 = Sequential()
# add the input layer and the LSTM layer
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# add first drop out layer in order to reduce overfitting
model_1.add(Dropout(0.11))
# layer 2
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# drop out layer
model_1.add(Dropout(0.11))
# Layer 3
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# drop out layer
model_1.add(Dropout(0.11))
# Layer 4
model_1.add(Bidirectional(LSTM(400, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = False)))
# drop out layer
model_1.add(Dropout(0.11))
# 
model_1.add(Dense(69))
# 
model_1.add(Dense(number_of_features))

model_1.compile(optimizer=Adam(learning_rate=0.0001), loss ='mse', metrics=['accuracy'])

model_1.fit(x=X, y=y, batch_size=100, epochs=300, verbose=2)

to_predict = all_games.tail(8)
to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
prediction = all_games.tail(1)
to_predict = np.array(to_predict)
scaled_to_predict = scaler.transform(to_predict)
# Out:
# Epoch 1/300
# 6/6 - 18s - loss: 1.0035 - accuracy: 0.1568 - 18s/epoch - 3s/step
# Epoch 2/300
# 6/6 - 3s - loss: 0.9971 - accuracy: 0.2108 - 3s/epoch - 444ms/step
# Epoch 3/300
# 6/6 - 2s - loss: 0.9910 - accuracy: 0.2260 - 2s/epoch - 397ms/step
# Epoch 4/300
# 6/6 - 2s - loss: 0.9864 - accuracy: 0.2310 - 2s/epoch - 404ms/step
# Epoch 5/300
# 6/6 - 2s - loss: 0.9818 - accuracy: 0.2260 - 2s/epoch - 408ms/step
# Epoch 6/300
# 6/6 - 3s - loss: 0.9767 - accuracy: 0.2175 - 3s/epoch - 434ms/step
# Epoch 7/300
# 6/6 - 3s - loss: 0.9758 - accuracy: 0.2260 - 3s/epoch - 479ms/step
# Epoch 8/300
# 6/6 - 2s - loss: 0.9750 - accuracy: 0.2175 - 2s/epoch - 409ms/step
# Epoch 9/300
# 6/6 - 2s - loss: 0.9730 - accuracy: 0.2344 - 2s/epoch - 409ms/step
# Epoch 10/300
# 6/6 - 3s - loss: 0.9710 - accuracy: 0.2445 - 3s/epoch - 442ms/step
# Epoch 11/300
# 6/6 - 2s - loss: 0.9716 - accuracy: 0.2378 - 2s/epoch - 407ms/step
# Epoch 12/300
# 6/6 - 3s - loss: 0.9705 - accuracy: 0.2411 - 3s/epoch - 422ms/step
# Epoch 13/300
# 6/6 - 3s - loss: 0.9692 - accuracy: 0.2546 - 3s/epoch - 422ms/step
# Epoch 14/300
# 6/6 - 2s - loss: 0.9692 - accuracy: 0.2513 - 2s/epoch - 414ms/step
# Epoch 15/300
# 6/6 - 2s - loss: 0.9679 - accuracy: 0.2496 - 2s/epoch - 411ms/step
# Epoch 16/300
# 6/6 - 2s - loss: 0.9663 - accuracy: 0.2428 - 2s/epoch - 400ms/step
# Epoch 17/300
# 6/6 - 2s - loss: 0.9661 - accuracy: 0.2513 - 2s/epoch - 399ms/step
# Epoch 18/300
# 6/6 - 2s - loss: 0.9667 - accuracy: 0.2428 - 2s/epoch - 391ms/step
# Epoch 19/300
# 6/6 - 2s - loss: 0.9666 - accuracy: 0.2445 - 2s/epoch - 408ms/step
# Epoch 20/300
# 6/6 - 3s - loss: 0.9646 - accuracy: 0.2597 - 3s/epoch - 434ms/step
# Epoch 21/300
# 6/6 - 2s - loss: 0.9634 - accuracy: 0.2411 - 2s/epoch - 398ms/step
# Epoch 22/300
# 6/6 - 2s - loss: 0.9620 - accuracy: 0.2479 - 2s/epoch - 397ms/step
# Epoch 23/300
# 6/6 - 2s - loss: 0.9628 - accuracy: 0.2361 - 2s/epoch - 397ms/step
# Epoch 24/300
# 6/6 - 2s - loss: 0.9602 - accuracy: 0.2411 - 2s/epoch - 413ms/step
# Epoch 25/300
# 6/6 - 3s - loss: 0.9618 - accuracy: 0.2546 - 3s/epoch - 423ms/step
# Epoch 26/300
# 6/6 - 3s - loss: 0.9609 - accuracy: 0.2496 - 3s/epoch - 452ms/step
# Epoch 27/300
# 6/6 - 2s - loss: 0.9585 - accuracy: 0.2428 - 2s/epoch - 387ms/step
# Epoch 28/300
# 6/6 - 2s - loss: 0.9564 - accuracy: 0.2445 - 2s/epoch - 387ms/step
# Epoch 29/300
# 6/6 - 2s - loss: 0.9569 - accuracy: 0.2513 - 2s/epoch - 381ms/step
# Epoch 30/300
# 6/6 - 2s - loss: 0.9562 - accuracy: 0.2445 - 2s/epoch - 376ms/step
# Epoch 31/300
# 6/6 - 2s - loss: 0.9550 - accuracy: 0.2597 - 2s/epoch - 381ms/step
# Epoch 32/300
# 6/6 - 2s - loss: 0.9503 - accuracy: 0.2496 - 2s/epoch - 380ms/step
# Epoch 33/300
# 6/6 - 2s - loss: 0.9504 - accuracy: 0.2479 - 2s/epoch - 395ms/step
# Epoch 34/300
# 6/6 - 2s - loss: 0.9488 - accuracy: 0.2462 - 2s/epoch - 409ms/step
# Epoch 35/300
# 6/6 - 3s - loss: 0.9506 - accuracy: 0.2395 - 3s/epoch - 423ms/step
# Epoch 36/300
# 6/6 - 2s - loss: 0.9458 - accuracy: 0.2614 - 2s/epoch - 381ms/step
# Epoch 37/300
# 6/6 - 2s - loss: 0.9457 - accuracy: 0.2530 - 2s/epoch - 385ms/step
# Epoch 38/300
# 6/6 - 2s - loss: 0.9416 - accuracy: 0.2580 - 2s/epoch - 389ms/step
# Epoch 39/300
# 6/6 - 3s - loss: 0.9390 - accuracy: 0.2563 - 3s/epoch - 435ms/step
# Epoch 40/300
# 6/6 - 2s - loss: 0.9410 - accuracy: 0.2563 - 2s/epoch - 410ms/step
# Epoch 41/300
# 6/6 - 2s - loss: 0.9357 - accuracy: 0.2580 - 2s/epoch - 391ms/step
# Epoch 42/300
# 6/6 - 2s - loss: 0.9365 - accuracy: 0.2597 - 2s/epoch - 384ms/step
# Epoch 43/300
# 6/6 - 2s - loss: 0.9317 - accuracy: 0.2648 - 2s/epoch - 378ms/step
# Epoch 44/300
# 6/6 - 2s - loss: 0.9309 - accuracy: 0.2563 - 2s/epoch - 378ms/step
# Epoch 45/300
# 6/6 - 2s - loss: 0.9307 - accuracy: 0.2631 - 2s/epoch - 377ms/step
# Epoch 46/300
# 6/6 - 2s - loss: 0.9279 - accuracy: 0.2631 - 2s/epoch - 391ms/step
# Epoch 47/300
# 6/6 - 2s - loss: 0.9310 - accuracy: 0.2563 - 2s/epoch - 385ms/step
# Epoch 48/300
# 6/6 - 2s - loss: 0.9175 - accuracy: 0.2681 - 2s/epoch - 379ms/step
# Epoch 49/300
# 6/6 - 2s - loss: 0.9186 - accuracy: 0.2648 - 2s/epoch - 388ms/step
# Epoch 50/300
# 6/6 - 2s - loss: 0.9098 - accuracy: 0.2698 - 2s/epoch - 383ms/step
# Epoch 51/300
# 6/6 - 2s - loss: 0.9089 - accuracy: 0.2698 - 2s/epoch - 377ms/step
# Epoch 52/300
# 6/6 - 2s - loss: 0.9096 - accuracy: 0.2378 - 2s/epoch - 410ms/step
# Epoch 53/300
# 6/6 - 2s - loss: 0.9072 - accuracy: 0.2597 - 2s/epoch - 409ms/step
# Epoch 54/300
# 6/6 - 2s - loss: 0.9091 - accuracy: 0.2749 - 2s/epoch - 411ms/step
# Epoch 55/300
# 6/6 - 2s - loss: 0.9020 - accuracy: 0.2782 - 2s/epoch - 394ms/step
# Epoch 56/300
# 6/6 - 2s - loss: 0.8935 - accuracy: 0.2681 - 2s/epoch - 377ms/step
# Epoch 57/300
# 6/6 - 2s - loss: 0.9014 - accuracy: 0.2732 - 2s/epoch - 379ms/step
# Epoch 58/300
# 6/6 - 2s - loss: 0.8881 - accuracy: 0.2833 - 2s/epoch - 377ms/step
# Epoch 59/300
# 6/6 - 2s - loss: 0.8908 - accuracy: 0.2766 - 2s/epoch - 380ms/step
# Epoch 60/300
# 6/6 - 2s - loss: 0.8910 - accuracy: 0.2614 - 2s/epoch - 378ms/step
# Epoch 61/300
# 6/6 - 2s - loss: 0.8844 - accuracy: 0.2546 - 2s/epoch - 380ms/step
# Epoch 62/300
# 6/6 - 3s - loss: 0.8875 - accuracy: 0.2766 - 3s/epoch - 417ms/step
# Epoch 63/300
# 6/6 - 2s - loss: 0.8973 - accuracy: 0.2749 - 2s/epoch - 410ms/step
# Epoch 64/300
# 6/6 - 2s - loss: 0.8905 - accuracy: 0.2681 - 2s/epoch - 391ms/step
# Epoch 65/300
# 6/6 - 2s - loss: 0.8892 - accuracy: 0.2580 - 2s/epoch - 381ms/step
# Epoch 66/300
# 6/6 - 3s - loss: 0.8808 - accuracy: 0.2614 - 3s/epoch - 420ms/step
# Epoch 67/300
# 6/6 - 2s - loss: 0.8860 - accuracy: 0.2850 - 2s/epoch - 406ms/step
# Epoch 68/300
# 6/6 - 2s - loss: 0.8914 - accuracy: 0.2782 - 2s/epoch - 398ms/step
# Epoch 69/300
# 6/6 - 2s - loss: 0.8780 - accuracy: 0.3035 - 2s/epoch - 381ms/step
# Epoch 70/300
# 6/6 - 2s - loss: 0.8775 - accuracy: 0.2917 - 2s/epoch - 378ms/step
# Epoch 71/300
# 6/6 - 2s - loss: 0.8703 - accuracy: 0.2917 - 2s/epoch - 390ms/step
# Epoch 72/300
# 6/6 - 2s - loss: 0.8714 - accuracy: 0.2833 - 2s/epoch - 377ms/step
# Epoch 73/300
# 6/6 - 2s - loss: 0.8677 - accuracy: 0.2901 - 2s/epoch - 404ms/step
# Epoch 74/300
# 6/6 - 2s - loss: 0.8708 - accuracy: 0.2799 - 2s/epoch - 377ms/step
# Epoch 75/300
# 6/6 - 2s - loss: 0.8965 - accuracy: 0.2850 - 2s/epoch - 382ms/step
# Epoch 76/300
# 6/6 - 2s - loss: 0.9174 - accuracy: 0.2698 - 2s/epoch - 380ms/step
# Epoch 77/300
# 6/6 - 2s - loss: 0.8927 - accuracy: 0.2833 - 2s/epoch - 411ms/step
# Epoch 78/300
# 6/6 - 2s - loss: 0.8856 - accuracy: 0.2799 - 2s/epoch - 386ms/step
# Epoch 79/300
# 6/6 - 2s - loss: 0.8763 - accuracy: 0.2985 - 2s/epoch - 378ms/step
# Epoch 80/300
# 6/6 - 2s - loss: 0.8652 - accuracy: 0.2833 - 2s/epoch - 376ms/step
# Epoch 81/300
# 6/6 - 2s - loss: 0.8557 - accuracy: 0.2968 - 2s/epoch - 396ms/step
# Epoch 82/300
# 6/6 - 3s - loss: 0.8570 - accuracy: 0.2884 - 3s/epoch - 429ms/step
# Epoch 83/300
# 6/6 - 2s - loss: 0.8486 - accuracy: 0.2901 - 2s/epoch - 411ms/step
# Epoch 84/300
# 6/6 - 2s - loss: 0.8465 - accuracy: 0.2850 - 2s/epoch - 378ms/step
# Epoch 85/300
# 6/6 - 2s - loss: 0.8442 - accuracy: 0.2934 - 2s/epoch - 379ms/step
# Epoch 86/300
# 6/6 - 2s - loss: 0.8379 - accuracy: 0.3002 - 2s/epoch - 381ms/step
# Epoch 87/300
# 6/6 - 2s - loss: 0.8359 - accuracy: 0.2951 - 2s/epoch - 384ms/step
# Epoch 88/300
# 6/6 - 2s - loss: 0.8356 - accuracy: 0.2934 - 2s/epoch - 380ms/step
# Epoch 89/300
# 6/6 - 2s - loss: 0.8390 - accuracy: 0.3069 - 2s/epoch - 378ms/step
# Epoch 90/300
# 6/6 - 2s - loss: 0.8392 - accuracy: 0.2850 - 2s/epoch - 397ms/step
# Epoch 91/300
# 6/6 - 2s - loss: 0.8362 - accuracy: 0.2833 - 2s/epoch - 413ms/step
# Epoch 92/300
# 6/6 - 3s - loss: 0.8274 - accuracy: 0.2968 - 3s/epoch - 420ms/step
# Epoch 93/300
# 6/6 - 2s - loss: 0.8327 - accuracy: 0.3035 - 2s/epoch - 389ms/step
# Epoch 94/300
# 6/6 - 2s - loss: 0.8246 - accuracy: 0.2867 - 2s/epoch - 380ms/step
# Epoch 95/300
# 6/6 - 2s - loss: 0.8228 - accuracy: 0.2968 - 2s/epoch - 399ms/step
# Epoch 96/300
# 6/6 - 2s - loss: 0.8206 - accuracy: 0.3069 - 2s/epoch - 408ms/step
# Epoch 97/300
# 6/6 - 2s - loss: 0.8216 - accuracy: 0.2884 - 2s/epoch - 393ms/step
# Epoch 98/300
# 6/6 - 2s - loss: 0.8192 - accuracy: 0.3137 - 2s/epoch - 380ms/step
# Epoch 99/300
# 6/6 - 2s - loss: 0.8220 - accuracy: 0.2985 - 2s/epoch - 379ms/step
# Epoch 100/300
# 6/6 - 2s - loss: 0.8166 - accuracy: 0.2968 - 2s/epoch - 383ms/step
# Epoch 101/300
# 6/6 - 2s - loss: 0.8115 - accuracy: 0.3035 - 2s/epoch - 376ms/step
# Epoch 102/300
# 6/6 - 2s - loss: 0.8090 - accuracy: 0.3120 - 2s/epoch - 380ms/step
# Epoch 103/300
# 6/6 - 2s - loss: 0.8140 - accuracy: 0.3086 - 2s/epoch - 405ms/step
# Epoch 104/300
# 6/6 - 2s - loss: 0.8121 - accuracy: 0.2917 - 2s/epoch - 377ms/step
# Epoch 105/300
# 6/6 - 2s - loss: 0.7981 - accuracy: 0.2968 - 2s/epoch - 378ms/step
# Epoch 106/300
# 6/6 - 2s - loss: 0.7990 - accuracy: 0.3035 - 2s/epoch - 377ms/step
# Epoch 107/300
# 6/6 - 2s - loss: 0.7961 - accuracy: 0.3019 - 2s/epoch - 386ms/step
# Epoch 108/300
# 6/6 - 2s - loss: 0.7940 - accuracy: 0.3052 - 2s/epoch - 377ms/step
# Epoch 109/300
# 6/6 - 2s - loss: 0.7988 - accuracy: 0.3052 - 2s/epoch - 382ms/step
# Epoch 110/300
# 6/6 - 2s - loss: 0.7899 - accuracy: 0.3221 - 2s/epoch - 405ms/step
# Epoch 111/300
# 6/6 - 3s - loss: 0.7901 - accuracy: 0.3255 - 3s/epoch - 421ms/step
# Epoch 112/300
# 6/6 - 2s - loss: 0.7852 - accuracy: 0.3103 - 2s/epoch - 396ms/step
# Epoch 113/300
# 6/6 - 2s - loss: 0.7816 - accuracy: 0.3069 - 2s/epoch - 381ms/step
# Epoch 114/300
# 6/6 - 2s - loss: 0.7839 - accuracy: 0.3170 - 2s/epoch - 380ms/step
# Epoch 115/300
# 6/6 - 2s - loss: 0.7766 - accuracy: 0.3255 - 2s/epoch - 379ms/step
# Epoch 116/300
# 6/6 - 2s - loss: 0.7724 - accuracy: 0.3137 - 2s/epoch - 377ms/step
# Epoch 117/300
# 6/6 - 2s - loss: 0.7598 - accuracy: 0.3272 - 2s/epoch - 400ms/step
# Epoch 118/300
# 6/6 - 2s - loss: 0.7551 - accuracy: 0.3238 - 2s/epoch - 398ms/step
# Epoch 119/300
# 6/6 - 3s - loss: 0.7572 - accuracy: 0.3204 - 3s/epoch - 428ms/step
# Epoch 120/300
# 6/6 - 3s - loss: 0.7626 - accuracy: 0.3052 - 3s/epoch - 434ms/step
# Epoch 121/300
# 6/6 - 2s - loss: 0.7567 - accuracy: 0.3423 - 2s/epoch - 397ms/step
# Epoch 122/300
# 6/6 - 2s - loss: 0.7410 - accuracy: 0.3187 - 2s/epoch - 378ms/step
# Epoch 123/300
# 6/6 - 2s - loss: 0.7400 - accuracy: 0.3187 - 2s/epoch - 401ms/step
# Epoch 124/300
# 6/6 - 2s - loss: 0.7385 - accuracy: 0.3288 - 2s/epoch - 408ms/step
# Epoch 125/300
# 6/6 - 2s - loss: 0.7391 - accuracy: 0.3238 - 2s/epoch - 390ms/step
# Epoch 126/300
# 6/6 - 2s - loss: 0.7540 - accuracy: 0.3390 - 2s/epoch - 413ms/step
# Epoch 127/300
# 6/6 - 2s - loss: 0.7418 - accuracy: 0.3390 - 2s/epoch - 385ms/step
# Epoch 128/300
# 6/6 - 3s - loss: 0.7299 - accuracy: 0.3288 - 3s/epoch - 426ms/step
# Epoch 129/300
# 6/6 - 2s - loss: 0.7296 - accuracy: 0.3272 - 2s/epoch - 400ms/step
# Epoch 130/300
# 6/6 - 2s - loss: 0.7207 - accuracy: 0.3406 - 2s/epoch - 381ms/step
# Epoch 131/300
# 6/6 - 2s - loss: 0.7084 - accuracy: 0.3322 - 2s/epoch - 377ms/step
# Epoch 132/300
# 6/6 - 2s - loss: 0.6986 - accuracy: 0.3373 - 2s/epoch - 378ms/step
# Epoch 133/300
# 6/6 - 2s - loss: 0.7092 - accuracy: 0.3659 - 2s/epoch - 378ms/step
# Epoch 134/300
# 6/6 - 2s - loss: 0.7258 - accuracy: 0.3491 - 2s/epoch - 380ms/step
# Epoch 135/300
# 6/6 - 2s - loss: 0.7083 - accuracy: 0.3575 - 2s/epoch - 390ms/step
# Epoch 136/300
# 6/6 - 2s - loss: 0.7181 - accuracy: 0.3727 - 2s/epoch - 380ms/step
# Epoch 137/300
# 6/6 - 2s - loss: 0.6987 - accuracy: 0.3491 - 2s/epoch - 380ms/step
# Epoch 138/300
# 6/6 - 2s - loss: 0.6891 - accuracy: 0.3744 - 2s/epoch - 400ms/step
# Epoch 139/300
# 6/6 - 2s - loss: 0.6817 - accuracy: 0.3676 - 2s/epoch - 410ms/step
# Epoch 140/300
# 6/6 - 3s - loss: 0.6830 - accuracy: 0.3626 - 3s/epoch - 421ms/step
# Epoch 141/300
# 6/6 - 2s - loss: 0.6708 - accuracy: 0.3811 - 2s/epoch - 382ms/step
# Epoch 142/300
# 6/6 - 2s - loss: 0.6730 - accuracy: 0.3710 - 2s/epoch - 380ms/step
# Epoch 143/300
# 6/6 - 2s - loss: 0.6692 - accuracy: 0.3744 - 2s/epoch - 380ms/step
# Epoch 144/300
# 6/6 - 2s - loss: 0.6610 - accuracy: 0.3761 - 2s/epoch - 378ms/step
# Epoch 145/300
# 6/6 - 2s - loss: 0.6649 - accuracy: 0.3642 - 2s/epoch - 380ms/step
# Epoch 146/300
# 6/6 - 2s - loss: 0.6518 - accuracy: 0.4047 - 2s/epoch - 397ms/step
# Epoch 147/300
# 6/6 - 3s - loss: 0.6549 - accuracy: 0.3828 - 3s/epoch - 422ms/step
# Epoch 148/300
# 6/6 - 3s - loss: 0.6608 - accuracy: 0.3980 - 3s/epoch - 459ms/step
# Epoch 149/300
# 6/6 - 2s - loss: 0.6474 - accuracy: 0.3997 - 2s/epoch - 398ms/step
# Epoch 150/300
# 6/6 - 2s - loss: 0.6377 - accuracy: 0.3963 - 2s/epoch - 400ms/step
# Epoch 151/300
# 6/6 - 2s - loss: 0.6337 - accuracy: 0.3963 - 2s/epoch - 415ms/step
# Epoch 152/300
# 6/6 - 3s - loss: 0.6364 - accuracy: 0.4148 - 3s/epoch - 418ms/step
# Epoch 153/300
# 6/6 - 2s - loss: 0.6468 - accuracy: 0.3980 - 2s/epoch - 388ms/step
# Epoch 154/300
# 6/6 - 2s - loss: 0.6470 - accuracy: 0.3777 - 2s/epoch - 392ms/step
# Epoch 155/300
# 6/6 - 2s - loss: 0.6282 - accuracy: 0.4047 - 2s/epoch - 379ms/step
# Epoch 156/300
# 6/6 - 2s - loss: 0.6319 - accuracy: 0.4182 - 2s/epoch - 383ms/step
# Epoch 157/300
# 6/6 - 2s - loss: 0.6117 - accuracy: 0.4165 - 2s/epoch - 378ms/step
# Epoch 158/300
# 6/6 - 2s - loss: 0.6058 - accuracy: 0.3980 - 2s/epoch - 378ms/step
# Epoch 159/300
# 6/6 - 2s - loss: 0.6016 - accuracy: 0.4283 - 2s/epoch - 374ms/step
# Epoch 160/300
# 6/6 - 2s - loss: 0.6023 - accuracy: 0.4064 - 2s/epoch - 378ms/step
# Epoch 161/300
# 6/6 - 2s - loss: 0.5941 - accuracy: 0.4266 - 2s/epoch - 377ms/step
# Epoch 162/300
# 6/6 - 2s - loss: 0.5916 - accuracy: 0.4266 - 2s/epoch - 382ms/step
# Epoch 163/300
# 6/6 - 2s - loss: 0.5847 - accuracy: 0.4368 - 2s/epoch - 384ms/step
# Epoch 164/300
# 6/6 - 2s - loss: 0.5837 - accuracy: 0.4216 - 2s/epoch - 377ms/step
# Epoch 165/300
# 6/6 - 2s - loss: 0.5962 - accuracy: 0.4384 - 2s/epoch - 377ms/step
# Epoch 166/300
# 6/6 - 2s - loss: 0.5932 - accuracy: 0.4266 - 2s/epoch - 379ms/step
# Epoch 167/300
# 6/6 - 2s - loss: 0.5766 - accuracy: 0.4570 - 2s/epoch - 408ms/step
# Epoch 168/300
# 6/6 - 3s - loss: 0.5835 - accuracy: 0.4300 - 3s/epoch - 425ms/step
# Epoch 169/300
# 6/6 - 2s - loss: 0.5657 - accuracy: 0.4368 - 2s/epoch - 396ms/step
# Epoch 170/300
# 6/6 - 2s - loss: 0.5770 - accuracy: 0.4233 - 2s/epoch - 379ms/step
# Epoch 171/300
# 6/6 - 2s - loss: 0.5650 - accuracy: 0.4317 - 2s/epoch - 379ms/step
# Epoch 172/300
# 6/6 - 2s - loss: 0.5583 - accuracy: 0.4401 - 2s/epoch - 379ms/step
# Epoch 173/300
# 6/6 - 2s - loss: 0.5464 - accuracy: 0.4486 - 2s/epoch - 390ms/step
# Epoch 174/300
# 6/6 - 2s - loss: 0.5387 - accuracy: 0.4604 - 2s/epoch - 390ms/step
# Epoch 175/300
# 6/6 - 2s - loss: 0.5366 - accuracy: 0.4739 - 2s/epoch - 377ms/step
# Epoch 176/300
# 6/6 - 2s - loss: 0.5381 - accuracy: 0.4519 - 2s/epoch - 417ms/step
# Epoch 177/300
# 6/6 - 3s - loss: 0.5210 - accuracy: 0.4705 - 3s/epoch - 418ms/step
# Epoch 178/300
# 6/6 - 2s - loss: 0.5389 - accuracy: 0.4637 - 2s/epoch - 390ms/step
# Epoch 179/300
# 6/6 - 2s - loss: 0.5286 - accuracy: 0.4536 - 2s/epoch - 403ms/step
# Epoch 180/300
# 6/6 - 2s - loss: 0.5186 - accuracy: 0.4654 - 2s/epoch - 406ms/step
# Epoch 181/300
# 6/6 - 2s - loss: 0.5130 - accuracy: 0.4654 - 2s/epoch - 400ms/step
# Epoch 182/300
# 6/6 - 2s - loss: 0.5038 - accuracy: 0.4772 - 2s/epoch - 382ms/step
# Epoch 183/300
# 6/6 - 2s - loss: 0.5101 - accuracy: 0.4570 - 2s/epoch - 379ms/step
# Epoch 184/300
# 6/6 - 2s - loss: 0.4868 - accuracy: 0.4789 - 2s/epoch - 376ms/step
# Epoch 185/300
# 6/6 - 2s - loss: 0.4911 - accuracy: 0.4789 - 2s/epoch - 377ms/step
# Epoch 186/300
# 6/6 - 2s - loss: 0.4819 - accuracy: 0.4924 - 2s/epoch - 377ms/step
# Epoch 187/300
# 6/6 - 2s - loss: 0.4779 - accuracy: 0.5008 - 2s/epoch - 374ms/step
# Epoch 188/300
# 6/6 - 2s - loss: 0.4668 - accuracy: 0.4924 - 2s/epoch - 378ms/step
# Epoch 189/300
# 6/6 - 2s - loss: 0.4753 - accuracy: 0.4857 - 2s/epoch - 376ms/step
# Epoch 190/300
# 6/6 - 2s - loss: 0.4742 - accuracy: 0.4924 - 2s/epoch - 390ms/step
# Epoch 191/300
# 6/6 - 2s - loss: 0.4710 - accuracy: 0.4840 - 2s/epoch - 377ms/step
# Epoch 192/300
# 6/6 - 2s - loss: 0.4647 - accuracy: 0.4840 - 2s/epoch - 377ms/step
# Epoch 193/300
# 6/6 - 2s - loss: 0.4484 - accuracy: 0.4924 - 2s/epoch - 391ms/step
# Epoch 194/300
# 6/6 - 2s - loss: 0.4491 - accuracy: 0.5126 - 2s/epoch - 377ms/step
# Epoch 195/300
# 6/6 - 2s - loss: 0.4313 - accuracy: 0.5245 - 2s/epoch - 395ms/step
# Epoch 196/300
# 6/6 - 3s - loss: 0.4276 - accuracy: 0.5194 - 3s/epoch - 422ms/step
# Epoch 197/300
# 6/6 - 2s - loss: 0.4250 - accuracy: 0.5160 - 2s/epoch - 416ms/step
# Epoch 198/300
# 6/6 - 2s - loss: 0.4180 - accuracy: 0.5447 - 2s/epoch - 396ms/step
# Epoch 199/300
# 6/6 - 2s - loss: 0.4101 - accuracy: 0.5245 - 2s/epoch - 400ms/step
# Epoch 200/300
# 6/6 - 2s - loss: 0.4039 - accuracy: 0.5042 - 2s/epoch - 382ms/step
# Epoch 201/300
# 6/6 - 2s - loss: 0.3919 - accuracy: 0.5396 - 2s/epoch - 390ms/step
# Epoch 202/300
# 6/6 - 2s - loss: 0.3865 - accuracy: 0.5295 - 2s/epoch - 379ms/step
# Epoch 203/300
# 6/6 - 2s - loss: 0.3841 - accuracy: 0.5177 - 2s/epoch - 390ms/step
# Epoch 204/300
# 6/6 - 2s - loss: 0.3852 - accuracy: 0.5261 - 2s/epoch - 375ms/step
# Epoch 205/300
# 6/6 - 3s - loss: 0.3788 - accuracy: 0.5379 - 3s/epoch - 481ms/step
# Epoch 206/300
# 6/6 - 2s - loss: 0.3770 - accuracy: 0.5599 - 2s/epoch - 404ms/step
# Epoch 207/300
# 6/6 - 2s - loss: 0.3665 - accuracy: 0.5481 - 2s/epoch - 376ms/step
# Epoch 208/300
# 6/6 - 2s - loss: 0.3627 - accuracy: 0.5514 - 2s/epoch - 414ms/step
# Epoch 209/300
# 6/6 - 2s - loss: 0.3633 - accuracy: 0.5413 - 2s/epoch - 417ms/step
# Epoch 210/300
# 6/6 - 2s - loss: 0.3630 - accuracy: 0.5582 - 2s/epoch - 379ms/step
# Epoch 211/300
# 6/6 - 2s - loss: 0.3530 - accuracy: 0.5582 - 2s/epoch - 377ms/step
# Epoch 212/300
# 6/6 - 2s - loss: 0.3332 - accuracy: 0.5649 - 2s/epoch - 377ms/step
# Epoch 213/300
# 6/6 - 2s - loss: 0.3266 - accuracy: 0.5818 - 2s/epoch - 394ms/step
# Epoch 214/300
# 6/6 - 2s - loss: 0.3189 - accuracy: 0.5750 - 2s/epoch - 376ms/step
# Epoch 215/300
# 6/6 - 2s - loss: 0.3192 - accuracy: 0.5717 - 2s/epoch - 379ms/step
# Epoch 216/300
# 6/6 - 2s - loss: 0.3086 - accuracy: 0.5936 - 2s/epoch - 384ms/step
# Epoch 217/300
# 6/6 - 2s - loss: 0.2992 - accuracy: 0.6071 - 2s/epoch - 376ms/step
# Epoch 218/300
# 6/6 - 2s - loss: 0.2952 - accuracy: 0.5818 - 2s/epoch - 378ms/step
# Epoch 219/300
# 6/6 - 2s - loss: 0.2835 - accuracy: 0.5852 - 2s/epoch - 380ms/step
# Epoch 220/300
# 6/6 - 2s - loss: 0.2860 - accuracy: 0.6054 - 2s/epoch - 375ms/step
# Epoch 221/300
# 6/6 - 2s - loss: 0.2747 - accuracy: 0.5852 - 2s/epoch - 378ms/step
# Epoch 222/300
# 6/6 - 2s - loss: 0.2653 - accuracy: 0.6003 - 2s/epoch - 375ms/step
# Epoch 223/300
# 6/6 - 2s - loss: 0.2634 - accuracy: 0.6256 - 2s/epoch - 377ms/step
# Epoch 224/300
# 6/6 - 2s - loss: 0.2575 - accuracy: 0.6290 - 2s/epoch - 387ms/step
# Epoch 225/300
# 6/6 - 3s - loss: 0.2536 - accuracy: 0.6256 - 3s/epoch - 424ms/step
# Epoch 226/300
# 6/6 - 3s - loss: 0.2519 - accuracy: 0.6239 - 3s/epoch - 424ms/step
# Epoch 227/300
# 6/6 - 2s - loss: 0.2442 - accuracy: 0.6374 - 2s/epoch - 380ms/step
# Epoch 228/300
# 6/6 - 2s - loss: 0.2395 - accuracy: 0.6206 - 2s/epoch - 378ms/step
# Epoch 229/300
# 6/6 - 2s - loss: 0.2300 - accuracy: 0.6223 - 2s/epoch - 377ms/step
# Epoch 230/300
# 6/6 - 2s - loss: 0.2300 - accuracy: 0.6509 - 2s/epoch - 379ms/step
# Epoch 231/300
# 6/6 - 2s - loss: 0.2163 - accuracy: 0.6543 - 2s/epoch - 392ms/step
# Epoch 232/300
# 6/6 - 2s - loss: 0.2055 - accuracy: 0.6476 - 2s/epoch - 377ms/step
# Epoch 233/300
# 6/6 - 2s - loss: 0.2003 - accuracy: 0.6459 - 2s/epoch - 391ms/step
# Epoch 234/300
# 6/6 - 2s - loss: 0.1968 - accuracy: 0.6560 - 2s/epoch - 411ms/step
# Epoch 235/300
# 6/6 - 3s - loss: 0.1939 - accuracy: 0.6695 - 3s/epoch - 420ms/step
# Epoch 236/300
# 6/6 - 2s - loss: 0.1860 - accuracy: 0.6745 - 2s/epoch - 397ms/step
# Epoch 237/300
# 6/6 - 2s - loss: 0.1805 - accuracy: 0.6830 - 2s/epoch - 413ms/step
# Epoch 238/300
# 6/6 - 2s - loss: 0.1774 - accuracy: 0.6695 - 2s/epoch - 388ms/step
# Epoch 239/300
# 6/6 - 2s - loss: 0.1707 - accuracy: 0.6863 - 2s/epoch - 378ms/step
# Epoch 240/300
# 6/6 - 2s - loss: 0.1630 - accuracy: 0.7099 - 2s/epoch - 378ms/step
# Epoch 241/300
# 6/6 - 2s - loss: 0.1626 - accuracy: 0.6863 - 2s/epoch - 379ms/step
# Epoch 242/300
# 6/6 - 2s - loss: 0.1554 - accuracy: 0.7099 - 2s/epoch - 377ms/step
# Epoch 243/300
# 6/6 - 2s - loss: 0.1535 - accuracy: 0.7015 - 2s/epoch - 378ms/step
# Epoch 244/300
# 6/6 - 2s - loss: 0.1453 - accuracy: 0.7150 - 2s/epoch - 378ms/step
# Epoch 245/300
# 6/6 - 2s - loss: 0.1478 - accuracy: 0.7032 - 2s/epoch - 378ms/step
# Epoch 246/300
# 6/6 - 2s - loss: 0.1446 - accuracy: 0.7420 - 2s/epoch - 389ms/step
# Epoch 247/300
# 6/6 - 2s - loss: 0.1411 - accuracy: 0.7369 - 2s/epoch - 379ms/step
# Epoch 248/300
# 6/6 - 2s - loss: 0.1386 - accuracy: 0.7386 - 2s/epoch - 387ms/step
# Epoch 249/300
# 6/6 - 2s - loss: 0.1364 - accuracy: 0.7302 - 2s/epoch - 377ms/step
# Epoch 250/300
# 6/6 - 2s - loss: 0.1286 - accuracy: 0.7437 - 2s/epoch - 377ms/step
# Epoch 251/300
# 6/6 - 2s - loss: 0.1252 - accuracy: 0.7386 - 2s/epoch - 388ms/step
# Epoch 252/300
# 6/6 - 2s - loss: 0.1220 - accuracy: 0.7538 - 2s/epoch - 386ms/step
# Epoch 253/300
# 6/6 - 2s - loss: 0.1142 - accuracy: 0.7555 - 2s/epoch - 400ms/step
# Epoch 254/300
# 6/6 - 3s - loss: 0.1116 - accuracy: 0.7521 - 3s/epoch - 431ms/step
# Epoch 255/300
# 6/6 - 2s - loss: 0.1052 - accuracy: 0.7673 - 2s/epoch - 415ms/step
# Epoch 256/300
# 6/6 - 3s - loss: 0.1007 - accuracy: 0.7639 - 3s/epoch - 421ms/step
# Epoch 257/300
# 6/6 - 2s - loss: 0.0963 - accuracy: 0.7926 - 2s/epoch - 396ms/step
# Epoch 258/300
# 6/6 - 2s - loss: 0.0947 - accuracy: 0.7875 - 2s/epoch - 379ms/step
# Epoch 259/300
# 6/6 - 2s - loss: 0.0891 - accuracy: 0.7909 - 2s/epoch - 374ms/step
# Epoch 260/300
# 6/6 - 2s - loss: 0.0899 - accuracy: 0.7841 - 2s/epoch - 379ms/step
# Epoch 261/300
# 6/6 - 2s - loss: 0.0845 - accuracy: 0.8027 - 2s/epoch - 377ms/step
# Epoch 262/300
# 6/6 - 2s - loss: 0.0821 - accuracy: 0.7909 - 2s/epoch - 409ms/step
# Epoch 263/300
# 6/6 - 2s - loss: 0.0819 - accuracy: 0.7858 - 2s/epoch - 410ms/step
# Epoch 264/300
# 6/6 - 2s - loss: 0.0777 - accuracy: 0.7926 - 2s/epoch - 404ms/step
# Epoch 265/300
# 6/6 - 2s - loss: 0.0775 - accuracy: 0.8010 - 2s/epoch - 398ms/step
# Epoch 266/300
# 6/6 - 2s - loss: 0.0719 - accuracy: 0.8212 - 2s/epoch - 396ms/step
# Epoch 267/300
# 6/6 - 2s - loss: 0.0758 - accuracy: 0.7875 - 2s/epoch - 380ms/step
# Epoch 268/300
# 6/6 - 2s - loss: 0.0662 - accuracy: 0.8229 - 2s/epoch - 376ms/step
# Epoch 269/300
# 6/6 - 2s - loss: 0.0665 - accuracy: 0.8246 - 2s/epoch - 378ms/step
# Epoch 270/300
# 6/6 - 2s - loss: 0.0636 - accuracy: 0.8229 - 2s/epoch - 381ms/step
# Epoch 271/300
# 6/6 - 2s - loss: 0.0619 - accuracy: 0.8212 - 2s/epoch - 379ms/step
# Epoch 272/300
# 6/6 - 2s - loss: 0.0629 - accuracy: 0.8314 - 2s/epoch - 382ms/step
# Epoch 273/300
# 6/6 - 2s - loss: 0.0622 - accuracy: 0.8415 - 2s/epoch - 410ms/step
# Epoch 274/300
# 6/6 - 2s - loss: 0.0631 - accuracy: 0.8415 - 2s/epoch - 392ms/step
# Epoch 275/300
# 6/6 - 2s - loss: 0.0612 - accuracy: 0.8027 - 2s/epoch - 384ms/step
# Epoch 276/300
# 6/6 - 2s - loss: 0.0597 - accuracy: 0.8381 - 2s/epoch - 381ms/step
# Epoch 277/300
# 6/6 - 2s - loss: 0.0589 - accuracy: 0.8061 - 2s/epoch - 378ms/step
# Epoch 278/300
# 6/6 - 2s - loss: 0.0557 - accuracy: 0.8482 - 2s/epoch - 378ms/step
# Epoch 279/300
# 6/6 - 2s - loss: 0.0539 - accuracy: 0.8196 - 2s/epoch - 364ms/step
# Epoch 280/300
# 6/6 - 2s - loss: 0.0514 - accuracy: 0.8499 - 2s/epoch - 406ms/step
# Epoch 281/300
# 6/6 - 2s - loss: 0.0519 - accuracy: 0.8499 - 2s/epoch - 373ms/step
# Epoch 282/300
# 6/6 - 3s - loss: 0.0518 - accuracy: 0.8449 - 3s/epoch - 425ms/step
# Epoch 283/300
# 6/6 - 2s - loss: 0.0480 - accuracy: 0.8482 - 2s/epoch - 402ms/step
# Epoch 284/300
# 6/6 - 2s - loss: 0.0486 - accuracy: 0.8381 - 2s/epoch - 389ms/step
# Epoch 285/300
# 6/6 - 2s - loss: 0.0456 - accuracy: 0.8432 - 2s/epoch - 365ms/step
# Epoch 286/300
# 6/6 - 2s - loss: 0.0420 - accuracy: 0.8499 - 2s/epoch - 369ms/step
# Epoch 287/300
# 6/6 - 2s - loss: 0.0444 - accuracy: 0.8550 - 2s/epoch - 366ms/step
# Epoch 288/300
# 6/6 - 2s - loss: 0.0408 - accuracy: 0.8381 - 2s/epoch - 366ms/step
# Epoch 289/300
# 6/6 - 2s - loss: 0.0405 - accuracy: 0.8567 - 2s/epoch - 365ms/step
# Epoch 290/300
# 6/6 - 2s - loss: 0.0384 - accuracy: 0.8499 - 2s/epoch - 365ms/step
# Epoch 291/300
# 6/6 - 2s - loss: 0.0344 - accuracy: 0.8550 - 2s/epoch - 389ms/step
# Epoch 292/300
# 6/6 - 2s - loss: 0.0346 - accuracy: 0.8668 - 2s/epoch - 407ms/step
# Epoch 293/300
# 6/6 - 2s - loss: 0.0346 - accuracy: 0.8820 - 2s/epoch - 403ms/step
# Epoch 294/300
# 6/6 - 2s - loss: 0.0336 - accuracy: 0.8651 - 2s/epoch - 389ms/step
# Epoch 295/300
# 6/6 - 2s - loss: 0.0332 - accuracy: 0.8887 - 2s/epoch - 384ms/step
# Epoch 296/300
# 6/6 - 2s - loss: 0.0327 - accuracy: 0.8887 - 2s/epoch - 369ms/step
# Epoch 297/300
# 6/6 - 2s - loss: 0.0314 - accuracy: 0.8870 - 2s/epoch - 366ms/step
# Epoch 298/300
# 6/6 - 2s - loss: 0.0317 - accuracy: 0.8836 - 2s/epoch - 376ms/step
# Epoch 299/300
# 6/6 - 2s - loss: 0.0306 - accuracy: 0.8702 - 2s/epoch - 364ms/step
# Epoch 300/300
# 6/6 - 2s - loss: 0.0295 - accuracy: 0.9022 - 2s/epoch - 366ms/step
# C:\Users\grigo\AppData\Local\Temp\ipykernel_21528\2200496497.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)

# %%
y_pred = model_1.predict(np.array([scaled_to_predict]))
print('The predicted numbers in the last lottery game are:', scaler.inverse_transform(y_pred).astype(int)[0])
# Out:
# 1/1 [==============================] - 2s 2s/step
# The predicted numbers in the last lottery game are: [ 8  9 20 24 46]

# %%
model_2 = Sequential()
# add the input layer and the LSTM layer
model_2.add(Bidirectional(LSTM(300, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# add first drop out layer in order to reduce overfitting
model_2.add(Dropout(0.12))
# layer 2
model_2.add(Bidirectional(LSTM(300, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# drop out layer
model_2.add(Dropout(0.12))
# Layer 3
model_2.add(Bidirectional(LSTM(23000, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = True)))
# Layer 4
model_2.add(Bidirectional(LSTM(300, input_shape = (WINDOW_LENGTH, number_of_features), return_sequences = False)))
# 
model_2.add(Dense(69))
# 
model_2.add(Dense(number_of_features))

# %%
# merge two models
from keras.layers import Concatenate
merged = Concatenate([model_1, model_2])

# %%
final_model = Sequential()
final_model.add(merged)
final_model.add(Dense(number_of_features, activation='softmax'))
final_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# checkpoint = ModelCheckpoint('weights.h5', monitor='val_acc', save_best_only=True, verbose=2)
# early_stopping = EarlyStopping(monitor="val_loss", patience=5)

final_model.fit(x=[X, X], y=y, batch_size=7, epochs=200, verbose=1, validation_split=0.1, shuffle=True)
# callbacks=[early_stopping, checkpoint]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# i:\workspace\Experiments_in_DataScience\Experiments_in_DataScience\Deep_Learning_Experiments\Lottery_Prediction.ipynb Cell 19 line 9
#       <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a> final_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#       <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=5'>6</a> # checkpoint = ModelCheckpoint('weights.h5', monitor='val_acc', save_best_only=True, verbose=2)
#       <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=6'>7</a> # early_stopping = EarlyStopping(monitor="val_loss", patience=5)
# ----> <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=8'>9</a> final_model.fit(x=int(X.shape[0]), y=y, batch_size=7, epochs=200, verbose=1, validation_split=0.1, shuffle=True)
#      <a href='vscode-notebook-cell:/i%3A/workspace/Experiments_in_DataScience/Experiments_in_DataScience/Deep_Learning_Experiments/Lottery_Prediction.ipynb#X41sZmlsZQ%3D%3D?line=9'>10</a> # callbacks=[early_stopping, checkpoint]
#
# File i:\workspace\Experiments_in_DataScience\Experiments_in_DataScience\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File i:\workspace\Experiments_in_DataScience\Experiments_in_DataScience\.venv\Lib\site-packages\keras\src\engine\data_adapter.py:1766, in train_validation_split(arrays, validation_split)
#    1764 unsplitable = [type(t) for t in flat_arrays if not _can_split(t)]
#    1765 if unsplitable:
# -> 1766     raise ValueError(
#    1767         "`validation_split` is only supported for Tensors or NumPy "
#    1768         "arrays, found following types in the input: {}".format(unsplitable)
#    1769     )
#    1771 if all(t is None for t in flat_arrays):
#    1772     return arrays, arrays
#
# ValueError: `validation_split` is only supported for Tensors or NumPy arrays, found following types in the input: [<class 'int'>]

# %%
#Model Details
from tensorflow.keras.utils import plot_model
final_model.summary()
plot_model(final_model, "output/architecture.png", show_shapes=True)

# %% [markdown]
# build RNN

# %%
import os
import torch
from tensorflow import keras
from tensorflow.keras.optimizers import Adam

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:4096"
device = torch.device('cuda:0')

# %%
model_1.compile(optimizer=Adam(learning_rate=0.0001), loss ='mse', metrics=['accuracy'])
model_1.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
final_model

# %% [markdown]
# Train the sequential model

# %%
model.fit(x=X, y=y, batch_size=100, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 6/6 - 19s - loss: 1.0037 - accuracy: 0.2192 - 19s/epoch - 3s/step
# Epoch 2/300
# 6/6 - 1s - loss: 1.0007 - accuracy: 0.2074 - 1s/epoch - 214ms/step
# Epoch 3/300
# 6/6 - 1s - loss: 0.9975 - accuracy: 0.2260 - 1s/epoch - 239ms/step
# Epoch 4/300
# 6/6 - 1s - loss: 0.9949 - accuracy: 0.2159 - 1s/epoch - 224ms/step
# Epoch 5/300
# 6/6 - 1s - loss: 0.9924 - accuracy: 0.2260 - 1s/epoch - 214ms/step
# Epoch 6/300
# 6/6 - 1s - loss: 0.9880 - accuracy: 0.2226 - 1s/epoch - 211ms/step
# Epoch 7/300
# 6/6 - 1s - loss: 0.9819 - accuracy: 0.2344 - 1s/epoch - 217ms/step
# Epoch 8/300
# 6/6 - 1s - loss: 0.9774 - accuracy: 0.2260 - 1s/epoch - 212ms/step
# Epoch 9/300
# 6/6 - 1s - loss: 0.9755 - accuracy: 0.2175 - 1s/epoch - 214ms/step
# Epoch 10/300
# 6/6 - 1s - loss: 0.9756 - accuracy: 0.2024 - 1s/epoch - 198ms/step
# Epoch 11/300
# 6/6 - 1s - loss: 0.9751 - accuracy: 0.2226 - 1s/epoch - 204ms/step
# Epoch 12/300
# 6/6 - 1s - loss: 0.9740 - accuracy: 0.2411 - 1s/epoch - 210ms/step
# Epoch 13/300
# 6/6 - 1s - loss: 0.9722 - accuracy: 0.2378 - 1s/epoch - 207ms/step
# Epoch 14/300
# 6/6 - 1s - loss: 0.9713 - accuracy: 0.2293 - 1s/epoch - 215ms/step
# Epoch 15/300
# 6/6 - 1s - loss: 0.9701 - accuracy: 0.2260 - 1s/epoch - 213ms/step
# Epoch 16/300
# 6/6 - 1s - loss: 0.9693 - accuracy: 0.2293 - 1s/epoch - 212ms/step
# Epoch 17/300
# 6/6 - 1s - loss: 0.9718 - accuracy: 0.2395 - 1s/epoch - 210ms/step
# Epoch 18/300
# 6/6 - 1s - loss: 0.9688 - accuracy: 0.2428 - 1s/epoch - 192ms/step
# Epoch 19/300
# 6/6 - 1s - loss: 0.9684 - accuracy: 0.2428 - 1s/epoch - 195ms/step
# Epoch 20/300
# 6/6 - 1s - loss: 0.9679 - accuracy: 0.2411 - 1s/epoch - 193ms/step
# Epoch 21/300
# 6/6 - 1s - loss: 0.9660 - accuracy: 0.2496 - 1s/epoch - 191ms/step
# Epoch 22/300
# 6/6 - 1s - loss: 0.9663 - accuracy: 0.2344 - 1s/epoch - 194ms/step
# Epoch 23/300
# 6/6 - 1s - loss: 0.9654 - accuracy: 0.2462 - 1s/epoch - 192ms/step
# Epoch 24/300
# 6/6 - 1s - loss: 0.9637 - accuracy: 0.2479 - 1s/epoch - 201ms/step
# Epoch 25/300
# 6/6 - 1s - loss: 0.9636 - accuracy: 0.2546 - 1s/epoch - 197ms/step
# Epoch 26/300
# 6/6 - 1s - loss: 0.9637 - accuracy: 0.2496 - 1s/epoch - 189ms/step
# Epoch 27/300
# 6/6 - 1s - loss: 0.9621 - accuracy: 0.2395 - 1s/epoch - 214ms/step
# Epoch 28/300
# 6/6 - 1s - loss: 0.9602 - accuracy: 0.2530 - 1s/epoch - 214ms/step
# Epoch 29/300
# 6/6 - 1s - loss: 0.9588 - accuracy: 0.2378 - 1s/epoch - 226ms/step
# Epoch 30/300
# 6/6 - 1s - loss: 0.9598 - accuracy: 0.2361 - 1s/epoch - 212ms/step
# Epoch 31/300
# 6/6 - 1s - loss: 0.9564 - accuracy: 0.2411 - 1s/epoch - 212ms/step
# Epoch 32/300
# 6/6 - 1s - loss: 0.9580 - accuracy: 0.2462 - 1s/epoch - 197ms/step
# Epoch 33/300
# 6/6 - 1s - loss: 0.9564 - accuracy: 0.2462 - 1s/epoch - 205ms/step
# Epoch 34/300
# 6/6 - 1s - loss: 0.9552 - accuracy: 0.2445 - 1s/epoch - 201ms/step
# Epoch 35/300
# 6/6 - 1s - loss: 0.9533 - accuracy: 0.2361 - 1s/epoch - 203ms/step
# Epoch 36/300
# 6/6 - 1s - loss: 0.9547 - accuracy: 0.2411 - 1s/epoch - 199ms/step
# Epoch 37/300
# 6/6 - 1s - loss: 0.9506 - accuracy: 0.2496 - 1s/epoch - 208ms/step
# Epoch 38/300
# 6/6 - 1s - loss: 0.9510 - accuracy: 0.2293 - 1s/epoch - 234ms/step
# Epoch 39/300
# 6/6 - 1s - loss: 0.9458 - accuracy: 0.2530 - 1s/epoch - 211ms/step
# Epoch 40/300
# 6/6 - 1s - loss: 0.9434 - accuracy: 0.2462 - 1s/epoch - 233ms/step
# Epoch 41/300
# 6/6 - 1s - loss: 0.9469 - accuracy: 0.2462 - 1s/epoch - 202ms/step
# Epoch 42/300
# 6/6 - 1s - loss: 0.9454 - accuracy: 0.2310 - 1s/epoch - 212ms/step
# Epoch 43/300
# 6/6 - 1s - loss: 0.9366 - accuracy: 0.2344 - 1s/epoch - 196ms/step
# Epoch 44/300
# 6/6 - 1s - loss: 0.9350 - accuracy: 0.2344 - 1s/epoch - 195ms/step
# Epoch 45/300
# 6/6 - 1s - loss: 0.9434 - accuracy: 0.2395 - 1s/epoch - 198ms/step
# Epoch 46/300
# 6/6 - 1s - loss: 0.9313 - accuracy: 0.2344 - 1s/epoch - 208ms/step
# Epoch 47/300
# 6/6 - 1s - loss: 0.9398 - accuracy: 0.2445 - 1s/epoch - 193ms/step
# Epoch 48/300
# 6/6 - 1s - loss: 0.9323 - accuracy: 0.2344 - 1s/epoch - 195ms/step
# Epoch 49/300
# 6/6 - 1s - loss: 0.9314 - accuracy: 0.2479 - 1s/epoch - 195ms/step
# Epoch 50/300
# 6/6 - 2s - loss: 0.9347 - accuracy: 0.2411 - 2s/epoch - 253ms/step
# Epoch 51/300
# 6/6 - 2s - loss: 0.9294 - accuracy: 0.2395 - 2s/epoch - 257ms/step
# Epoch 52/300
# 6/6 - 1s - loss: 0.9289 - accuracy: 0.2479 - 1s/epoch - 247ms/step
# Epoch 53/300
# 6/6 - 1s - loss: 0.9143 - accuracy: 0.2445 - 1s/epoch - 248ms/step
# Epoch 54/300
# 6/6 - 1s - loss: 0.9209 - accuracy: 0.2445 - 1s/epoch - 249ms/step
# Epoch 55/300
# 6/6 - 1s - loss: 0.9249 - accuracy: 0.2260 - 1s/epoch - 248ms/step
# Epoch 56/300
# 6/6 - 1s - loss: 0.9349 - accuracy: 0.2395 - 1s/epoch - 232ms/step
# Epoch 57/300
# 6/6 - 2s - loss: 0.9240 - accuracy: 0.2344 - 2s/epoch - 264ms/step
# Epoch 58/300
# 6/6 - 2s - loss: 0.9190 - accuracy: 0.2378 - 2s/epoch - 256ms/step
# Epoch 59/300
# 6/6 - 1s - loss: 0.9200 - accuracy: 0.2563 - 1s/epoch - 237ms/step
# Epoch 60/300
# 6/6 - 1s - loss: 0.9223 - accuracy: 0.2462 - 1s/epoch - 234ms/step
# Epoch 61/300
# 6/6 - 1s - loss: 0.8995 - accuracy: 0.2479 - 1s/epoch - 218ms/step
# Epoch 62/300
# 6/6 - 1s - loss: 0.9139 - accuracy: 0.2226 - 1s/epoch - 214ms/step
# Epoch 63/300
# 6/6 - 1s - loss: 0.9033 - accuracy: 0.2462 - 1s/epoch - 225ms/step
# Epoch 64/300
# 6/6 - 1s - loss: 0.8995 - accuracy: 0.2546 - 1s/epoch - 229ms/step
# Epoch 65/300
# 6/6 - 1s - loss: 0.8992 - accuracy: 0.2428 - 1s/epoch - 224ms/step
# Epoch 66/300
# 6/6 - 1s - loss: 0.8981 - accuracy: 0.2378 - 1s/epoch - 212ms/step
# Epoch 67/300
# 6/6 - 1s - loss: 0.8900 - accuracy: 0.2614 - 1s/epoch - 214ms/step
# Epoch 68/300
# 6/6 - 1s - loss: 0.8896 - accuracy: 0.2563 - 1s/epoch - 214ms/step
# Epoch 69/300
# 6/6 - 1s - loss: 0.8876 - accuracy: 0.2496 - 1s/epoch - 224ms/step
# Epoch 70/300
# 6/6 - 1s - loss: 0.8856 - accuracy: 0.2479 - 1s/epoch - 206ms/step
# Epoch 71/300
# 6/6 - 1s - loss: 0.8953 - accuracy: 0.2395 - 1s/epoch - 243ms/step
# Epoch 72/300
# 6/6 - 1s - loss: 0.8936 - accuracy: 0.2293 - 1s/epoch - 213ms/step
# Epoch 73/300
# 6/6 - 1s - loss: 0.8831 - accuracy: 0.2563 - 1s/epoch - 203ms/step
# Epoch 74/300
# 6/6 - 1s - loss: 0.8801 - accuracy: 0.2715 - 1s/epoch - 210ms/step
# Epoch 75/300
# 6/6 - 1s - loss: 0.8760 - accuracy: 0.2530 - 1s/epoch - 200ms/step
# Epoch 76/300
# 6/6 - 1s - loss: 0.8804 - accuracy: 0.2411 - 1s/epoch - 197ms/step
# Epoch 77/300
# 6/6 - 1s - loss: 0.8700 - accuracy: 0.2445 - 1s/epoch - 218ms/step
# Epoch 78/300
# 6/6 - 1s - loss: 0.8783 - accuracy: 0.2580 - 1s/epoch - 232ms/step
# Epoch 79/300
# 6/6 - 2s - loss: 0.8740 - accuracy: 0.2597 - 2s/epoch - 261ms/step
# Epoch 80/300
# 6/6 - 2s - loss: 0.8669 - accuracy: 0.2546 - 2s/epoch - 314ms/step
# Epoch 81/300
# 6/6 - 2s - loss: 0.8674 - accuracy: 0.2546 - 2s/epoch - 267ms/step
# Epoch 82/300
# 6/6 - 2s - loss: 0.8671 - accuracy: 0.2445 - 2s/epoch - 254ms/step
# Epoch 83/300
# 6/6 - 2s - loss: 0.8699 - accuracy: 0.2749 - 2s/epoch - 278ms/step
# Epoch 84/300
# 6/6 - 1s - loss: 0.8711 - accuracy: 0.2546 - 1s/epoch - 214ms/step
# Epoch 85/300
# 6/6 - 1s - loss: 0.8590 - accuracy: 0.2698 - 1s/epoch - 210ms/step
# Epoch 86/300
# 6/6 - 1s - loss: 0.8610 - accuracy: 0.2631 - 1s/epoch - 200ms/step
# Epoch 87/300
# 6/6 - 1s - loss: 0.8650 - accuracy: 0.2563 - 1s/epoch - 227ms/step
# Epoch 88/300
# 6/6 - 1s - loss: 0.8588 - accuracy: 0.2597 - 1s/epoch - 191ms/step
# Epoch 89/300
# 6/6 - 1s - loss: 0.8628 - accuracy: 0.2648 - 1s/epoch - 192ms/step
# Epoch 90/300
# 6/6 - 1s - loss: 0.8542 - accuracy: 0.2833 - 1s/epoch - 207ms/step
# Epoch 91/300
# 6/6 - 1s - loss: 0.8536 - accuracy: 0.2597 - 1s/epoch - 227ms/step
# Epoch 92/300
# 6/6 - 1s - loss: 0.8530 - accuracy: 0.2698 - 1s/epoch - 209ms/step
# Epoch 93/300
# 6/6 - 1s - loss: 0.8577 - accuracy: 0.2580 - 1s/epoch - 211ms/step
# Epoch 94/300
# 6/6 - 1s - loss: 0.8518 - accuracy: 0.2698 - 1s/epoch - 242ms/step
# Epoch 95/300
# 6/6 - 2s - loss: 0.8443 - accuracy: 0.2782 - 2s/epoch - 267ms/step
# Epoch 96/300
# 6/6 - 1s - loss: 0.8446 - accuracy: 0.2715 - 1s/epoch - 231ms/step
# Epoch 97/300
# 6/6 - 1s - loss: 0.8483 - accuracy: 0.2867 - 1s/epoch - 229ms/step
# Epoch 98/300
# 6/6 - 1s - loss: 0.8612 - accuracy: 0.2597 - 1s/epoch - 224ms/step
# Epoch 99/300
# 6/6 - 1s - loss: 0.8533 - accuracy: 0.2732 - 1s/epoch - 215ms/step
# Epoch 100/300
# 6/6 - 1s - loss: 0.8430 - accuracy: 0.2681 - 1s/epoch - 217ms/step
# Epoch 101/300
# 6/6 - 1s - loss: 0.8449 - accuracy: 0.2732 - 1s/epoch - 233ms/step
# Epoch 102/300
# 6/6 - 1s - loss: 0.8402 - accuracy: 0.2850 - 1s/epoch - 226ms/step
# Epoch 103/300
# 6/6 - 1s - loss: 0.8468 - accuracy: 0.2782 - 1s/epoch - 225ms/step
# Epoch 104/300
# 6/6 - 1s - loss: 0.8400 - accuracy: 0.2766 - 1s/epoch - 208ms/step
# Epoch 105/300
# 6/6 - 1s - loss: 0.8342 - accuracy: 0.2901 - 1s/epoch - 203ms/step
# Epoch 106/300
# 6/6 - 1s - loss: 0.8359 - accuracy: 0.2766 - 1s/epoch - 204ms/step
# Epoch 107/300
# 6/6 - 1s - loss: 0.8472 - accuracy: 0.2698 - 1s/epoch - 201ms/step
# Epoch 108/300
# 6/6 - 1s - loss: 0.8511 - accuracy: 0.2799 - 1s/epoch - 199ms/step
# Epoch 109/300
# 6/6 - 1s - loss: 0.8446 - accuracy: 0.2917 - 1s/epoch - 197ms/step
# Epoch 110/300
# 6/6 - 1s - loss: 0.8278 - accuracy: 0.3002 - 1s/epoch - 193ms/step
# Epoch 111/300
# 6/6 - 1s - loss: 0.8288 - accuracy: 0.2732 - 1s/epoch - 196ms/step
# Epoch 112/300
# 6/6 - 1s - loss: 0.8191 - accuracy: 0.2766 - 1s/epoch - 194ms/step
# Epoch 113/300
# 6/6 - 1s - loss: 0.8235 - accuracy: 0.2850 - 1s/epoch - 191ms/step
# Epoch 114/300
# 6/6 - 1s - loss: 0.8187 - accuracy: 0.2766 - 1s/epoch - 200ms/step
# Epoch 115/300
# 6/6 - 1s - loss: 0.8281 - accuracy: 0.2917 - 1s/epoch - 198ms/step
# Epoch 116/300
# 6/6 - 1s - loss: 0.8171 - accuracy: 0.2681 - 1s/epoch - 213ms/step
# Epoch 117/300
# 6/6 - 1s - loss: 0.8095 - accuracy: 0.2934 - 1s/epoch - 231ms/step
# Epoch 118/300
# 6/6 - 1s - loss: 0.8119 - accuracy: 0.2917 - 1s/epoch - 236ms/step
# Epoch 119/300
# 6/6 - 1s - loss: 0.8109 - accuracy: 0.3103 - 1s/epoch - 211ms/step
# Epoch 120/300
# 6/6 - 1s - loss: 0.8113 - accuracy: 0.2867 - 1s/epoch - 216ms/step
# Epoch 121/300
# 6/6 - 1s - loss: 0.8065 - accuracy: 0.2985 - 1s/epoch - 200ms/step
# Epoch 122/300
# 6/6 - 1s - loss: 0.8037 - accuracy: 0.3103 - 1s/epoch - 201ms/step
# Epoch 123/300
# 6/6 - 1s - loss: 0.8012 - accuracy: 0.2951 - 1s/epoch - 213ms/step
# Epoch 124/300
# 6/6 - 1s - loss: 0.7969 - accuracy: 0.3019 - 1s/epoch - 201ms/step
# Epoch 125/300
# 6/6 - 1s - loss: 0.7948 - accuracy: 0.2934 - 1s/epoch - 194ms/step
# Epoch 126/300
# 6/6 - 1s - loss: 0.7916 - accuracy: 0.2917 - 1s/epoch - 207ms/step
# Epoch 127/300
# 6/6 - 1s - loss: 0.7953 - accuracy: 0.3052 - 1s/epoch - 194ms/step
# Epoch 128/300
# 6/6 - 1s - loss: 0.7872 - accuracy: 0.2951 - 1s/epoch - 197ms/step
# Epoch 129/300
# 6/6 - 1s - loss: 0.7887 - accuracy: 0.2934 - 1s/epoch - 206ms/step
# Epoch 130/300
# 6/6 - 1s - loss: 0.7851 - accuracy: 0.2732 - 1s/epoch - 194ms/step
# Epoch 131/300
# 6/6 - 1s - loss: 0.7823 - accuracy: 0.2917 - 1s/epoch - 211ms/step
# Epoch 132/300
# 6/6 - 1s - loss: 0.7747 - accuracy: 0.3035 - 1s/epoch - 199ms/step
# Epoch 133/300
# 6/6 - 1s - loss: 0.7791 - accuracy: 0.3170 - 1s/epoch - 212ms/step
# Epoch 134/300
# 6/6 - 1s - loss: 0.7876 - accuracy: 0.3103 - 1s/epoch - 206ms/step
# Epoch 135/300
# 6/6 - 1s - loss: 0.7973 - accuracy: 0.3255 - 1s/epoch - 212ms/step
# Epoch 136/300
# 6/6 - 1s - loss: 0.8068 - accuracy: 0.2968 - 1s/epoch - 221ms/step
# Epoch 137/300
# 6/6 - 2s - loss: 0.8070 - accuracy: 0.3069 - 2s/epoch - 271ms/step
# Epoch 138/300
# 6/6 - 1s - loss: 0.7822 - accuracy: 0.3305 - 1s/epoch - 237ms/step
# Epoch 139/300
# 6/6 - 1s - loss: 0.7799 - accuracy: 0.3103 - 1s/epoch - 225ms/step
# Epoch 140/300
# 6/6 - 1s - loss: 0.7729 - accuracy: 0.3221 - 1s/epoch - 221ms/step
# Epoch 141/300
# 6/6 - 1s - loss: 0.7623 - accuracy: 0.3137 - 1s/epoch - 202ms/step
# Epoch 142/300
# 6/6 - 1s - loss: 0.7570 - accuracy: 0.3238 - 1s/epoch - 195ms/step
# Epoch 143/300
# 6/6 - 1s - loss: 0.7554 - accuracy: 0.3120 - 1s/epoch - 194ms/step
# Epoch 144/300
# 6/6 - 1s - loss: 0.7599 - accuracy: 0.3170 - 1s/epoch - 199ms/step
# Epoch 145/300
# 6/6 - 1s - loss: 0.7699 - accuracy: 0.3069 - 1s/epoch - 207ms/step
# Epoch 146/300
# 6/6 - 1s - loss: 0.7695 - accuracy: 0.3153 - 1s/epoch - 241ms/step
# Epoch 147/300
# 6/6 - 2s - loss: 0.7744 - accuracy: 0.3170 - 2s/epoch - 255ms/step
# Epoch 148/300
# 6/6 - 1s - loss: 0.7639 - accuracy: 0.3255 - 1s/epoch - 234ms/step
# Epoch 149/300
# 6/6 - 1s - loss: 0.7595 - accuracy: 0.3221 - 1s/epoch - 204ms/step
# Epoch 150/300
# 6/6 - 1s - loss: 0.7475 - accuracy: 0.3356 - 1s/epoch - 201ms/step
# Epoch 151/300
# 6/6 - 1s - loss: 0.7448 - accuracy: 0.3272 - 1s/epoch - 205ms/step
# Epoch 152/300
# 6/6 - 1s - loss: 0.7477 - accuracy: 0.3272 - 1s/epoch - 196ms/step
# Epoch 153/300
# 6/6 - 1s - loss: 0.7506 - accuracy: 0.3221 - 1s/epoch - 244ms/step
# Epoch 154/300
# 6/6 - 1s - loss: 0.7464 - accuracy: 0.3170 - 1s/epoch - 238ms/step
# Epoch 155/300
# 6/6 - 1s - loss: 0.7378 - accuracy: 0.3221 - 1s/epoch - 247ms/step
# Epoch 156/300
# 6/6 - 1s - loss: 0.7388 - accuracy: 0.3170 - 1s/epoch - 237ms/step
# Epoch 157/300
# 6/6 - 1s - loss: 0.7361 - accuracy: 0.3187 - 1s/epoch - 220ms/step
# Epoch 158/300
# 6/6 - 1s - loss: 0.7336 - accuracy: 0.3221 - 1s/epoch - 236ms/step
# Epoch 159/300
# 6/6 - 1s - loss: 0.7300 - accuracy: 0.3440 - 1s/epoch - 225ms/step
# Epoch 160/300
# 6/6 - 1s - loss: 0.7295 - accuracy: 0.3626 - 1s/epoch - 212ms/step
# Epoch 161/300
# 6/6 - 1s - loss: 0.7388 - accuracy: 0.3221 - 1s/epoch - 198ms/step
# Epoch 162/300
# 6/6 - 1s - loss: 0.7400 - accuracy: 0.3305 - 1s/epoch - 204ms/step
# Epoch 163/300
# 6/6 - 1s - loss: 0.7278 - accuracy: 0.3356 - 1s/epoch - 201ms/step
# Epoch 164/300
# 6/6 - 1s - loss: 0.7236 - accuracy: 0.3423 - 1s/epoch - 203ms/step
# Epoch 165/300
# 6/6 - 1s - loss: 0.7243 - accuracy: 0.3339 - 1s/epoch - 212ms/step
# Epoch 166/300
# 6/6 - 1s - loss: 0.7272 - accuracy: 0.3423 - 1s/epoch - 207ms/step
# Epoch 167/300
# 6/6 - 1s - loss: 0.7160 - accuracy: 0.3221 - 1s/epoch - 213ms/step
# Epoch 168/300
# 6/6 - 1s - loss: 0.7108 - accuracy: 0.3373 - 1s/epoch - 199ms/step
# Epoch 169/300
# 6/6 - 1s - loss: 0.7161 - accuracy: 0.3440 - 1s/epoch - 236ms/step
# Epoch 170/300
# 6/6 - 1s - loss: 0.7091 - accuracy: 0.3440 - 1s/epoch - 223ms/step
# Epoch 171/300
# 6/6 - 2s - loss: 0.7030 - accuracy: 0.3373 - 2s/epoch - 250ms/step
# Epoch 172/300
# 6/6 - 1s - loss: 0.7142 - accuracy: 0.3406 - 1s/epoch - 240ms/step
# Epoch 173/300
# 6/6 - 1s - loss: 0.7064 - accuracy: 0.3440 - 1s/epoch - 201ms/step
# Epoch 174/300
# 6/6 - 1s - loss: 0.7146 - accuracy: 0.3440 - 1s/epoch - 236ms/step
# Epoch 175/300
# 6/6 - 1s - loss: 0.6970 - accuracy: 0.3305 - 1s/epoch - 216ms/step
# Epoch 176/300
# 6/6 - 1s - loss: 0.6906 - accuracy: 0.3524 - 1s/epoch - 219ms/step
# Epoch 177/300
# 6/6 - 1s - loss: 0.6960 - accuracy: 0.3356 - 1s/epoch - 206ms/step
# Epoch 178/300
# 6/6 - 1s - loss: 0.6961 - accuracy: 0.3474 - 1s/epoch - 218ms/step
# Epoch 179/300
# 6/6 - 1s - loss: 0.6914 - accuracy: 0.3491 - 1s/epoch - 219ms/step
# Epoch 180/300
# 6/6 - 1s - loss: 0.6908 - accuracy: 0.3406 - 1s/epoch - 215ms/step
# Epoch 181/300
# 6/6 - 1s - loss: 0.6947 - accuracy: 0.3356 - 1s/epoch - 208ms/step
# Epoch 182/300
# 6/6 - 1s - loss: 0.6848 - accuracy: 0.3339 - 1s/epoch - 206ms/step
# Epoch 183/300
# 6/6 - 1s - loss: 0.6890 - accuracy: 0.3575 - 1s/epoch - 220ms/step
# Epoch 184/300
# 6/6 - 1s - loss: 0.6919 - accuracy: 0.3609 - 1s/epoch - 236ms/step
# Epoch 185/300
# 6/6 - 1s - loss: 0.6844 - accuracy: 0.3423 - 1s/epoch - 210ms/step
# Epoch 186/300
# 6/6 - 1s - loss: 0.6848 - accuracy: 0.3541 - 1s/epoch - 212ms/step
# Epoch 187/300
# 6/6 - 1s - loss: 0.6768 - accuracy: 0.3305 - 1s/epoch - 195ms/step
# Epoch 188/300
# 6/6 - 1s - loss: 0.6690 - accuracy: 0.3491 - 1s/epoch - 198ms/step
# Epoch 189/300
# 6/6 - 1s - loss: 0.6600 - accuracy: 0.3305 - 1s/epoch - 198ms/step
# Epoch 190/300
# 6/6 - 1s - loss: 0.6640 - accuracy: 0.3440 - 1s/epoch - 201ms/step
# Epoch 191/300
# 6/6 - 1s - loss: 0.6678 - accuracy: 0.3474 - 1s/epoch - 204ms/step
# Epoch 192/300
# 6/6 - 1s - loss: 0.6625 - accuracy: 0.3693 - 1s/epoch - 209ms/step
# Epoch 193/300
# 6/6 - 1s - loss: 0.6642 - accuracy: 0.3592 - 1s/epoch - 198ms/step
# Epoch 194/300
# 6/6 - 1s - loss: 0.6647 - accuracy: 0.3558 - 1s/epoch - 197ms/step
# Epoch 195/300
# 6/6 - 1s - loss: 0.6561 - accuracy: 0.3794 - 1s/epoch - 200ms/step
# Epoch 196/300
# 6/6 - 1s - loss: 0.6521 - accuracy: 0.3761 - 1s/epoch - 200ms/step
# Epoch 197/300
# 6/6 - 1s - loss: 0.6483 - accuracy: 0.3659 - 1s/epoch - 206ms/step
# Epoch 198/300
# 6/6 - 1s - loss: 0.6360 - accuracy: 0.3524 - 1s/epoch - 199ms/step
# Epoch 199/300
# 6/6 - 1s - loss: 0.6445 - accuracy: 0.3524 - 1s/epoch - 194ms/step
# Epoch 200/300
# 6/6 - 1s - loss: 0.6406 - accuracy: 0.3592 - 1s/epoch - 192ms/step
# Epoch 201/300
# 6/6 - 1s - loss: 0.6557 - accuracy: 0.3575 - 1s/epoch - 200ms/step
# Epoch 202/300
# 6/6 - 1s - loss: 0.6327 - accuracy: 0.3676 - 1s/epoch - 193ms/step
# Epoch 203/300
# 6/6 - 1s - loss: 0.6291 - accuracy: 0.3626 - 1s/epoch - 210ms/step
# Epoch 204/300
# 6/6 - 2s - loss: 0.6269 - accuracy: 0.3828 - 2s/epoch - 274ms/step
# Epoch 205/300
# 6/6 - 1s - loss: 0.6255 - accuracy: 0.3474 - 1s/epoch - 243ms/step
# Epoch 206/300
# 6/6 - 2s - loss: 0.6249 - accuracy: 0.3811 - 2s/epoch - 277ms/step
# Epoch 207/300
# 6/6 - 2s - loss: 0.6280 - accuracy: 0.3777 - 2s/epoch - 254ms/step
# Epoch 208/300
# 6/6 - 1s - loss: 0.6196 - accuracy: 0.3609 - 1s/epoch - 248ms/step
# Epoch 209/300
# 6/6 - 2s - loss: 0.6192 - accuracy: 0.3912 - 2s/epoch - 255ms/step
# Epoch 210/300
# 6/6 - 1s - loss: 0.6185 - accuracy: 0.3811 - 1s/epoch - 226ms/step
# Epoch 211/300
# 6/6 - 2s - loss: 0.6077 - accuracy: 0.3626 - 2s/epoch - 262ms/step
# Epoch 212/300
# 6/6 - 1s - loss: 0.6043 - accuracy: 0.3794 - 1s/epoch - 229ms/step
# Epoch 213/300
# 6/6 - 2s - loss: 0.6151 - accuracy: 0.3710 - 2s/epoch - 251ms/step
# Epoch 214/300
# 6/6 - 1s - loss: 0.6162 - accuracy: 0.3997 - 1s/epoch - 227ms/step
# Epoch 215/300
# 6/6 - 1s - loss: 0.6014 - accuracy: 0.4047 - 1s/epoch - 198ms/step
# Epoch 216/300
# 6/6 - 1s - loss: 0.6010 - accuracy: 0.3895 - 1s/epoch - 215ms/step
# Epoch 217/300
# 6/6 - 1s - loss: 0.5968 - accuracy: 0.3946 - 1s/epoch - 231ms/step
# Epoch 218/300
# 6/6 - 1s - loss: 0.6005 - accuracy: 0.3929 - 1s/epoch - 218ms/step
# Epoch 219/300
# 6/6 - 2s - loss: 0.5969 - accuracy: 0.3912 - 2s/epoch - 250ms/step
# Epoch 220/300
# 6/6 - 1s - loss: 0.5943 - accuracy: 0.3862 - 1s/epoch - 240ms/step
# Epoch 221/300
# 6/6 - 1s - loss: 0.5869 - accuracy: 0.4081 - 1s/epoch - 223ms/step
# Epoch 222/300
# 6/6 - 1s - loss: 0.5858 - accuracy: 0.3862 - 1s/epoch - 225ms/step
# Epoch 223/300
# 6/6 - 1s - loss: 0.5900 - accuracy: 0.3895 - 1s/epoch - 218ms/step
# Epoch 224/300
# 6/6 - 1s - loss: 0.5798 - accuracy: 0.3862 - 1s/epoch - 225ms/step
# Epoch 225/300
# 6/6 - 1s - loss: 0.5826 - accuracy: 0.4064 - 1s/epoch - 205ms/step
# Epoch 226/300
# 6/6 - 1s - loss: 0.5791 - accuracy: 0.3946 - 1s/epoch - 213ms/step
# Epoch 227/300
# 6/6 - 1s - loss: 0.5843 - accuracy: 0.3929 - 1s/epoch - 206ms/step
# Epoch 228/300
# 6/6 - 1s - loss: 0.5701 - accuracy: 0.3946 - 1s/epoch - 211ms/step
# Epoch 229/300
# 6/6 - 1s - loss: 0.5750 - accuracy: 0.4266 - 1s/epoch - 238ms/step
# Epoch 230/300
# 6/6 - 1s - loss: 0.5742 - accuracy: 0.4047 - 1s/epoch - 234ms/step
# Epoch 231/300
# 6/6 - 1s - loss: 0.5719 - accuracy: 0.3980 - 1s/epoch - 202ms/step
# Epoch 232/300
# 6/6 - 1s - loss: 0.5749 - accuracy: 0.3997 - 1s/epoch - 201ms/step
# Epoch 233/300
# 6/6 - 1s - loss: 0.5691 - accuracy: 0.4165 - 1s/epoch - 197ms/step
# Epoch 234/300
# 6/6 - 1s - loss: 0.5731 - accuracy: 0.4064 - 1s/epoch - 216ms/step
# Epoch 235/300
# 6/6 - 1s - loss: 0.5641 - accuracy: 0.4199 - 1s/epoch - 231ms/step
# Epoch 236/300
# 6/6 - 1s - loss: 0.5648 - accuracy: 0.4182 - 1s/epoch - 209ms/step
# Epoch 237/300
# 6/6 - 1s - loss: 0.5674 - accuracy: 0.4115 - 1s/epoch - 197ms/step
# Epoch 238/300
# 6/6 - 1s - loss: 0.5501 - accuracy: 0.4148 - 1s/epoch - 204ms/step
# Epoch 239/300
# 6/6 - 1s - loss: 0.5550 - accuracy: 0.4300 - 1s/epoch - 198ms/step
# Epoch 240/300
# 6/6 - 1s - loss: 0.5465 - accuracy: 0.4132 - 1s/epoch - 192ms/step
# Epoch 241/300
# 6/6 - 1s - loss: 0.5518 - accuracy: 0.4148 - 1s/epoch - 189ms/step
# Epoch 242/300
# 6/6 - 1s - loss: 0.5513 - accuracy: 0.4233 - 1s/epoch - 200ms/step
# Epoch 243/300
# 6/6 - 1s - loss: 0.5628 - accuracy: 0.4081 - 1s/epoch - 242ms/step
# Epoch 244/300
# 6/6 - 1s - loss: 0.5499 - accuracy: 0.4199 - 1s/epoch - 220ms/step
# Epoch 245/300
# 6/6 - 1s - loss: 0.5405 - accuracy: 0.4418 - 1s/epoch - 230ms/step
# Epoch 246/300
# 6/6 - 1s - loss: 0.5464 - accuracy: 0.4216 - 1s/epoch - 237ms/step
# Epoch 247/300
# 6/6 - 2s - loss: 0.5303 - accuracy: 0.4334 - 2s/epoch - 252ms/step
# Epoch 248/300
# 6/6 - 2s - loss: 0.5447 - accuracy: 0.4401 - 2s/epoch - 253ms/step
# Epoch 249/300
# 6/6 - 1s - loss: 0.5342 - accuracy: 0.4418 - 1s/epoch - 233ms/step
# Epoch 250/300
# 6/6 - 2s - loss: 0.5305 - accuracy: 0.4604 - 2s/epoch - 250ms/step
# Epoch 251/300
# 6/6 - 1s - loss: 0.5282 - accuracy: 0.4368 - 1s/epoch - 248ms/step
# Epoch 252/300
# 6/6 - 1s - loss: 0.5338 - accuracy: 0.4047 - 1s/epoch - 217ms/step
# Epoch 253/300
# 6/6 - 2s - loss: 0.5264 - accuracy: 0.4452 - 2s/epoch - 271ms/step
# Epoch 254/300
# 6/6 - 1s - loss: 0.5213 - accuracy: 0.4486 - 1s/epoch - 244ms/step
# Epoch 255/300
# 6/6 - 2s - loss: 0.5181 - accuracy: 0.4519 - 2s/epoch - 256ms/step
# Epoch 256/300
# 6/6 - 2s - loss: 0.5065 - accuracy: 0.4519 - 2s/epoch - 319ms/step
# Epoch 257/300
# 6/6 - 1s - loss: 0.5144 - accuracy: 0.4469 - 1s/epoch - 247ms/step
# Epoch 258/300
# 6/6 - 1s - loss: 0.5085 - accuracy: 0.4469 - 1s/epoch - 231ms/step
# Epoch 259/300
# 6/6 - 2s - loss: 0.5056 - accuracy: 0.4486 - 2s/epoch - 280ms/step
# Epoch 260/300
# 6/6 - 1s - loss: 0.5050 - accuracy: 0.4654 - 1s/epoch - 224ms/step
# Epoch 261/300
# 6/6 - 1s - loss: 0.4961 - accuracy: 0.4486 - 1s/epoch - 212ms/step
# Epoch 262/300
# 6/6 - 1s - loss: 0.5059 - accuracy: 0.4435 - 1s/epoch - 224ms/step
# Epoch 263/300
# 6/6 - 1s - loss: 0.4967 - accuracy: 0.4688 - 1s/epoch - 207ms/step
# Epoch 264/300
# 6/6 - 1s - loss: 0.4904 - accuracy: 0.4637 - 1s/epoch - 206ms/step
# Epoch 265/300
# 6/6 - 1s - loss: 0.4923 - accuracy: 0.4570 - 1s/epoch - 206ms/step
# Epoch 266/300
# 6/6 - 1s - loss: 0.4853 - accuracy: 0.4688 - 1s/epoch - 206ms/step
# Epoch 267/300
# 6/6 - 1s - loss: 0.4839 - accuracy: 0.4452 - 1s/epoch - 199ms/step
# Epoch 268/300
# 6/6 - 1s - loss: 0.4919 - accuracy: 0.4452 - 1s/epoch - 207ms/step
# Epoch 269/300
# 6/6 - 1s - loss: 0.4855 - accuracy: 0.4755 - 1s/epoch - 239ms/step
# Epoch 270/300
# 6/6 - 1s - loss: 0.4794 - accuracy: 0.4435 - 1s/epoch - 218ms/step
# Epoch 271/300
# 6/6 - 1s - loss: 0.4876 - accuracy: 0.4587 - 1s/epoch - 229ms/step
# Epoch 272/300
# 6/6 - 2s - loss: 0.4864 - accuracy: 0.4722 - 2s/epoch - 255ms/step
# Epoch 273/300
# 6/6 - 1s - loss: 0.4724 - accuracy: 0.4671 - 1s/epoch - 213ms/step
# Epoch 274/300
# 6/6 - 1s - loss: 0.4654 - accuracy: 0.4823 - 1s/epoch - 201ms/step
# Epoch 275/300
# 6/6 - 1s - loss: 0.4695 - accuracy: 0.4722 - 1s/epoch - 204ms/step
# Epoch 276/300
# 6/6 - 1s - loss: 0.4568 - accuracy: 0.4553 - 1s/epoch - 207ms/step
# Epoch 277/300
# 6/6 - 1s - loss: 0.4563 - accuracy: 0.4637 - 1s/epoch - 212ms/step
# Epoch 278/300
# 6/6 - 1s - loss: 0.4559 - accuracy: 0.4874 - 1s/epoch - 212ms/step
# Epoch 279/300
# 6/6 - 1s - loss: 0.4603 - accuracy: 0.5194 - 1s/epoch - 228ms/step
# Epoch 280/300
# 6/6 - 1s - loss: 0.4533 - accuracy: 0.4654 - 1s/epoch - 214ms/step
# Epoch 281/300
# 6/6 - 1s - loss: 0.4548 - accuracy: 0.4992 - 1s/epoch - 207ms/step
# Epoch 282/300
# 6/6 - 1s - loss: 0.4529 - accuracy: 0.4823 - 1s/epoch - 223ms/step
# Epoch 283/300
# 6/6 - 1s - loss: 0.4416 - accuracy: 0.4840 - 1s/epoch - 234ms/step
# Epoch 284/300
# 6/6 - 1s - loss: 0.4395 - accuracy: 0.4907 - 1s/epoch - 208ms/step
# Epoch 285/300
# 6/6 - 1s - loss: 0.4374 - accuracy: 0.4924 - 1s/epoch - 217ms/step
# Epoch 286/300
# 6/6 - 1s - loss: 0.4323 - accuracy: 0.5143 - 1s/epoch - 205ms/step
# Epoch 287/300
# 6/6 - 1s - loss: 0.4255 - accuracy: 0.4924 - 1s/epoch - 203ms/step
# Epoch 288/300
# 6/6 - 1s - loss: 0.4170 - accuracy: 0.4874 - 1s/epoch - 199ms/step
# Epoch 289/300
# 6/6 - 1s - loss: 0.4183 - accuracy: 0.5110 - 1s/epoch - 200ms/step
# Epoch 290/300
# 6/6 - 1s - loss: 0.4133 - accuracy: 0.4890 - 1s/epoch - 215ms/step
# Epoch 291/300
# 6/6 - 1s - loss: 0.4144 - accuracy: 0.5076 - 1s/epoch - 222ms/step
# Epoch 292/300
# 6/6 - 1s - loss: 0.4076 - accuracy: 0.5059 - 1s/epoch - 209ms/step
# Epoch 293/300
# 6/6 - 1s - loss: 0.4107 - accuracy: 0.5160 - 1s/epoch - 201ms/step
# Epoch 294/300
# 6/6 - 1s - loss: 0.4088 - accuracy: 0.4924 - 1s/epoch - 213ms/step
# Epoch 295/300
# 6/6 - 1s - loss: 0.3960 - accuracy: 0.5295 - 1s/epoch - 206ms/step
# Epoch 296/300
# 6/6 - 1s - loss: 0.4085 - accuracy: 0.4941 - 1s/epoch - 210ms/step
# Epoch 297/300
# 6/6 - 1s - loss: 0.4049 - accuracy: 0.5295 - 1s/epoch - 210ms/step
# Epoch 298/300
# 6/6 - 1s - loss: 0.4010 - accuracy: 0.5059 - 1s/epoch - 208ms/step
# Epoch 299/300
# 6/6 - 1s - loss: 0.3994 - accuracy: 0.5363 - 1s/epoch - 227ms/step
# Epoch 300/300
# 6/6 - 1s - loss: 0.3913 - accuracy: 0.5177 - 1s/epoch - 217ms/step

# %% [markdown]
# Prediction

# %%
to_predict = all_games.tail(8)
to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
prediction = all_games.tail(1)
to_predict = np.array(to_predict)
scaled_to_predict = scaler.transform(to_predict)
# Out:
# C:\Users\grigo\AppData\Local\Temp\ipykernel_21528\2568062844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_predict.drop([to_predict.index[-1]],axis=0, inplace=True)
# array([[-0.83156105, -0.86598885, -0.02011658,  1.15692394,  1.11533021],
#        [ 1.31286573,  1.24480621,  0.54314779,  1.57473685,  0.90200597],
#        [-1.13790774,  0.23162458, -0.2615156 , -0.09651478, -0.80458791],
#        [-0.32098325, -0.78155705, -1.22711168, -2.01845416,  0.4753575 ],
#        [-0.11675213, -0.35939804, -0.50291462,  1.32404911,  1.00866809],
#        [-0.32098325,  0.14719278, -0.6638473 ,  0.48842329,  0.79534386],
#        [ 1.00651905,  0.56935179,  0.14081609, -0.26363995, -1.44456061]])

# %%
y_pred = model.predict(np.array([scaled_to_predict]))
print('The predicted numbers in the last lottery game are:', scaler.inverse_transform(y_pred).astype(int)[0])
# Out:
# 1/1 [==============================] - 4s 4s/step
# The predicted numbers in the last lottery game are: [ 9 20 29 41 50]

# %%
prediction = np.array(prediction)
print(f'The actual numbers in the last lottery game were: {prediction[0]}')
# Out:
# The actual numbers in the last lottery game were: [ 8 11 19 24 46]

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
